# %% [markdown]
# ### Compare Results

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# #### Mean Squared Error

# %%
# %store -r mse_test_svm_new
# %store -r mse_test_rf_new
# %store -r mse_test_knn_new
# %store -r mse_test_new
# %store -r mse

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Load the MSE values
mse_values = {
    'Classifier': ['SVM', 'Random Forest', 'KNN', 'Linear Regression', 'LSTM'],
    'MSE': [mse_test_svm_new, mse_test_rf_new, mse_test_knn_new, mse_test_new, mse]
}

# Create a DataFrame from the MSE values
mse_data = pd.DataFrame(mse_values)

# Plot the MSE values
sns.set_theme(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.barplot(x='Classifier', y='MSE', hue='Classifier', data=mse_data, dodge=False)
plt.xlabel('Classifier')
plt.ylabel('Mean Squared Error (MSE)')
plt.title('Classifier Mean Squared Errors')

# Add text labels for each bar
for index, row in mse_data.iterrows():
    plt.text(index, row['MSE'] + 0.01, f'{row["MSE"]:.2f}', color='black', ha="center")

plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Root Mean Squared Error

# %%
# %store -r rmse_test_svm_new
# %store -r rmse_test_rf_new
# %store -r rmse_test_knn_new
# %store -r rmse_test_new
# %store -r rmse

# %%
rmse_values = {
    'Classifier': ['SVM', 'Random Forest', 'KNN', 'Linear Regression', 'LSTM'],
    'RMSE': [rmse_test_svm_new, rmse_test_rf_new, rmse_test_knn_new, rmse_test_new, rmse]
}

rmse_data = pd.DataFrame(rmse_values)

sns.set_theme(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.barplot(x='Classifier', y='RMSE', hue='Classifier', data=rmse_data, dodge=False)
plt.xlabel('Classifier')
plt.ylabel('Mean Squared Error (RMSE)')
plt.title('Classifier Root Mean Squared Errors')

for index, row in rmse_data.iterrows():
    plt.text(index, row['RMSE'] + 0.01, f'{row["RMSE"]:.2f}', color='black', ha="center")

plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Mean Absolute Error

# %%
# %store -r mae_test_svm_new
# %store -r mae_test_rf_new
# %store -r mae_test_knn_new
# %store -r mae_test_new
# %store -r mae

# %%
mae_values = {
    'Classifier': ['SVM', 'Random Forest', 'KNN', 'Linear Regression', 'LSTM'],
    'MAE': [mae_test_svm_new, mae_test_rf_new, mae_test_knn_new, mae_test_new, mae]
}

mae_data = pd.DataFrame(mae_values)

sns.set_theme(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.barplot(x='Classifier', y='MAE', hue='Classifier', data=mae_data, dodge=False)
plt.xlabel('Classifier')
plt.ylabel('Mean Absolute Error (MAE)')
plt.title('Classifier Mean Absolute Errors')

for index, row in mae_data.iterrows():
    plt.text(index, row['MAE'] + 0.01, f'{row["MAE"]:.2f}', color='black', ha="center")

plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### R2 Score

# %%
# %store -r r2_test_svm_new
# %store -r r2_test_rf_new
# %store -r r2_test_new
# %store -r r2_test_knn_new
# %store -r r2

# %%
r2_values = {
    'Classifier': ['SVM', 'Random Forest', 'KNN', 'Linear Regression', 'LSTM'],
    'R2': [r2_test_svm_new, r2_test_rf_new, r2_test_knn_new, r2_test_new, r2]
}

r2_data = pd.DataFrame(r2_values)

sns.set_theme(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.barplot(x='Classifier', y='R2', hue='Classifier', data=r2_data, dodge=False)
plt.xlabel('Classifier')
plt.ylabel('R2 Score (R2)')
plt.title('Classifier R2 Scores')

for index, row in r2_data.iterrows():
    plt.text(index, row['R2'] + 0.01, f'{row["R2"]:.2f}', color='black', ha="center")

plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
