# %% [markdown]
# #### Import Libraries

# %%
import pandas as pd
import numpy as np
import os
from matplotlib import pyplot
from matplotlib.ticker import FormatStrFormatter
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

import tensorflow as tf
from tensorflow.keras import layers, Sequential
from tensorflow.keras import backend as K

import matplotlib.pyplot as plt 
from matplotlib.ticker import FormatStrFormatter

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

from sklearn.preprocessing import StandardScaler
from datetime import datetime
import sys

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
tf.get_logger().setLevel('ERROR')

USE_CUDA = False
EPOCHS = 10
comms_round = 20
# Out:
# 2024-07-03 03:45:14.876569: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-03 03:45:14.876643: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-03 03:45:14.877156: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-03 03:45:14.975258: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-03 03:45:16.023849: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ### Dataset

# %%
# %store -r Fed_X_Train_st
# %store -r Fed_X_Test_st

# %store -r Fed_y_Train
# %store -r Fed_y_Test

merged_dataset = pd.concat([Fed_X_Train_st, Fed_y_Train], axis=1)
Fed_X_Test_st = Fed_X_Test_st.drop(columns=['unit_number'])

# %%
feature_columns = ['time_cycles', 'LPC_Outlet_Temperature', 'HPC_Outlet_Temperature', 'LPT Outlet Temperature', 'Bypass-Duct Pressure', 
                'HPC Outlet Pressure', 'Physical Fan Speed', 'Physical Core Speed', 'HPC Outlet Static Pressure',
                'Ratio of Fuel Flow to Ps30', 'Corrected Fan Speed', 'Bypass Ratio', 'Bleed Enthalpy',
                'High-Pressure Turbines Cool Air Flow', 'Low-Pressure Turbines Cool Air Flow']

features = merged_dataset[feature_columns]

labels = merged_dataset['RUL']

# %% [markdown]
# ### Data Partition

# %%
grouped = merged_dataset.groupby('unit_number')

unit_numbers = merged_dataset['unit_number'].unique()

np.random.seed(42)
np.random.shuffle(unit_numbers)

num_clients = 10
unit_subsets = np.array_split(unit_numbers, num_clients)

client_data = {f"client_{i+1}": pd.DataFrame() for i in range(num_clients)}

for i, unit_subset in enumerate(unit_subsets):
    client_data[f"client_{i+1}"] = grouped.filter(lambda x: x.name in unit_subset)

for i in range(num_clients):
    print(f"Client {i+1} dataset size: {len(client_data[f'client_{i+1}'])}")

client_1_data = client_data["client_1"]
client_2_data = client_data["client_2"]
client_3_data = client_data["client_3"]
client_4_data = client_data["client_4"]
client_5_data = client_data["client_5"]
client_6_data = client_data["client_6"]
client_7_data = client_data["client_7"]
client_8_data = client_data["client_8"]
client_9_data = client_data["client_9"]
client_10_data = client_data["client_10"]
# Out:
# Client 1 dataset size: 2174
# Client 2 dataset size: 1896
# Client 3 dataset size: 2054
# Client 4 dataset size: 2237
# Client 5 dataset size: 2031
# Client 6 dataset size: 1878
# Client 7 dataset size: 2046
# Client 8 dataset size: 2024
# Client 9 dataset size: 2082
# Client 10 dataset size: 2209

# %%
client_1_data = client_data["client_1"].drop(columns=['unit_number'], errors='ignore')
client_2_data = client_data["client_2"].drop(columns=['unit_number'], errors='ignore')
client_3_data = client_data["client_3"].drop(columns=['unit_number'], errors='ignore')
client_4_data = client_data["client_4"].drop(columns=['unit_number'], errors='ignore')
client_5_data = client_data["client_5"].drop(columns=['unit_number'], errors='ignore')
client_6_data = client_data["client_6"].drop(columns=['unit_number'], errors='ignore')
client_7_data = client_data["client_7"].drop(columns=['unit_number'], errors='ignore')
client_8_data = client_data["client_8"].drop(columns=['unit_number'], errors='ignore')
client_9_data = client_data["client_9"].drop(columns=['unit_number'], errors='ignore')
client_10_data = client_data["client_10"].drop(columns=['unit_number'], errors='ignore')

# %% [markdown]
# #### Train, Test split for each one of the 10 datasets

# %%
datasets = []

for i, df in enumerate([client_1_data, client_2_data, client_3_data, client_4_data, client_5_data, 
                        client_6_data, client_7_data, client_8_data, client_9_data, client_10_data]):
    
    features = df[feature_columns]
    labels = df['RUL']
    
    train_features, test_features, train_labels, test_labels = train_test_split(features, labels, test_size=0.3, random_state=0)
    
    datasets.append({
        'name': f'dataset_{i+1}',
        'train_features': train_features,
        'test_features': test_features,
        'train_labels': train_labels,
        'test_labels': test_labels
    })

# %% [markdown]
# ### LSTM Model

# %%
def create_lstm_model(input_shape):
    model = Sequential([
        layers.Reshape((input_shape, 1), input_shape=(input_shape,)),
        layers.LSTM(32, activation="relu", return_sequences=True),
        layers.Dropout(0.1), 
        layers.LSTM(64, activation="relu", return_sequences=True),
        layers.Dropout(0.2), 
        layers.LSTM(128, activation="relu"),
        layers.Dropout(0.3), 
        layers.Dense(128, activation="relu"),
        layers.Dropout(0.4), 
        layers.Dense(1)
    ])
    model.compile(loss="mse", optimizer=tf.keras.optimizers.Adam(learning_rate=0.001))
    return model


input_shape = len(train_features.columns)
lstm_model = create_lstm_model(input_shape)
# Out:
# 2024-07-03 03:45:17.633142: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-03 03:45:17.816807: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-03 03:45:17.819991: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-03 03:45:17.823045: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-03 03:45:17.825365: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-03 03:45:17.827513: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-03 03:45:18.727492: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-03 03:45:18.729351: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-03 03:45:18.731163: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-03 03:45:18.732982: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2414 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650, pci bus id: 0000:01:00.0, compute capability: 7.5

# %%
def evaluate_model(model, X_test, y_test):
    predictions = model.predict(X_test)
    
    if np.isnan(predictions).any():
        raise ValueError("Model predictions contain NaNs.")
    
    mae = mean_absolute_error(y_test, predictions)
    rmse = np.sqrt(mean_squared_error(y_test, predictions))
    r2 = r2_score(y_test, predictions)
    
    return mae, rmse, r2

# %% [markdown]
# #### Function for KRUM

# %%
def krum(weights, num_byzantine):
    n = len(weights)
    num_layers = len(weights[0]) 
    distances = np.zeros((n, n))
    
    for i in range(n):
        for j in range(i + 1, n):
            distance = 0
            for layer in range(num_layers):
                distance += np.linalg.norm(weights[i][layer] - weights[j][layer])
            distances[i, j] = distance
            distances[j, i] = distance
    
    scores = np.zeros(n)
    for i in range(n):
        scores[i] = np.sum(np.sort(distances[i])[:n - num_byzantine - 2])
    
    return weights[np.argmin(scores)]

# %% [markdown]
# ### Federated Learning System with FedMA AGGREGATION

# %%
global_model = create_lstm_model(input_shape)

global_stats_mae_4 = pd.DataFrame(columns=['Round'] + [str(i) for i in range(len(datasets))] + ['test'])
global_stats_rmse_4 = pd.DataFrame(columns=['Round'] + [str(i) for i in range(len(datasets))] + ['test'])
global_stats_r2_4 = pd.DataFrame(columns=['Round'] + [str(i) for i in range(len(datasets))] + ['test'])


for comm_round in range(comms_round):
    print('Round', comm_round)
    global_weights = global_model.get_weights()
    client_weights = []
    
    for dataset in datasets:
        local_model = create_lstm_model(input_shape)
        local_model.compile(loss='mse', optimizer=tf.keras.optimizers.Adam(), metrics='MAE')

        def scheduler(epoch):
            if epoch < 5:
                return 0.001
            else:
                return 0.0001

        callback = tf.keras.callbacks.LearningRateScheduler(scheduler, verbose=0)
        local_model.set_weights(global_weights)

        epochs = EPOCHS 
        history = local_model.fit(dataset['train_features'], dataset['train_labels'], epochs=epochs, callbacks=[callback])

        client_weights.append(local_model.get_weights())

        for dataset_1 in datasets:
            mae, rmse, r2 = evaluate_model(local_model, dataset_1['test_features'], dataset_1['test_labels'])
            print(f'Evaluation results for {dataset["name"]} on {dataset_1["name"]} in round {comm_round}: MAE={mae}, RMSE={rmse}, R²={r2}')               

        mae, rmse, r2 = evaluate_model(local_model, dataset['test_features'], dataset['test_labels'])
        print(f'Evaluation results for {dataset["name"]} on itself in round {comm_round}: MAE={mae}, RMSE={rmse}, R²={r2}')

        K.clear_session()

    num_byzantine = 2  # Υποθέτουμε ότι υπάρχουν 2 Byzantine clients
    aggregated_weights = krum(client_weights, num_byzantine)

    global_model.set_weights(aggregated_weights)

    global_row_mae = [comm_round]
    global_row_rmse = [comm_round]
    global_row_r2 = [comm_round]

    for dataset in datasets:
        mae, rmse, r2 = evaluate_model(global_model, dataset['test_features'], dataset['test_labels'])
        global_row_mae.append(mae)
        global_row_rmse.append(rmse)
        global_row_r2.append(r2)
        print(f'Global evaluation results for {dataset["name"]} in round {comm_round}: MAE={mae}, RMSE={rmse}, R²={r2}')

    # Evaluate on the separate test dataset
    test_mae, test_rmse, test_r2 = evaluate_model(global_model, Fed_X_Test_st, Fed_y_Test)
    global_row_mae.append(test_mae)
    global_row_rmse.append(test_rmse)
    global_row_r2.append(test_r2)
    print(f'Global evaluation results on test dataset in round {comm_round}: MAE={test_mae}, RMSE={test_rmse}, R²={test_r2}')

    global_stats_mae_4.loc[len(global_stats_mae_4)] = global_row_mae
    global_stats_r2_4.loc[len(global_stats_r2_4)] = global_row_r2
    global_stats_rmse_4.loc[len(global_stats_rmse_4)] = global_row_rmse

print("Training completed.")
# Out:
# Round 0
# Epoch 1/10
# 2024-07-03 03:45:24.515309: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f4bc4023260 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-07-03 03:45:24.515404: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce GTX 1650, Compute Capability 7.5
# 2024-07-03 03:45:24.532547: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-07-03 03:45:24.604686: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8902
# 2024-07-03 03:45:24.669028: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 48/48 [==============================] - 8s 39ms/step - loss: 7279.8618 - MAE: 73.7063 - lr: 0.0010
# Epoch 2/10
# 48/48 [==============================] - 2s 35ms/step - loss: 1650.8149 - MAE: 32.6761 - lr: 0.0010
# Epoch 3/10
# 48/48 [==============================] - 2s 35ms/step - loss: 728.5532 - MAE: 21.2018 - lr: 0.0010
# Epoch 4/10
# 48/48 [==============================] - 2s 36ms/step - loss: 648.0617 - MAE: 19.8314 - lr: 0.0010
# Epoch 5/10
# 48/48 [==============================] - 2s 35ms/step - loss: 605.6204 - MAE: 18.8780 - lr: 0.0010
# Epoch 6/10
# 48/48 [==============================] - 2s 35ms/step - loss: 614.7981 - MAE: 19.0998 - lr: 1.0000e-04
# Epoch 7/10
# 48/48 [==============================] - 2s 36ms/step - loss: 611.4176 - MAE: 18.9411 - lr: 1.0000e-04
# Epoch 8/10
# 48/48 [==============================] - 2s 37ms/step - loss: 590.6565 - MAE: 18.8421 - lr: 1.0000e-04
# Epoch 9/10
# 48/48 [==============================] - 2s 37ms/step - loss: 587.6897 - MAE: 18.7013 - lr: 1.0000e-04
# Epoch 10/10
# 48/48 [==============================] - 2s 37ms/step - loss: 569.4965 - MAE: 18.4160 - lr: 1.0000e-04
# 21/21 [==============================] - 0s 6ms/step
# Evaluation results for dataset_1 on dataset_1 in round 0: MAE=13.731824781409085, RMSE=19.186985928505788, R²=0.7986293822148132
# 18/18 [==============================] - 0s 6ms/step
# Evaluation results for dataset_1 on dataset_2 in round 0: MAE=13.50896723199184, RMSE=18.69358934945279, R²=0.8147840353273859
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_1 on dataset_3 in round 0: MAE=17.29934173117194, RMSE=23.125121988261967, R²=0.7183013421309161
# 21/21 [==============================] - 0s 6ms/step
# Evaluation results for dataset_1 on dataset_4 in round 0: MAE=15.793212411304316, RMSE=20.809434117556595, R²=0.755340857181227
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_1 on dataset_5 in round 0: MAE=16.504114598524374, RMSE=22.234494079227975, R²=0.7458549960518721
# 18/18 [==============================] - 0s 7ms/step
# Evaluation results for dataset_1 on dataset_6 in round 0: MAE=17.468421411218372, RMSE=24.119511206611172, R²=0.6958989450670677
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_1 on dataset_7 in round 0: MAE=18.17275985745343, RMSE=25.33244743433685, R²=0.6778732799954351
# 19/19 [==============================] - 0s 6ms/step
# Evaluation results for dataset_1 on dataset_8 in round 0: MAE=14.647683009505272, RMSE=20.105000397552097, R²=0.7895021554733634
# 20/20 [==============================] - 0s 7ms/step
# Evaluation results for dataset_1 on dataset_9 in round 0: MAE=16.448861113739014, RMSE=21.868686704160535, R²=0.7545243587423978
# 21/21 [==============================] - 0s 6ms/step
# Evaluation results for dataset_1 on dataset_10 in round 0: MAE=15.817991144516888, RMSE=21.744587968224113, R²=0.7382766534510627
# 21/21 [==============================] - 0s 6ms/step
# Evaluation results for dataset_1 on itself in round 0: MAE=13.731824781409085, RMSE=19.186985928505788, R²=0.7986293822148132
# Epoch 1/10
# 42/42 [==============================] - 4s 35ms/step - loss: 6504.4990 - MAE: 68.9585 - lr: 0.0010
# Epoch 2/10
# 42/42 [==============================] - 1s 35ms/step - loss: 1106.4540 - MAE: 27.0428 - lr: 0.0010
# Epoch 3/10
# 42/42 [==============================] - 1s 35ms/step - loss: 673.0475 - MAE: 20.2355 - lr: 0.0010
# Epoch 4/10
# 42/42 [==============================] - 1s 35ms/step - loss: 630.8765 - MAE: 19.5837 - lr: 0.0010
# Epoch 5/10
# 42/42 [==============================] - 1s 35ms/step - loss: 507.0244 - MAE: 17.5637 - lr: 0.0010
# Epoch 6/10
# 42/42 [==============================] - 1s 35ms/step - loss: 467.5043 - MAE: 16.9097 - lr: 1.0000e-04
# Epoch 7/10
# 42/42 [==============================] - 1s 35ms/step - loss: 469.3711 - MAE: 16.7430 - lr: 1.0000e-04
# Epoch 8/10
# 42/42 [==============================] - 1s 35ms/step - loss: 465.4953 - MAE: 16.7036 - lr: 1.0000e-04
# Epoch 9/10
# 42/42 [==============================] - 1s 35ms/step - loss: 455.7882 - MAE: 16.7554 - lr: 1.0000e-04
# Epoch 10/10
# 42/42 [==============================] - 2s 36ms/step - loss: 462.0416 - MAE: 16.7020 - lr: 1.0000e-04
# 21/21 [==============================] - 0s 7ms/step
# Evaluation results for dataset_2 on dataset_1 in round 0: MAE=17.92701369076739, RMSE=23.181528777887053, R²=0.7060545546163635
# 18/18 [==============================] - 0s 7ms/step
# Evaluation results for dataset_2 on dataset_2 in round 0: MAE=12.205485069898394, RMSE=15.921371870151628, R²=0.8656449502827331
# 20/20 [==============================] - 0s 7ms/step
# Evaluation results for dataset_2 on dataset_3 in round 0: MAE=18.170525568617414, RMSE=24.543145388259838, R²=0.6826948264516612
# 21/21 [==============================] - 0s 7ms/step
# Evaluation results for dataset_2 on dataset_4 in round 0: MAE=22.017634718191054, RMSE=28.25292038805878, R²=0.549009285209832
# 20/20 [==============================] - 0s 7ms/step
# Evaluation results for dataset_2 on dataset_5 in round 0: MAE=18.74279882008912, RMSE=24.890050951249734, R²=0.6815225818159746
# 18/18 [==============================] - 0s 7ms/step
# Evaluation results for dataset_2 on dataset_6 in round 0: MAE=15.310814322309291, RMSE=20.182086433401828, R²=0.787081672758612
# 20/20 [==============================] - 0s 7ms/step
# Evaluation results for dataset_2 on dataset_7 in round 0: MAE=18.390398594766175, RMSE=26.000447439984086, R²=0.6606607514717366
# 19/19 [==============================] - 0s 7ms/step
# Evaluation results for dataset_2 on dataset_8 in round 0: MAE=15.162873039120122, RMSE=19.758305065117302, R²=0.7966993092710042
# 20/20 [==============================] - 0s 7ms/step
# Evaluation results for dataset_2 on dataset_9 in round 0: MAE=17.910669409179686, RMSE=23.03028613355868, R²=0.7277539012401409
# 21/21 [==============================] - 0s 7ms/step
# Evaluation results for dataset_2 on dataset_10 in round 0: MAE=18.23921783081906, RMSE=24.009249493618967, R²=0.6809217007174047
# 18/18 [==============================] - 0s 7ms/step
# Evaluation results for dataset_2 on itself in round 0: MAE=12.205485069898394, RMSE=15.921371870151628, R²=0.8656449502827331
# Epoch 1/10
# 45/45 [==============================] - 4s 36ms/step - loss: 9108.2637 - MAE: 84.3115 - lr: 0.0010
# Epoch 2/10
# 45/45 [==============================] - 2s 35ms/step - loss: 9252.4307 - MAE: 86.1268 - lr: 0.0010
# Epoch 3/10
# 45/45 [==============================] - 2s 35ms/step - loss: 2684.0430 - MAE: 40.5467 - lr: 0.0010
# Epoch 4/10
# 45/45 [==============================] - 2s 35ms/step - loss: 777.1297 - MAE: 22.4068 - lr: 0.0010
# Epoch 5/10
# 45/45 [==============================] - 2s 35ms/step - loss: 697.3442 - MAE: 21.0902 - lr: 0.0010
# Epoch 6/10
# 45/45 [==============================] - 2s 35ms/step - loss: 665.1105 - MAE: 20.4427 - lr: 1.0000e-04
# Epoch 7/10
# 45/45 [==============================] - 2s 35ms/step - loss: 651.3435 - MAE: 20.2367 - lr: 1.0000e-04
# Epoch 8/10
# 45/45 [==============================] - 2s 35ms/step - loss: 680.2928 - MAE: 20.6428 - lr: 1.0000e-04
# Epoch 9/10
# 45/45 [==============================] - 2s 36ms/step - loss: 705.7644 - MAE: 21.1197 - lr: 1.0000e-04
# Epoch 10/10
# 45/45 [==============================] - 2s 35ms/step - loss: 672.8009 - MAE: 20.6081 - lr: 1.0000e-04
# 21/21 [==============================] - 0s 6ms/step
# Evaluation results for dataset_3 on dataset_1 in round 0: MAE=15.589662056421979, RMSE=19.977087500425295, R²=0.7817034198711601
# 18/18 [==============================] - 0s 6ms/step
# Evaluation results for dataset_3 on dataset_2 in round 0: MAE=13.354205462551285, RMSE=17.260948297116634, R²=0.8420853852749219
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_3 on dataset_3 in round 0: MAE=17.228825402221187, RMSE=22.07188090076804, R²=0.7433771043303834
# 21/21 [==============================] - 0s 6ms/step
# Evaluation results for dataset_3 on dataset_4 in round 0: MAE=18.451448278058145, RMSE=23.137094879846433, R²=0.697546535095875
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_3 on dataset_5 in round 0: MAE=17.652776497309326, RMSE=22.766235980550817, R²=0.7335537950130284
# 18/18 [==============================] - 0s 6ms/step
# Evaluation results for dataset_3 on dataset_6 in round 0: MAE=16.81426458367219, RMSE=21.911947255892848, R²=0.749017830119737
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_3 on dataset_7 in round 0: MAE=18.43018562533568, RMSE=25.068999462420482, R²=0.6845384359227329
# 19/19 [==============================] - 0s 6ms/step
# Evaluation results for dataset_3 on dataset_8 in round 0: MAE=14.910183496381107, RMSE=19.113493976866106, R²=0.8097521974917761
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_3 on dataset_9 in round 0: MAE=17.22925905418396, RMSE=21.519127689703744, R²=0.7623092271790342
# 21/21 [==============================] - 0s 6ms/step
# Evaluation results for dataset_3 on dataset_10 in round 0: MAE=17.37732270544291, RMSE=22.466617549106758, R²=0.7206070238004865
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_3 on itself in round 0: MAE=17.228825402221187, RMSE=22.07188090076804, R²=0.7433771043303834
# Epoch 1/10
# 49/49 [==============================] - 4s 35ms/step - loss: 7822.5649 - MAE: 76.7241 - lr: 0.0010
# Epoch 2/10
# 49/49 [==============================] - 2s 36ms/step - loss: 2189.6731 - MAE: 37.7622 - lr: 0.0010
# Epoch 3/10
# 49/49 [==============================] - 2s 36ms/step - loss: 835.2758 - MAE: 23.1347 - lr: 0.0010
# Epoch 4/10
# 49/49 [==============================] - 2s 35ms/step - loss: 695.5983 - MAE: 20.5072 - lr: 0.0010
# Epoch 5/10
# 49/49 [==============================] - 2s 35ms/step - loss: 661.8967 - MAE: 20.2934 - lr: 0.0010
# Epoch 6/10
# 49/49 [==============================] - 2s 35ms/step - loss: 611.2682 - MAE: 19.1525 - lr: 1.0000e-04
# Epoch 7/10
# 49/49 [==============================] - 2s 35ms/step - loss: 614.8846 - MAE: 19.6945 - lr: 1.0000e-04
# Epoch 8/10
# 49/49 [==============================] - 2s 35ms/step - loss: 588.1359 - MAE: 19.1374 - lr: 1.0000e-04
# Epoch 9/10
# 49/49 [==============================] - 2s 36ms/step - loss: 586.6234 - MAE: 18.9923 - lr: 1.0000e-04
# Epoch 10/10
# 49/49 [==============================] - 2s 35ms/step - loss: 573.7363 - MAE: 18.6265 - lr: 1.0000e-04
# 21/21 [==============================] - 0s 6ms/step
# Evaluation results for dataset_4 on dataset_1 in round 0: MAE=14.185800990868492, RMSE=20.033635051704827, R²=0.7804658412860167
# 18/18 [==============================] - 0s 6ms/step
# Evaluation results for dataset_4 on dataset_2 in round 0: MAE=15.694026412360488, RMSE=21.724574496640194, R²=0.7498528381983118
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_4 on dataset_3 in round 0: MAE=18.56843612723451, RMSE=24.90835008997609, R²=0.6731814977432956
# 21/21 [==============================] - 0s 6ms/step
# Evaluation results for dataset_4 on dataset_4 in round 0: MAE=14.244900353252888, RMSE=18.946167480127404, R²=0.7971926673388147
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_4 on dataset_5 in round 0: MAE=16.67135582282895, RMSE=22.785766520821156, R²=0.7330964448865382
# 18/18 [==============================] - 0s 6ms/step
# Evaluation results for dataset_4 on dataset_6 in round 0: MAE=18.77877029713164, RMSE=26.34890112704512, R²=0.6370841486773973
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_4 on dataset_7 in round 0: MAE=19.07431217154385, RMSE=25.906758226238967, R²=0.663101874651061
# 19/19 [==============================] - 0s 6ms/step
# Evaluation results for dataset_4 on dataset_8 in round 0: MAE=16.590848357661773, RMSE=22.889078349231742, R²=0.7271675063023544
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_4 on dataset_9 in round 0: MAE=16.95621483154297, RMSE=23.291222032711296, R²=0.7215497907830831
# 21/21 [==============================] - 0s 6ms/step
# Evaluation results for dataset_4 on dataset_10 in round 0: MAE=16.025821647313204, RMSE=22.33760452115008, R²=0.7238066011136228
# 21/21 [==============================] - 0s 6ms/step
# Evaluation results for dataset_4 on itself in round 0: MAE=14.244900353252888, RMSE=18.946167480127404, R²=0.7971926673388147
# Epoch 1/10
# 45/45 [==============================] - 4s 35ms/step - loss: 8059.0459 - MAE: 78.6645 - lr: 0.0010
# Epoch 2/10
# 45/45 [==============================] - 2s 35ms/step - loss: 1502.4768 - MAE: 31.1362 - lr: 0.0010
# Epoch 3/10
# 45/45 [==============================] - 2s 35ms/step - loss: 821.2797 - MAE: 22.9354 - lr: 0.0010
# Epoch 4/10
# 45/45 [==============================] - 2s 36ms/step - loss: 773.1168 - MAE: 22.3602 - lr: 0.0010
# Epoch 5/10
# 45/45 [==============================] - 2s 36ms/step - loss: 785.7032 - MAE: 22.5179 - lr: 0.0010
# Epoch 6/10
# 45/45 [==============================] - 2s 35ms/step - loss: 668.4099 - MAE: 20.3729 - lr: 1.0000e-04
# Epoch 7/10
# 45/45 [==============================] - 2s 35ms/step - loss: 671.5366 - MAE: 20.5900 - lr: 1.0000e-04
# Epoch 8/10
# 45/45 [==============================] - 2s 35ms/step - loss: 651.3192 - MAE: 19.9224 - lr: 1.0000e-04
# Epoch 9/10
# 45/45 [==============================] - 2s 36ms/step - loss: 667.5615 - MAE: 20.3961 - lr: 1.0000e-04
# Epoch 10/10
# 45/45 [==============================] - 2s 35ms/step - loss: 643.8102 - MAE: 19.8926 - lr: 1.0000e-04
# 21/21 [==============================] - 0s 7ms/step
# Evaluation results for dataset_5 on dataset_1 in round 0: MAE=16.217535960911608, RMSE=20.662144923298083, R²=0.7664749923244877
# 18/18 [==============================] - 0s 6ms/step
# Evaluation results for dataset_5 on dataset_2 in round 0: MAE=12.970955848693848, RMSE=16.893095121306224, R²=0.8487443951310705
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_5 on dataset_3 in round 0: MAE=18.277313909422443, RMSE=23.465959462537622, R²=0.7099363248469266
# 21/21 [==============================] - 0s 6ms/step
# Evaluation results for dataset_5 on dataset_4 in round 0: MAE=18.71109583690053, RMSE=23.445802203936218, R²=0.6894217040809453
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_5 on dataset_5 in round 0: MAE=17.396451653027142, RMSE=21.992681114497127, R²=0.7513528836422957
# 18/18 [==============================] - 0s 6ms/step
# Evaluation results for dataset_5 on dataset_6 in round 0: MAE=16.78784580433622, RMSE=21.67165875086343, R²=0.7544922370569305
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_5 on dataset_7 in round 0: MAE=18.22188127157354, RMSE=24.140299298562486, R²=0.7074785275746212
# 19/19 [==============================] - 0s 6ms/step
# Evaluation results for dataset_5 on dataset_8 in round 0: MAE=15.085956109197516, RMSE=19.359035760739754, R²=0.8048327579034404
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_5 on dataset_9 in round 0: MAE=17.25239203338623, RMSE=21.66073229518955, R²=0.7591707309895218
# 21/21 [==============================] - 0s 6ms/step
# Evaluation results for dataset_5 on dataset_10 in round 0: MAE=16.690494697018448, RMSE=21.314215604420824, R²=0.7485342693617475
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_5 on itself in round 0: MAE=17.396451653027142, RMSE=21.992681114497127, R²=0.7513528836422957
# Epoch 1/10
# 42/42 [==============================] - 4s 35ms/step - loss: 6174.2183 - MAE: 66.2032 - lr: 0.0010
# Epoch 2/10
# 42/42 [==============================] - 1s 35ms/step - loss: 1527.3423 - MAE: 30.2771 - lr: 0.0010
# Epoch 3/10
# 42/42 [==============================] - 2s 36ms/step - loss: 788.8204 - MAE: 22.3031 - lr: 0.0010
# Epoch 4/10
# 42/42 [==============================] - 1s 35ms/step - loss: 707.0074 - MAE: 20.8127 - lr: 0.0010
# Epoch 5/10
# 42/42 [==============================] - 1s 36ms/step - loss: 701.7117 - MAE: 20.9321 - lr: 0.0010
# Epoch 6/10
# 42/42 [==============================] - 2s 36ms/step - loss: 637.5439 - MAE: 19.7585 - lr: 1.0000e-04
# Epoch 7/10
# 42/42 [==============================] - 2s 36ms/step - loss: 672.7671 - MAE: 20.4022 - lr: 1.0000e-04
# Epoch 8/10
# 42/42 [==============================] - 2s 37ms/step - loss: 644.4454 - MAE: 19.9618 - lr: 1.0000e-04
# Epoch 9/10
# 42/42 [==============================] - 1s 36ms/step - loss: 608.6776 - MAE: 19.4186 - lr: 1.0000e-04
# Epoch 10/10
# 42/42 [==============================] - 2s 36ms/step - loss: 636.2231 - MAE: 19.8514 - lr: 1.0000e-04
# 21/21 [==============================] - 0s 6ms/step
# Evaluation results for dataset_6 on dataset_1 in round 0: MAE=21.100432042505986, RMSE=26.427125340969045, R²=0.6179832219593901
# 18/18 [==============================] - 0s 6ms/step
# Evaluation results for dataset_6 on dataset_2 in round 0: MAE=14.134691388410088, RMSE=18.346306533958185, R²=0.8216018638304072
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_6 on dataset_3 in round 0: MAE=20.045637358722654, RMSE=26.93098178465223, R²=0.617949224660479
# 21/21 [==============================] - 0s 6ms/step
# Evaluation results for dataset_6 on dataset_4 in round 0: MAE=25.587364548019, RMSE=31.839717315075767, R²=0.4272312492580339
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_6 on dataset_5 in round 0: MAE=21.21086844694419, RMSE=27.75422475139679, R²=0.6040090375472541
# 18/18 [==============================] - 0s 6ms/step
# Evaluation results for dataset_6 on dataset_6 in round 0: MAE=15.620491483955519, RMSE=20.324510379331304, R²=0.7840659619460373
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_6 on dataset_7 in round 0: MAE=19.956103969086264, RMSE=27.85611343692223, R²=0.6104945893621532
# 19/19 [==============================] - 0s 6ms/step
# Evaluation results for dataset_6 on dataset_8 in round 0: MAE=17.353818524824945, RMSE=22.393156933562192, R²=0.7388619670643275
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_6 on dataset_9 in round 0: MAE=19.94113297958374, RMSE=25.439858503213785, R²=0.6678055438466978
# 21/21 [==============================] - 0s 6ms/step
# Evaluation results for dataset_6 on dataset_10 in round 0: MAE=20.640176910440665, RMSE=26.592599029536597, R²=0.608563184411685
# 18/18 [==============================] - 0s 6ms/step
# Evaluation results for dataset_6 on itself in round 0: MAE=15.620491483955519, RMSE=20.324510379331304, R²=0.7840659619460373
# Epoch 1/10
# 45/45 [==============================] - 4s 35ms/step - loss: 8099.3345 - MAE: 78.7802 - lr: 0.0010
# Epoch 2/10
# 45/45 [==============================] - 2s 35ms/step - loss: 7969.2163 - MAE: 77.8660 - lr: 0.0010
# Epoch 3/10
# 45/45 [==============================] - 2s 35ms/step - loss: 1927.6113 - MAE: 35.7570 - lr: 0.0010
# Epoch 4/10
# 45/45 [==============================] - 2s 36ms/step - loss: 935.9604 - MAE: 24.5150 - lr: 0.0010
# Epoch 5/10
# 45/45 [==============================] - 2s 36ms/step - loss: 865.6037 - MAE: 23.2687 - lr: 0.0010
# Epoch 6/10
# 45/45 [==============================] - 2s 36ms/step - loss: 764.9966 - MAE: 22.3062 - lr: 1.0000e-04
# Epoch 7/10
# 45/45 [==============================] - 2s 36ms/step - loss: 757.5056 - MAE: 21.7533 - lr: 1.0000e-04
# Epoch 8/10
# 45/45 [==============================] - 2s 35ms/step - loss: 735.8529 - MAE: 21.4467 - lr: 1.0000e-04
# Epoch 9/10
# 45/45 [==============================] - 2s 36ms/step - loss: 753.0114 - MAE: 21.5457 - lr: 1.0000e-04
# Epoch 10/10
# 45/45 [==============================] - 2s 35ms/step - loss: 738.9706 - MAE: 21.5151 - lr: 1.0000e-04
# 21/21 [==============================] - 0s 6ms/step
# Evaluation results for dataset_7 on dataset_1 in round 0: MAE=16.36157408388614, RMSE=20.8104172552065, R²=0.7631113982933045
# 18/18 [==============================] - 0s 6ms/step
# Evaluation results for dataset_7 on dataset_2 in round 0: MAE=13.105294885451011, RMSE=16.784408886475447, R²=0.8506844207370868
# 20/20 [==============================] - 0s 7ms/step
# Evaluation results for dataset_7 on dataset_3 in round 0: MAE=18.204313819953263, RMSE=23.223935183921874, R²=0.7158888130224295
# 21/21 [==============================] - 0s 6ms/step
# Evaluation results for dataset_7 on dataset_4 in round 0: MAE=18.709847845491907, RMSE=23.580098788103772, R²=0.6858535549224989
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_7 on dataset_5 in round 0: MAE=17.472943876610426, RMSE=21.970218370873535, R²=0.751860547447477
# 18/18 [==============================] - 0s 6ms/step
# Evaluation results for dataset_7 on dataset_6 in round 0: MAE=16.548168147286624, RMSE=21.25709806262024, R²=0.7637951155895435
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_7 on dataset_7 in round 0: MAE=18.167418435264487, RMSE=23.786907568010577, R²=0.7159803289116793
# 19/19 [==============================] - 0s 6ms/step
# Evaluation results for dataset_7 on dataset_8 in round 0: MAE=15.165881192997881, RMSE=19.384273568068227, R²=0.8043235585828201
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_7 on dataset_9 in round 0: MAE=17.32049097290039, RMSE=21.667184659312387, R²=0.7590272317248786
# 21/21 [==============================] - 0s 6ms/step
# Evaluation results for dataset_7 on dataset_10 in round 0: MAE=16.867137796738568, RMSE=21.37965082443213, R²=0.7469878860533695
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_7 on itself in round 0: MAE=18.167418435264487, RMSE=23.786907568010577, R²=0.7159803289116793
# Epoch 1/10
# 45/45 [==============================] - 4s 35ms/step - loss: 8882.1465 - MAE: 82.7875 - lr: 0.0010
# Epoch 2/10
# 45/45 [==============================] - 2s 35ms/step - loss: 7711.6709 - MAE: 76.0783 - lr: 0.0010
# Epoch 3/10
# 45/45 [==============================] - 2s 35ms/step - loss: 2663.1436 - MAE: 40.6221 - lr: 0.0010
# Epoch 4/10
# 45/45 [==============================] - 2s 35ms/step - loss: 811.3452 - MAE: 22.9453 - lr: 0.0010
# Epoch 5/10
# 45/45 [==============================] - 2s 35ms/step - loss: 654.9644 - MAE: 19.9635 - lr: 0.0010
# Epoch 6/10
# 45/45 [==============================] - 2s 36ms/step - loss: 588.4572 - MAE: 19.2196 - lr: 1.0000e-04
# Epoch 7/10
# 45/45 [==============================] - 2s 35ms/step - loss: 606.8445 - MAE: 19.2439 - lr: 1.0000e-04
# Epoch 8/10
# 45/45 [==============================] - 2s 35ms/step - loss: 603.1152 - MAE: 19.2751 - lr: 1.0000e-04
# Epoch 9/10
# 45/45 [==============================] - 2s 36ms/step - loss: 614.5071 - MAE: 19.6057 - lr: 1.0000e-04
# Epoch 10/10
# 45/45 [==============================] - 2s 35ms/step - loss: 612.7537 - MAE: 19.2766 - lr: 1.0000e-04
# 21/21 [==============================] - 0s 6ms/step
# Evaluation results for dataset_8 on dataset_1 in round 0: MAE=17.51123703712709, RMSE=22.3267958051643, R²=0.7273312361528768
# 18/18 [==============================] - 0s 6ms/step
# Evaluation results for dataset_8 on dataset_2 in round 0: MAE=12.640677114362667, RMSE=16.52881882038802, R²=0.8551972999037184
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_8 on dataset_3 in round 0: MAE=18.297418864851448, RMSE=23.931816122894066, R²=0.6983050589934487
# 21/21 [==============================] - 0s 7ms/step
# Evaluation results for dataset_8 on dataset_4 in round 0: MAE=21.014297816725005, RMSE=26.452484533793488, R²=0.6046571876646403
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_8 on dataset_5 in round 0: MAE=18.749830600081896, RMSE=24.178944522712026, R²=0.6994603680708616
# 18/18 [==============================] - 0s 6ms/step
# Evaluation results for dataset_8 on dataset_6 in round 0: MAE=16.193852112225606, RMSE=20.835197301845312, R²=0.7730782329222563
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_8 on dataset_7 in round 0: MAE=18.569859382966442, RMSE=25.519870697454728, R²=0.6730891089278537
# 19/19 [==============================] - 0s 6ms/step
# Evaluation results for dataset_8 on dataset_8 in round 0: MAE=15.40090384412753, RMSE=19.728458751230825, R²=0.7973130454499724
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_8 on dataset_9 in round 0: MAE=18.038908641433714, RMSE=22.67619484129589, R²=0.7360611273189779
# 21/21 [==============================] - 0s 6ms/step
# Evaluation results for dataset_8 on dataset_10 in round 0: MAE=18.163141772038617, RMSE=23.3612584621976, R²=0.6979126301442043
# 19/19 [==============================] - 0s 6ms/step
# Evaluation results for dataset_8 on itself in round 0: MAE=15.40090384412753, RMSE=19.728458751230825, R²=0.7973130454499724
# Epoch 1/10
# 46/46 [==============================] - 5s 36ms/step - loss: 7703.4717 - MAE: 76.3187 - lr: 0.0010
# Epoch 2/10
# 46/46 [==============================] - 2s 36ms/step - loss: 2195.3010 - MAE: 37.1814 - lr: 0.0010
# Epoch 3/10
# 46/46 [==============================] - 2s 36ms/step - loss: 865.6656 - MAE: 23.5605 - lr: 0.0010
# Epoch 4/10
# 46/46 [==============================] - 2s 36ms/step - loss: 713.1520 - MAE: 21.0645 - lr: 0.0010
# Epoch 5/10
# 46/46 [==============================] - 2s 35ms/step - loss: 665.2292 - MAE: 20.3879 - lr: 0.0010
# Epoch 6/10
# 46/46 [==============================] - 2s 36ms/step - loss: 613.4305 - MAE: 19.5742 - lr: 1.0000e-04
# Epoch 7/10
# 46/46 [==============================] - 2s 36ms/step - loss: 628.3647 - MAE: 19.6946 - lr: 1.0000e-04
# Epoch 8/10
# 46/46 [==============================] - 2s 35ms/step - loss: 643.4978 - MAE: 20.0111 - lr: 1.0000e-04
# Epoch 9/10
# 46/46 [==============================] - 2s 35ms/step - loss: 643.7333 - MAE: 19.8455 - lr: 1.0000e-04
# Epoch 10/10
# 46/46 [==============================] - 2s 35ms/step - loss: 652.6602 - MAE: 20.0127 - lr: 1.0000e-04
# 21/21 [==============================] - 0s 6ms/step
# Evaluation results for dataset_9 on dataset_1 in round 0: MAE=17.093623208780567, RMSE=21.408938782522707, R²=0.7492893002664488
# 18/18 [==============================] - 0s 7ms/step
# Evaluation results for dataset_9 on dataset_2 in round 0: MAE=12.94681908418089, RMSE=16.561422186901176, R²=0.8546254850953605
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_9 on dataset_3 in round 0: MAE=18.212010691192972, RMSE=23.256534958971287, R²=0.7150906312082355
# 21/21 [==============================] - 0s 7ms/step
# Evaluation results for dataset_9 on dataset_4 in round 0: MAE=20.023098741258895, RMSE=24.809520990326956, R²=0.6522415691874613
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_9 on dataset_5 in round 0: MAE=18.156845167816662, RMSE=22.892340941937245, R²=0.7305938638066876
# 18/18 [==============================] - 0s 6ms/step
# Evaluation results for dataset_9 on dataset_6 in round 0: MAE=16.35612754513186, RMSE=20.79598905557367, R²=0.773931484551923
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_9 on dataset_7 in round 0: MAE=18.55170371128604, RMSE=24.54306665772196, R²=0.6976359847000888
# 19/19 [==============================] - 0s 6ms/step
# Evaluation results for dataset_9 on dataset_8 in round 0: MAE=15.204354227373475, RMSE=19.338564409803336, R²=0.8052453016586868
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_9 on dataset_9 in round 0: MAE=17.716876242065428, RMSE=21.955331540678298, R²=0.752575331632736
# 21/21 [==============================] - 0s 6ms/step
# Evaluation results for dataset_9 on dataset_10 in round 0: MAE=17.50936652020991, RMSE=22.13819173261709, R²=0.7287158702073409
# 20/20 [==============================] - 0s 7ms/step
# Evaluation results for dataset_9 on itself in round 0: MAE=17.716876242065428, RMSE=21.955331540678298, R²=0.752575331632736
# Epoch 1/10
# 49/49 [==============================] - 4s 35ms/step - loss: 8532.3506 - MAE: 80.3735 - lr: 0.0010
# Epoch 2/10
# 49/49 [==============================] - 2s 36ms/step - loss: 1753.0880 - MAE: 33.4194 - lr: 0.0010
# Epoch 3/10
# 49/49 [==============================] - 2s 35ms/step - loss: 789.2729 - MAE: 22.6093 - lr: 0.0010
# Epoch 4/10
# 49/49 [==============================] - 2s 35ms/step - loss: 773.3286 - MAE: 21.9925 - lr: 0.0010
# Epoch 5/10
# 49/49 [==============================] - 2s 35ms/step - loss: 761.7492 - MAE: 21.8992 - lr: 0.0010
# Epoch 6/10
# 49/49 [==============================] - 2s 35ms/step - loss: 710.7610 - MAE: 21.1765 - lr: 1.0000e-04
# Epoch 7/10
# 49/49 [==============================] - 2s 35ms/step - loss: 683.2512 - MAE: 20.8079 - lr: 1.0000e-04
# Epoch 8/10
# 49/49 [==============================] - 2s 36ms/step - loss: 661.3280 - MAE: 20.3686 - lr: 1.0000e-04
# Epoch 9/10
# 49/49 [==============================] - 2s 36ms/step - loss: 669.5484 - MAE: 20.3752 - lr: 1.0000e-04
# Epoch 10/10
# 49/49 [==============================] - 2s 35ms/step - loss: 639.3749 - MAE: 20.0580 - lr: 1.0000e-04
# 21/21 [==============================] - 0s 6ms/step
# Evaluation results for dataset_10 on dataset_1 in round 0: MAE=16.722661202388373, RMSE=21.015886814313824, R²=0.758410513934281
# 18/18 [==============================] - 0s 6ms/step
# Evaluation results for dataset_10 on dataset_2 in round 0: MAE=13.397099491162962, RMSE=17.16779572923564, R²=0.8437852291424569
# 20/20 [==============================] - 0s 7ms/step
# Evaluation results for dataset_10 on dataset_3 in round 0: MAE=18.451983012874855, RMSE=23.390452617331093, R²=0.7118000079539866
# 21/21 [==============================] - 0s 6ms/step
# Evaluation results for dataset_10 on dataset_4 in round 0: MAE=18.989696023719652, RMSE=23.478348464857614, R²=0.6885588478660972
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_10 on dataset_5 in round 0: MAE=17.598956813186895, RMSE=22.09150238056067, R²=0.7491133360931118
# 18/18 [==============================] - 0s 6ms/step
# Evaluation results for dataset_10 on dataset_6 in round 0: MAE=16.468370936229718, RMSE=21.02543664619531, R²=0.7689154183746718
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_10 on dataset_7 in round 0: MAE=18.38237577676773, RMSE=23.88364785414024, R²=0.7136654406655354
# 19/19 [==============================] - 0s 6ms/step
# Evaluation results for dataset_10 on dataset_8 in round 0: MAE=15.51379868858739, RMSE=19.724902088148752, R²=0.7973861200105652
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_10 on dataset_9 in round 0: MAE=17.645142784500123, RMSE=21.86730018652871, R²=0.7545554850299304
# 21/21 [==============================] - 0s 6ms/step
# Evaluation results for dataset_10 on dataset_10 in round 0: MAE=17.245844254126915, RMSE=21.492862564707238, R²=0.7443012396577695
# 21/21 [==============================] - 0s 7ms/step
# Evaluation results for dataset_10 on itself in round 0: MAE=17.245844254126915, RMSE=21.492862564707238, R²=0.7443012396577695
# 21/21 [==============================] - 0s 6ms/step
# Global evaluation results for dataset_1 in round 0: MAE=21.100432042505986, RMSE=26.427125340969045, R²=0.6179832219593901
# 18/18 [==============================] - 0s 6ms/step
# Global evaluation results for dataset_2 in round 0: MAE=14.134691388410088, RMSE=18.346306533958185, R²=0.8216018638304072
# 20/20 [==============================] - 0s 6ms/step
# Global evaluation results for dataset_3 in round 0: MAE=20.045637358722654, RMSE=26.93098178465223, R²=0.617949224660479
# 21/21 [==============================] - 0s 6ms/step
# Global evaluation results for dataset_4 in round 0: MAE=25.587364548019, RMSE=31.839717315075767, R²=0.4272312492580339
# 20/20 [==============================] - 0s 6ms/step
# Global evaluation results for dataset_5 in round 0: MAE=21.21086844694419, RMSE=27.75422475139679, R²=0.6040090375472541
# 18/18 [==============================] - 0s 6ms/step
# Global evaluation results for dataset_6 in round 0: MAE=15.620491483955519, RMSE=20.324510379331304, R²=0.7840659619460373
# 20/20 [==============================] - 0s 6ms/step
# Global evaluation results for dataset_7 in round 0: MAE=19.956103969086264, RMSE=27.85611343692223, R²=0.6104945893621532
# 19/19 [==============================] - 0s 6ms/step
# Global evaluation results for dataset_8 in round 0: MAE=17.353818524824945, RMSE=22.393156933562192, R²=0.7388619670643275
# 20/20 [==============================] - 0s 7ms/step
# Global evaluation results for dataset_9 in round 0: MAE=19.94113297958374, RMSE=25.439858503213785, R²=0.6678055438466978
# 21/21 [==============================] - 0s 6ms/step
# Global evaluation results for dataset_10 in round 0: MAE=20.640176910440665, RMSE=26.592599029536597, R²=0.608563184411685
# 4/4 [==============================] - 0s 6ms/step
# Global evaluation results on test dataset in round 0: MAE=16.33223988056183, RMSE=22.87820226249418, R²=0.6969011795890123
# Round 1
# Epoch 1/10
# 48/48 [==============================] - 4s 35ms/step - loss: 1125.7791 - MAE: 25.6148 - lr: 0.0010
# Epoch 2/10
# 48/48 [==============================] - 2s 36ms/step - loss: 617.8133 - MAE: 19.1934 - lr: 0.0010
# Epoch 3/10
# 48/48 [==============================] - 2s 35ms/step - loss: 588.7789 - MAE: 18.6686 - lr: 0.0010
# Epoch 4/10
# 48/48 [==============================] - 2s 35ms/step - loss: 610.8289 - MAE: 18.8612 - lr: 0.0010
# Epoch 5/10
# 48/48 [==============================] - 2s 36ms/step - loss: 575.9122 - MAE: 18.1795 - lr: 0.0010
# Epoch 6/10
# 48/48 [==============================] - 2s 35ms/step - loss: 579.2168 - MAE: 18.2643 - lr: 1.0000e-04
# Epoch 7/10
# 48/48 [==============================] - 2s 36ms/step - loss: 552.3929 - MAE: 17.7753 - lr: 1.0000e-04
# Epoch 8/10
# 48/48 [==============================] - 2s 36ms/step - loss: 533.9132 - MAE: 17.6323 - lr: 1.0000e-04
# Epoch 9/10
# 48/48 [==============================] - 2s 35ms/step - loss: 517.7723 - MAE: 17.2562 - lr: 1.0000e-04
# Epoch 10/10
# 48/48 [==============================] - 2s 36ms/step - loss: 514.0684 - MAE: 17.0776 - lr: 1.0000e-04
# 21/21 [==============================] - 0s 6ms/step
# Evaluation results for dataset_1 on dataset_1 in round 1: MAE=14.9554350702905, RMSE=19.198247951911185, R²=0.7983929192094457
# 18/18 [==============================] - 0s 7ms/step
# Evaluation results for dataset_1 on dataset_2 in round 1: MAE=12.933283509185737, RMSE=16.66676235660751, R²=0.85277027264934
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_1 on dataset_3 in round 1: MAE=16.776849146600288, RMSE=21.624616613943854, R²=0.7536721330532561
# 21/21 [==============================] - 0s 6ms/step
# Evaluation results for dataset_1 on dataset_4 in round 1: MAE=17.563296480193024, RMSE=22.459924357422228, R²=0.7149917131660216
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_1 on dataset_5 in round 1: MAE=16.632938018001493, RMSE=21.74316537937656, R²=0.7569628795927876
# 18/18 [==============================] - 0s 6ms/step
# Evaluation results for dataset_1 on dataset_6 in round 1: MAE=15.953365680173778, RMSE=20.955500733492734, R²=0.7704501530325283
# 20/20 [==============================] - 0s 7ms/step
# Evaluation results for dataset_1 on dataset_7 in round 1: MAE=17.719574924594806, RMSE=24.328184528287156, R²=0.702907387551301
# 19/19 [==============================] - 0s 6ms/step
# Evaluation results for dataset_1 on dataset_8 in round 1: MAE=14.37437163646284, RMSE=18.463208606369843, R²=0.8224773246903916
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_1 on dataset_9 in round 1: MAE=16.43939238052368, RMSE=20.70834043350812, R²=0.7798829978280225
# 21/21 [==============================] - 0s 6ms/step
# Evaluation results for dataset_1 on dataset_10 in round 1: MAE=16.773263485363348, RMSE=21.671656508688333, R²=0.7400293521259336
# 21/21 [==============================] - 0s 6ms/step
# Evaluation results for dataset_1 on itself in round 1: MAE=14.9554350702905, RMSE=19.198247951911185, R²=0.7983929192094457
# Epoch 1/10
# 42/42 [==============================] - 4s 35ms/step - loss: 1868.0829 - MAE: 33.1634 - lr: 0.0010
# Epoch 2/10
# 42/42 [==============================] - 1s 35ms/step - loss: 522.7901 - MAE: 17.6796 - lr: 0.0010
# Epoch 3/10
# 42/42 [==============================] - 1s 36ms/step - loss: 510.9047 - MAE: 17.4237 - lr: 0.0010
# Epoch 4/10
# 42/42 [==============================] - 1s 35ms/step - loss: 496.3234 - MAE: 17.3784 - lr: 0.0010
# Epoch 5/10
# 42/42 [==============================] - 2s 36ms/step - loss: 468.8658 - MAE: 17.0178 - lr: 0.0010
# Epoch 6/10
# 42/42 [==============================] - 1s 35ms/step - loss: 406.2719 - MAE: 15.6162 - lr: 1.0000e-04
# Epoch 7/10
# 42/42 [==============================] - 1s 36ms/step - loss: 435.3263 - MAE: 16.2212 - lr: 1.0000e-04
# Epoch 8/10
# 42/42 [==============================] - 2s 36ms/step - loss: 436.2372 - MAE: 16.0031 - lr: 1.0000e-04
# Epoch 9/10
# 42/42 [==============================] - 1s 35ms/step - loss: 421.5773 - MAE: 15.7840 - lr: 1.0000e-04
# Epoch 10/10
# 42/42 [==============================] - 1s 35ms/step - loss: 449.9641 - MAE: 16.3492 - lr: 1.0000e-04
# 21/21 [==============================] - 0s 6ms/step
# Evaluation results for dataset_2 on dataset_1 in round 1: MAE=15.628512574556593, RMSE=21.395648031010165, R²=0.7496004879759242
# 18/18 [==============================] - 0s 6ms/step
# Evaluation results for dataset_2 on dataset_2 in round 1: MAE=10.741957850950673, RMSE=14.639288849587697, R²=0.8864118616676757
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_2 on dataset_3 in round 1: MAE=16.744013744583008, RMSE=23.453128665894997, R²=0.7102534421197367
# 21/21 [==============================] - 0s 6ms/step
# Evaluation results for dataset_2 on dataset_4 in round 1: MAE=19.338924536038014, RMSE=26.131213523617443, R²=0.6142019160339217
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_2 on dataset_5 in round 1: MAE=16.63357033807723, RMSE=23.057162565983724, R²=0.726700526020044
# 18/18 [==============================] - 0s 7ms/step
# Evaluation results for dataset_2 on dataset_6 in round 1: MAE=14.523807732771475, RMSE=20.102316633610677, R²=0.7887614680388978
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_2 on dataset_7 in round 1: MAE=16.88145115204665, RMSE=24.682641742337577, R²=0.6941871504347776
# 19/19 [==============================] - 0s 6ms/step
# Evaluation results for dataset_2 on dataset_8 in round 1: MAE=13.410574203259067, RMSE=18.379532396858256, R²=0.8240827622262783
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_2 on dataset_9 in round 1: MAE=16.12463604621887, RMSE=21.71424338950089, R²=0.7579793625957463
# 21/21 [==============================] - 0s 6ms/step
# Evaluation results for dataset_2 on dataset_10 in round 1: MAE=16.401806904719425, RMSE=22.55270215169009, R²=0.7184618400127916
# 18/18 [==============================] - 0s 7ms/step
# Evaluation results for dataset_2 on itself in round 1: MAE=10.741957850950673, RMSE=14.639288849587697, R²=0.8864118616676757
# Epoch 1/10
# 45/45 [==============================] - 5s 36ms/step - loss: 1407.8396 - MAE: 29.1218 - lr: 0.0010
# Epoch 2/10
# 45/45 [==============================] - 2s 35ms/step - loss: 665.0858 - MAE: 20.5091 - lr: 0.0010
# Epoch 3/10
# 45/45 [==============================] - 2s 36ms/step - loss: 668.0056 - MAE: 20.4154 - lr: 0.0010
# Epoch 4/10
# 45/45 [==============================] - 2s 36ms/step - loss: 641.8521 - MAE: 19.8084 - lr: 0.0010
# Epoch 5/10
# 45/45 [==============================] - 2s 36ms/step - loss: 662.3594 - MAE: 20.4116 - lr: 0.0010
# Epoch 6/10
# 45/45 [==============================] - 2s 35ms/step - loss: 612.7155 - MAE: 19.5664 - lr: 1.0000e-04
# Epoch 7/10
# 45/45 [==============================] - 2s 35ms/step - loss: 569.4039 - MAE: 18.6884 - lr: 1.0000e-04
# Epoch 8/10
# 45/45 [==============================] - 2s 36ms/step - loss: 609.4836 - MAE: 19.3713 - lr: 1.0000e-04
# Epoch 9/10
# 45/45 [==============================] - 2s 36ms/step - loss: 612.5919 - MAE: 19.5041 - lr: 1.0000e-04
# Epoch 10/10
# 45/45 [==============================] - 2s 35ms/step - loss: 591.6683 - MAE: 18.9641 - lr: 1.0000e-04
# 21/21 [==============================] - 0s 6ms/step
# Evaluation results for dataset_3 on dataset_1 in round 1: MAE=14.756436292099187, RMSE=19.17813211688654, R²=0.7988151837955517
# 18/18 [==============================] - 0s 6ms/step
# Evaluation results for dataset_3 on dataset_2 in round 1: MAE=12.810088190336847, RMSE=16.81176669674987, R²=0.8501972690651124
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_3 on dataset_3 in round 1: MAE=16.566311201361437, RMSE=21.623725301300915, R²=0.7536924386726601
# 21/21 [==============================] - 0s 6ms/step
# Evaluation results for dataset_3 on dataset_4 in round 1: MAE=17.52155067026615, RMSE=22.381298514948416, R²=0.7169836871810567
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_3 on dataset_5 in round 1: MAE=16.78559761008278, RMSE=21.902759827492954, R²=0.7533820095817766
# 18/18 [==============================] - 0s 6ms/step
# Evaluation results for dataset_3 on dataset_6 in round 1: MAE=16.06541427991069, RMSE=21.428778545702386, R²=0.7599643458046582
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_3 on dataset_7 in round 1: MAE=17.750370678470656, RMSE=24.34858296555884, R²=0.7024089725817535
# 19/19 [==============================] - 0s 6ms/step
# Evaluation results for dataset_3 on dataset_8 in round 1: MAE=14.14521594698492, RMSE=18.52668486282755, R²=0.8212545853999221
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_3 on dataset_9 in round 1: MAE=16.343282053375244, RMSE=20.85227945069879, R²=0.7768123956962455
# 21/21 [==============================] - 0s 6ms/step
# Evaluation results for dataset_3 on dataset_10 in round 1: MAE=16.43144856534932, RMSE=21.65499502944807, R²=0.740428936762489
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_3 on itself in round 1: MAE=16.566311201361437, RMSE=21.623725301300915, R²=0.7536924386726601
# Epoch 1/10
# 49/49 [==============================] - 4s 36ms/step - loss: 1172.1503 - MAE: 26.7162 - lr: 0.0010
# Epoch 2/10
# 49/49 [==============================] - 2s 35ms/step - loss: 624.2230 - MAE: 19.8210 - lr: 0.0010
# Epoch 3/10
# 49/49 [==============================] - 2s 35ms/step - loss: 631.7142 - MAE: 19.7986 - lr: 0.0010
# Epoch 4/10
# 49/49 [==============================] - 2s 35ms/step - loss: 589.1328 - MAE: 19.1142 - lr: 0.0010
# Epoch 5/10
# 49/49 [==============================] - 2s 36ms/step - loss: 585.7678 - MAE: 18.7590 - lr: 0.0010
# Epoch 6/10
# 49/49 [==============================] - 2s 36ms/step - loss: 501.8601 - MAE: 17.4667 - lr: 1.0000e-04
# Epoch 7/10
# 49/49 [==============================] - 2s 36ms/step - loss: 451.5964 - MAE: 16.2196 - lr: 1.0000e-04
# Epoch 8/10
# 49/49 [==============================] - 2s 35ms/step - loss: 465.3574 - MAE: 16.6663 - lr: 1.0000e-04
# Epoch 9/10
# 49/49 [==============================] - 2s 36ms/step - loss: 487.6284 - MAE: 16.9907 - lr: 1.0000e-04
# Epoch 10/10
# 49/49 [==============================] - 2s 36ms/step - loss: 479.1007 - MAE: 16.7768 - lr: 1.0000e-04
# 21/21 [==============================] - 0s 6ms/step
# Evaluation results for dataset_4 on dataset_1 in round 1: MAE=14.081252275528257, RMSE=19.18103190341319, R²=0.7987543397966516
# 18/18 [==============================] - 0s 6ms/step
# Evaluation results for dataset_4 on dataset_2 in round 1: MAE=14.874184661255152, RMSE=20.089534875265734, R²=0.7860891638381574
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_4 on dataset_3 in round 1: MAE=18.365111044199, RMSE=24.0784665331893, R²=0.69459625178578
# 21/21 [==============================] - 0s 6ms/step
# Evaluation results for dataset_4 on dataset_4 in round 1: MAE=13.196364063592185, RMSE=17.485117639602162, R²=0.8272659219785404
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_4 on dataset_5 in round 1: MAE=15.283414659343782, RMSE=20.64036908666801, R²=0.7809909856844481
# 18/18 [==============================] - 0s 6ms/step
# Evaluation results for dataset_4 on dataset_6 in round 1: MAE=17.418670993324714, RMSE=24.12131614395449, R²=0.6958534297261634
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_4 on dataset_7 in round 1: MAE=17.199265657884677, RMSE=23.186974041457, R²=0.7301262760780194
# 19/19 [==============================] - 0s 6ms/step
# Evaluation results for dataset_4 on dataset_8 in round 1: MAE=16.132254655423917, RMSE=21.679581820170174, R²=0.7552395276746892
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_4 on dataset_9 in round 1: MAE=16.151520207977295, RMSE=21.770152678371996, R²=0.7567314608028383
# 21/21 [==============================] - 0s 6ms/step
# Evaluation results for dataset_4 on dataset_10 in round 1: MAE=15.409788803457316, RMSE=20.83866459905503, R²=0.7596302185090037
# 21/21 [==============================] - 0s 6ms/step
# Evaluation results for dataset_4 on itself in round 1: MAE=13.196364063592185, RMSE=17.485117639602162, R²=0.8272659219785404
# Epoch 1/10
# 45/45 [==============================] - 4s 35ms/step - loss: 1172.4264 - MAE: 26.9442 - lr: 0.0010
# Epoch 2/10
# 45/45 [==============================] - 2s 36ms/step - loss: 749.1083 - MAE: 21.4422 - lr: 0.0010
# Epoch 3/10
# 45/45 [==============================] - 2s 36ms/step - loss: 667.0886 - MAE: 20.3359 - lr: 0.0010
# Epoch 4/10
# 45/45 [==============================] - 2s 36ms/step - loss: 618.6273 - MAE: 19.5235 - lr: 0.0010
# Epoch 5/10
# 45/45 [==============================] - 2s 36ms/step - loss: 548.5469 - MAE: 18.1703 - lr: 0.0010
# Epoch 6/10
# 45/45 [==============================] - 2s 36ms/step - loss: 483.1326 - MAE: 17.1357 - lr: 1.0000e-04
# Epoch 7/10
# 45/45 [==============================] - 2s 36ms/step - loss: 497.7660 - MAE: 17.0758 - lr: 1.0000e-04
# Epoch 8/10
# 45/45 [==============================] - 2s 36ms/step - loss: 504.3291 - MAE: 17.5794 - lr: 1.0000e-04
# Epoch 9/10
# 45/45 [==============================] - 2s 36ms/step - loss: 490.5898 - MAE: 17.0729 - lr: 1.0000e-04
# Epoch 10/10
# 45/45 [==============================] - 2s 36ms/step - loss: 531.6841 - MAE: 17.7317 - lr: 1.0000e-04
# 21/21 [==============================] - 0s 6ms/step
# Evaluation results for dataset_5 on dataset_1 in round 1: MAE=14.014459987511861, RMSE=19.132562200414213, R²=0.799770134258947
# 18/18 [==============================] - 0s 6ms/step
# Evaluation results for dataset_5 on dataset_2 in round 1: MAE=12.87024431362722, RMSE=17.449479115082646, R²=0.8386169360999549
# 20/20 [==============================] - 0s 6ms/step
# ...
# 21/21 [==============================] - 0s 7ms/step
# Evaluation results for dataset_6 on dataset_4 in round 19: MAE=19.233968523996218, RMSE=26.14916109736042, R²=0.613671782414823
# 20/20 [==============================] - 0s 7ms/step
# Evaluation results for dataset_6 on dataset_5 in round 19: MAE=14.384972396444102, RMSE=20.591556699355408, R²=0.7820256292012147
# 18/18 [==============================] - 0s 7ms/step
# Evaluation results for dataset_6 on dataset_6 in round 19: MAE=11.557539126129015, RMSE=16.9683958004485, R²=0.849490991868711
# 20/20 [==============================] - 0s 7ms/step
# Evaluation results for dataset_6 on dataset_7 in round 19: MAE=15.421825221384776, RMSE=22.15136046258296, R²=0.7536949826099613
# 19/19 [==============================] - 0s 7ms/step
# Evaluation results for dataset_6 on dataset_8 in round 19: MAE=12.256594905727788, RMSE=16.849433859077894, R²=0.8521538201759336
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_6 on dataset_9 in round 19: MAE=14.552064650726319, RMSE=20.527861185519818, R²=0.7837030467487551
# 21/21 [==============================] - 0s 7ms/step
# Evaluation results for dataset_6 on dataset_10 in round 19: MAE=15.699970028159486, RMSE=21.830455941093618, R²=0.736205514944699
# 18/18 [==============================] - 0s 6ms/step
# Evaluation results for dataset_6 on itself in round 19: MAE=11.557539126129015, RMSE=16.9683958004485, R²=0.849490991868711
# Epoch 1/10
# 45/45 [==============================] - 5s 39ms/step - loss: 542.3155 - MAE: 17.9326 - lr: 0.0010
# Epoch 2/10
# 45/45 [==============================] - 2s 36ms/step - loss: 488.3890 - MAE: 16.9023 - lr: 0.0010
# Epoch 3/10
# 45/45 [==============================] - 2s 37ms/step - loss: 439.1573 - MAE: 15.7418 - lr: 0.0010
# Epoch 4/10
# 45/45 [==============================] - 2s 36ms/step - loss: 440.1158 - MAE: 15.8431 - lr: 0.0010
# Epoch 5/10
# 45/45 [==============================] - 2s 36ms/step - loss: 435.8948 - MAE: 15.6162 - lr: 0.0010
# Epoch 6/10
# 45/45 [==============================] - 2s 36ms/step - loss: 407.5239 - MAE: 15.1577 - lr: 1.0000e-04
# Epoch 7/10
# 45/45 [==============================] - 2s 36ms/step - loss: 416.3263 - MAE: 15.3155 - lr: 1.0000e-04
# Epoch 8/10
# 45/45 [==============================] - 2s 36ms/step - loss: 403.0610 - MAE: 15.0175 - lr: 1.0000e-04
# Epoch 9/10
# 45/45 [==============================] - 2s 36ms/step - loss: 392.8498 - MAE: 15.0221 - lr: 1.0000e-04
# Epoch 10/10
# 45/45 [==============================] - 2s 36ms/step - loss: 407.6831 - MAE: 15.1994 - lr: 1.0000e-04
# 21/21 [==============================] - 0s 6ms/step
# Evaluation results for dataset_7 on dataset_1 in round 19: MAE=13.606855550184731, RMSE=19.523516701096725, R²=0.7915035403350161
# 18/18 [==============================] - 0s 6ms/step
# Evaluation results for dataset_7 on dataset_2 in round 19: MAE=11.112655194656291, RMSE=15.500831773999487, R²=0.8726488040558402
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_7 on dataset_3 in round 19: MAE=15.830088361928683, RMSE=22.58115781134023, R²=0.7313980725122604
# 21/21 [==============================] - 0s 6ms/step
# Evaluation results for dataset_7 on dataset_4 in round 19: MAE=15.240800462308384, RMSE=21.598977913187202, R²=0.7364231218588768
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_7 on dataset_5 in round 19: MAE=10.911289640332832, RMSE=15.682575933606303, R²=0.8735665843710605
# 18/18 [==============================] - 0s 6ms/step
# Evaluation results for dataset_7 on dataset_6 in round 19: MAE=12.468641031295695, RMSE=18.349858672368367, R²=0.8239863417148534
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_7 on dataset_7 in round 19: MAE=11.336944778889709, RMSE=16.51440797147105, R²=0.8631015696664536
# 19/19 [==============================] - 0s 6ms/step
# Evaluation results for dataset_7 on dataset_8 in round 19: MAE=12.188506841659546, RMSE=17.098098350078384, R²=0.8477577819214448
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_7 on dataset_9 in round 19: MAE=13.044931916809082, RMSE=18.827370488869853, R²=0.8180540741726627
# 21/21 [==============================] - 0s 6ms/step
# Evaluation results for dataset_7 on dataset_10 in round 19: MAE=13.18230802009548, RMSE=18.32394502776841, R²=0.8141433693307589
# 20/20 [==============================] - 0s 7ms/step
# Evaluation results for dataset_7 on itself in round 19: MAE=11.336944778889709, RMSE=16.51440797147105, R²=0.8631015696664536
# Epoch 1/10
# 45/45 [==============================] - 5s 36ms/step - loss: 312.9181 - MAE: 13.6794 - lr: 0.0010
# Epoch 2/10
# 45/45 [==============================] - 2s 40ms/step - loss: 309.2653 - MAE: 13.4824 - lr: 0.0010
# Epoch 3/10
# 45/45 [==============================] - 2s 38ms/step - loss: 291.6326 - MAE: 13.0904 - lr: 0.0010
# Epoch 4/10
# 45/45 [==============================] - 2s 36ms/step - loss: 316.8701 - MAE: 13.6446 - lr: 0.0010
# Epoch 5/10
# 45/45 [==============================] - 2s 36ms/step - loss: 282.1808 - MAE: 12.9177 - lr: 0.0010
# Epoch 6/10
# 45/45 [==============================] - 2s 36ms/step - loss: 284.1653 - MAE: 12.9905 - lr: 1.0000e-04
# Epoch 7/10
# 45/45 [==============================] - 2s 36ms/step - loss: 279.3580 - MAE: 12.8210 - lr: 1.0000e-04
# Epoch 8/10
# 45/45 [==============================] - 2s 36ms/step - loss: 276.7124 - MAE: 12.5092 - lr: 1.0000e-04
# Epoch 9/10
# 45/45 [==============================] - 2s 36ms/step - loss: 285.8755 - MAE: 12.9439 - lr: 1.0000e-04
# Epoch 10/10
# 45/45 [==============================] - 2s 36ms/step - loss: 291.5088 - MAE: 13.1348 - lr: 1.0000e-04
# 21/21 [==============================] - 0s 7ms/step
# Evaluation results for dataset_8 on dataset_1 in round 19: MAE=13.196291701169327, RMSE=19.538025545616414, R²=0.7911935381168346
# 18/18 [==============================] - 0s 6ms/step
# Evaluation results for dataset_8 on dataset_2 in round 19: MAE=10.000575505157766, RMSE=14.395806582731584, R²=0.8901588610021379
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_8 on dataset_3 in round 19: MAE=13.839020739884585, RMSE=20.131593610432034, R²=0.786512219190147
# 21/21 [==============================] - 0s 6ms/step
# Evaluation results for dataset_8 on dataset_4 in round 19: MAE=18.54105524293014, RMSE=27.13837616169467, R²=0.5838895478481196
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_8 on dataset_5 in round 19: MAE=14.371903492583604, RMSE=21.890500381986282, R²=0.7536580071005704
# 18/18 [==============================] - 0s 7ms/step
# Evaluation results for dataset_8 on dataset_6 in round 19: MAE=13.496900627799068, RMSE=20.180121602795772, R²=0.787123128143628
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_8 on dataset_7 in round 19: MAE=15.200178565439261, RMSE=23.74919310664251, R²=0.7168802489328785
# 19/19 [==============================] - 0s 7ms/step
# Evaluation results for dataset_8 on dataset_8 in round 19: MAE=9.346028185988727, RMSE=12.917141134968736, R²=0.9131095011485437
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_8 on dataset_9 in round 19: MAE=13.287712695693969, RMSE=20.19550716491138, R²=0.7906502119619669
# 21/21 [==============================] - 0s 6ms/step
# Evaluation results for dataset_8 on dataset_10 in round 19: MAE=14.643044506622475, RMSE=21.748373113904783, R²=0.7381855275838047
# 19/19 [==============================] - 0s 7ms/step
# Evaluation results for dataset_8 on itself in round 19: MAE=9.346028185988727, RMSE=12.917141134968736, R²=0.9131095011485437
# Epoch 1/10
# 46/46 [==============================] - 5s 36ms/step - loss: 490.3702 - MAE: 17.1301 - lr: 0.0010
# Epoch 2/10
# 46/46 [==============================] - 2s 36ms/step - loss: 439.1063 - MAE: 15.9414 - lr: 0.0010
# Epoch 3/10
# 46/46 [==============================] - 2s 36ms/step - loss: 423.5711 - MAE: 15.6182 - lr: 0.0010
# Epoch 4/10
# 46/46 [==============================] - 2s 36ms/step - loss: 424.6597 - MAE: 15.8152 - lr: 0.0010
# Epoch 5/10
# 46/46 [==============================] - 2s 36ms/step - loss: 449.7132 - MAE: 16.1679 - lr: 0.0010
# Epoch 6/10
# 46/46 [==============================] - 2s 36ms/step - loss: 384.7978 - MAE: 15.1102 - lr: 1.0000e-04
# Epoch 7/10
# 46/46 [==============================] - 2s 37ms/step - loss: 417.4343 - MAE: 15.5553 - lr: 1.0000e-04
# Epoch 8/10
# 46/46 [==============================] - 2s 36ms/step - loss: 393.5783 - MAE: 14.9873 - lr: 1.0000e-04
# Epoch 9/10
# 46/46 [==============================] - 2s 36ms/step - loss: 379.8398 - MAE: 14.7064 - lr: 1.0000e-04
# Epoch 10/10
# 46/46 [==============================] - 2s 36ms/step - loss: 402.2012 - MAE: 15.2724 - lr: 1.0000e-04
# 21/21 [==============================] - 0s 6ms/step
# Evaluation results for dataset_9 on dataset_1 in round 19: MAE=12.046617258197498, RMSE=17.327964774098692, R²=0.8357604671236619
# 18/18 [==============================] - 0s 6ms/step
# Evaluation results for dataset_9 on dataset_2 in round 19: MAE=10.496386445888525, RMSE=15.135445641413483, R²=0.8785818959622375
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_9 on dataset_3 in round 19: MAE=14.385793757786434, RMSE=20.274170439985266, R²=0.7834775665310096
# 21/21 [==============================] - 0s 7ms/step
# Evaluation results for dataset_9 on dataset_4 in round 19: MAE=15.385869452641124, RMSE=21.83572545816219, R²=0.7306132941546977
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_9 on dataset_5 in round 19: MAE=12.399949380999706, RMSE=17.93666398126587, R²=0.8346095544265102
# 18/18 [==============================] - 0s 7ms/step
# Evaluation results for dataset_9 on dataset_6 in round 19: MAE=12.920221986500083, RMSE=19.02371465261665, R²=0.8108215912339645
# 20/20 [==============================] - 0s 7ms/step
# Evaluation results for dataset_9 on dataset_7 in round 19: MAE=13.65548675534003, RMSE=20.59656869689695, R²=0.7870575729751627
# 19/19 [==============================] - 0s 6ms/step
# Evaluation results for dataset_9 on dataset_8 in round 19: MAE=10.537211658138977, RMSE=14.894676899468504, R²=0.8844681694526958
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_9 on dataset_9 in round 19: MAE=12.032926362609864, RMSE=17.438180777562195, R²=0.8439134977049868
# 21/21 [==============================] - 0s 6ms/step
# Evaluation results for dataset_9 on dataset_10 in round 19: MAE=13.07334100139267, RMSE=18.799759567559843, R²=0.8043658402477863
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_9 on itself in round 19: MAE=12.032926362609864, RMSE=17.438180777562195, R²=0.8439134977049868
# Epoch 1/10
# 49/49 [==============================] - 5s 36ms/step - loss: 508.2575 - MAE: 17.5244 - lr: 0.0010
# Epoch 2/10
# 49/49 [==============================] - 2s 36ms/step - loss: 475.7978 - MAE: 16.9669 - lr: 0.0010
# Epoch 3/10
# 49/49 [==============================] - 2s 36ms/step - loss: 466.0479 - MAE: 16.7286 - lr: 0.0010
# Epoch 4/10
# 49/49 [==============================] - 2s 36ms/step - loss: 451.7014 - MAE: 16.2412 - lr: 0.0010
# Epoch 5/10
# 49/49 [==============================] - 2s 37ms/step - loss: 433.5285 - MAE: 16.1006 - lr: 0.0010
# Epoch 6/10
# 49/49 [==============================] - 2s 36ms/step - loss: 428.9998 - MAE: 15.9612 - lr: 1.0000e-04
# Epoch 7/10
# 49/49 [==============================] - 2s 36ms/step - loss: 423.2956 - MAE: 15.7819 - lr: 1.0000e-04
# Epoch 8/10
# 49/49 [==============================] - 2s 36ms/step - loss: 431.3052 - MAE: 15.9723 - lr: 1.0000e-04
# Epoch 9/10
# 49/49 [==============================] - 2s 36ms/step - loss: 388.3127 - MAE: 15.0889 - lr: 1.0000e-04
# Epoch 10/10
# 49/49 [==============================] - 2s 37ms/step - loss: 432.2160 - MAE: 16.1924 - lr: 1.0000e-04
# 21/21 [==============================] - 0s 6ms/step
# Evaluation results for dataset_10 on dataset_1 in round 19: MAE=12.145902661780669, RMSE=18.498249980407238, R²=0.8128267089721372
# 18/18 [==============================] - 0s 6ms/step
# Evaluation results for dataset_10 on dataset_2 in round 19: MAE=11.483851559342316, RMSE=17.0592217021462, R²=0.8457548744428567
# 20/20 [==============================] - 0s 7ms/step
# Evaluation results for dataset_10 on dataset_3 in round 19: MAE=14.207916651977712, RMSE=21.19525043120934, R²=0.7633569153694651
# 21/21 [==============================] - 0s 6ms/step
# Evaluation results for dataset_10 on dataset_4 in round 19: MAE=14.943492916368303, RMSE=22.657081517185826, R²=0.709966045889684
# 20/20 [==============================] - 0s 7ms/step
# Evaluation results for dataset_10 on dataset_5 in round 19: MAE=10.936602602239516, RMSE=16.289085478068944, R²=0.8635980819826446
# 18/18 [==============================] - 0s 6ms/step
# Evaluation results for dataset_10 on dataset_6 in round 19: MAE=13.654900028878915, RMSE=20.552289043065404, R²=0.7791988554750182
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_10 on dataset_7 in round 19: MAE=11.894109366771064, RMSE=18.582793254721924, R²=0.8266617369211041
# 19/19 [==============================] - 0s 6ms/step
# Evaluation results for dataset_10 on dataset_8 in round 19: MAE=10.399809877339163, RMSE=15.078276335778297, R²=0.8816024058626684
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_10 on dataset_9 in round 19: MAE=11.613707872390748, RMSE=18.210883695381217, R²=0.8297743351648557
# 21/21 [==============================] - 0s 7ms/step
# Evaluation results for dataset_10 on dataset_10 in round 19: MAE=11.859975723119883, RMSE=17.33093929266356, R²=0.8337413302729906
# 21/21 [==============================] - 0s 6ms/step
# Evaluation results for dataset_10 on itself in round 19: MAE=11.859975723119883, RMSE=17.33093929266356, R²=0.8337413302729906
# 21/21 [==============================] - 0s 6ms/step
# Global evaluation results for dataset_1 in round 19: MAE=14.42098923299068, RMSE=21.27788988355113, R²=0.7523492187415263
# 18/18 [==============================] - 0s 7ms/step
# Global evaluation results for dataset_2 in round 19: MAE=8.42178779829994, RMSE=11.370614601277222, R²=0.9314731291437325
# 20/20 [==============================] - 0s 6ms/step
# Global evaluation results for dataset_3 in round 19: MAE=15.496458716678465, RMSE=22.56039517350716, R²=0.7318917868475995
# 21/21 [==============================] - 0s 7ms/step
# Global evaluation results for dataset_4 in round 19: MAE=19.441116745805456, RMSE=28.126229030267034, R²=0.553044869467189
# 20/20 [==============================] - 0s 6ms/step
# Global evaluation results for dataset_5 in round 19: MAE=15.540107616440194, RMSE=22.99010543364091, R²=0.728287887796121
# 18/18 [==============================] - 0s 6ms/step
# Global evaluation results for dataset_6 in round 19: MAE=12.935256603761768, RMSE=18.76456902076934, R²=0.8159405541301905
# 20/20 [==============================] - 0s 7ms/step
# Global evaluation results for dataset_7 in round 19: MAE=16.37824275711072, RMSE=24.371066734055074, R²=0.7018591207044802
# 19/19 [==============================] - 0s 6ms/step
# Global evaluation results for dataset_8 in round 19: MAE=10.990927742500054, RMSE=15.327740144741815, R²=0.877652319811218
# 20/20 [==============================] - 0s 7ms/step
# Global evaluation results for dataset_9 in round 19: MAE=15.491958968353272, RMSE=22.236972714272508, R²=0.746186730269017
# 21/21 [==============================] - 0s 6ms/step
# Global evaluation results for dataset_10 in round 19: MAE=16.232286075661086, RMSE=23.456752195105103, R²=0.6954378995581778
# 4/4 [==============================] - 0s 6ms/step
# Global evaluation results on test dataset in round 19: MAE=18.233130016326903, RMSE=23.96724189415444, R²=0.6673583899948717
# Training completed.

# %% [markdown]
# #### Save the model

# %%
# save model to storage
#global_model.save(f'federated/model_KRUM_{EPOCHS}_{comms_round}_{int(datetime.now().timestamp())}')

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(30, 7))

# Plot MAE
ax1.plot(global_stats_mae_4[global_stats_mae_4.columns[1:11]], label='train')
ax1.set_ylabel('MAE', fontsize=15)
ax1.set_xlabel('Round', fontsize=15)
ax1.xaxis.set_major_formatter(FormatStrFormatter('%.0f'))

# Plot R² instead of MAP
ax2.plot(global_stats_r2_4[global_stats_r2_4.columns[1:11]], label='train')
ax2.legend(global_stats_r2_4.columns[1:11], bbox_to_anchor=(1.05, 1.06), ncol=10)
ax2.set_ylabel('R²', fontsize=15)
ax2.set_xlabel('Round', fontsize=15)
ax2.xaxis.set_major_formatter(FormatStrFormatter('%.0f'))

# Plot RMSE
ax3.plot(global_stats_rmse_4[global_stats_rmse_4.columns[1:11]], label='train')
ax3.set_ylabel('RMSE', fontsize=15)
ax3.set_xlabel('Round', fontsize=15)
ax3.xaxis.set_major_formatter(FormatStrFormatter('%.0f'))

plt.tight_layout()
plt.show()
#pyplot.savefig(f'federated-KRUM_{EPOCHS}_{comms_round}.png', bbox_inches='tight', dpi=400)

# %%
print('size of model: ', sys.getsizeof(global_model.get_weights()))
# Out:
# size of model:  184

# %% [markdown]
# ### Calculating the average metrics across all rounds and storing them in new columns

# %%
global_stats_mae_4['A'] = (global_stats_mae_4['0'] + global_stats_mae_4['1'] + global_stats_mae_4['2'] + global_stats_mae_4['3'] +
                         global_stats_mae_4['4'] + global_stats_mae_4['5'] + global_stats_mae_4['6'] + global_stats_mae_4['7'] +
                         global_stats_mae_4['8'] + global_stats_mae_4['9'] + global_stats_mae_4['test']) / 11

global_stats_r2_4['A'] = (global_stats_r2_4['0'] + global_stats_r2_4['1'] + global_stats_r2_4['2'] + global_stats_r2_4['3'] +
                          global_stats_r2_4['4'] + global_stats_r2_4['5'] + global_stats_r2_4['6'] + global_stats_r2_4['7'] +
                          global_stats_r2_4['8'] + global_stats_r2_4['9'] + global_stats_r2_4['test']) / 11

global_stats_rmse_4['A'] = (global_stats_rmse_4['0'] + global_stats_rmse_4['1'] + global_stats_rmse_4['2'] + global_stats_rmse_4['3'] +
                          global_stats_rmse_4['4'] + global_stats_rmse_4['5'] + global_stats_rmse_4['6'] + global_stats_rmse_4['7'] +
                          global_stats_rmse_4['8'] + global_stats_rmse_4['9'] + global_stats_rmse_4['test']) / 11

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(30, 7))

# Plot MAE
ax1.plot(global_stats_mae_4['A'], label='train', marker='o')
ax1.set_ylabel('MAE', fontsize=15)
ax1.set_xlabel('Round', fontsize=15)
ax1.xaxis.set_major_formatter(FormatStrFormatter('%.0f'))

# Plot R²
ax2.plot(global_stats_r2_4['A'], label='train', marker='o')
ax2.set_ylabel('R²', fontsize=15)
ax2.set_xlabel('Round', fontsize=15)
ax2.xaxis.set_major_formatter(FormatStrFormatter('%.0f'))

# Plot RMSE
ax3.plot(global_stats_rmse_4['A'], label='train', marker='o')
ax3.set_ylabel('RMSE', fontsize=15)
ax3.set_xlabel('Round', fontsize=15)
ax3.xaxis.set_major_formatter(FormatStrFormatter('%.0f'))

# Add text annotations for the last round values
round_idx = len(global_stats_mae_4) - 1
ax1.text(round_idx, global_stats_mae_4['A'][round_idx], f'{global_stats_mae_4["A"][round_idx]:.2f}', bbox=dict(facecolor='white', alpha=0.5, edgecolor='black'))
ax2.text(round_idx, global_stats_r2_4['A'][round_idx], f'{global_stats_r2_4["A"][round_idx]:.2f}', bbox=dict(facecolor='white', alpha=0.5, edgecolor='black'))
ax3.text(round_idx, global_stats_rmse_4['A'][round_idx], f'{global_stats_rmse_4["A"][round_idx]:.2f}', bbox=dict(facecolor='white', alpha=0.5, edgecolor='black'))

plt.tight_layout()
plt.show()

pyplot.savefig(f'global-KRUM_{EPOCHS}_{comms_round}.png', bbox_inches='tight', dpi=400)

# %%
fig, (ax1, ax2, ax3) = pyplot.subplots(1, 3, figsize=(30, 7))

ax1.plot(global_stats_mae_4['test'], label='test', marker='o', color='red')
ax1.set_ylabel('MAE', fontsize=15)
ax1.set_xlabel('Round', fontsize=15)
ax1.xaxis.set_major_formatter(FormatStrFormatter('%.0f'))

ax2.plot(global_stats_r2_4['test'], label='test', marker='o', color='red')
ax2.set_ylabel('R2', fontsize=15)
ax2.set_xlabel('Round', fontsize=15)
ax2.xaxis.set_major_formatter(FormatStrFormatter('%.0f'))

ax3.plot(global_stats_rmse_4['test'], label='test', marker='o', color='red')
ax3.set_ylabel('RMSE', fontsize=15)
ax3.set_xlabel('Round', fontsize=15)
ax3.xaxis.set_major_formatter(FormatStrFormatter('%.0f'))

round_idx = len(global_stats_mae_4) - 1  
ax1.text(round_idx, global_stats_mae_4['test'][round_idx], f'{global_stats_mae_4["test"][round_idx]:.2f}', bbox=dict(facecolor='white', alpha=0.5, edgecolor='black'))
ax2.text(round_idx, global_stats_r2_4['test'][round_idx], f'{global_stats_r2_4["test"][round_idx]:.2f}', bbox=dict(facecolor='white', alpha=0.5, edgecolor='black'))
ax3.text(round_idx, global_stats_rmse_4['test'][round_idx], f'{global_stats_rmse_4["test"][round_idx]:.2f}', bbox=dict(facecolor='white', alpha=0.5, edgecolor='black'))

ax1.set_title('MAE for Test Dataset', fontsize=20)
ax2.set_title('R^2 for Test Dataset', fontsize=20)
ax3.set_title('RMSE for Test Dataset', fontsize=20)

plt.tight_layout()

plt.show()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
