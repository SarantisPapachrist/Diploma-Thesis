# %% [markdown]
# #### Import Libraries

# %%
import pandas as pd
import numpy as np
import os
from matplotlib import pyplot
from matplotlib.ticker import FormatStrFormatter
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error

import tensorflow as tf
from tensorflow.keras import layers, Sequential
from tensorflow.keras import backend as K

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

from sklearn.preprocessing import StandardScaler
from datetime import datetime
import sys

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
tf.get_logger().setLevel('ERROR')

USE_CUDA = False
EPOCHS = 20
comms_round = 20
# Out:
# 2024-06-02 19:08:54.300639: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-02 19:08:54.300674: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-02 19:08:54.300945: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-06-02 19:08:54.363955: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-02 19:08:55.474007: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ### Dataset

# %%
# %store -r FD1_X_Train
# %store -r FD1_X_Test

# %store -r FD1_X_Train_st
# %store -r FD1_X_Test_st

# %store -r FD1_y_Train
# %store -r FD1_y_Test

merged_dataset = pd.concat([FD1_X_Train_st, FD1_y_Train], axis=1)

# %%
feature_columns = ['time_cycles', 'LPC_Outlet_Temperature', 'HPC_Outlet_Temperature', 'LPT Outlet Temperature', 'Bypass-Duct Pressure', 
                'HPC Outlet Pressure', 'Physical Fan Speed', 'Physical Core Speed', 'HPC Outlet Static Pressure',
                'Ratio of Fuel Flow to Ps30', 'Corrected Fan Speed', 'Bypass Ratio', 'Bleed Enthalpy',
                'High-Pressure Turbines Cool Air Flow', 'Low-Pressure Turbines Cool Air Flow']

features = merged_dataset[feature_columns]

labels = merged_dataset['RUL']

# Split the data into training and testing sets
train_features, test_features, train_labels, test_labels = train_test_split(features, labels, test_size=0.3, random_state=0)

# %% [markdown]
# ### Data Partition

# %%
num_edge_devices = 10  

samples_per_device = len(merged_dataset) // num_edge_devices

edge_data_partition_1 = merged_dataset.iloc[0:samples_per_device]
edge_data_partition_2 = merged_dataset.iloc[samples_per_device:2*samples_per_device]
edge_data_partition_3 = merged_dataset.iloc[2*samples_per_device:3*samples_per_device]
edge_data_partition_4 = merged_dataset.iloc[3*samples_per_device:4*samples_per_device]
edge_data_partition_5 = merged_dataset.iloc[4*samples_per_device:5*samples_per_device]
edge_data_partition_6 = merged_dataset.iloc[5*samples_per_device:6*samples_per_device]
edge_data_partition_7 = merged_dataset.iloc[6*samples_per_device:7*samples_per_device]
edge_data_partition_8 = merged_dataset.iloc[7*samples_per_device:8*samples_per_device]
edge_data_partition_9 = merged_dataset.iloc[8*samples_per_device:9*samples_per_device]
edge_data_partition_10 = merged_dataset.iloc[9*samples_per_device:]

# %% [markdown]
# #### Train, Test split for each one of the 10 datasets

# %%
datasets = []

for i, df in enumerate([edge_data_partition_1, edge_data_partition_2, edge_data_partition_3, edge_data_partition_4, edge_data_partition_5, edge_data_partition_6, edge_data_partition_7, edge_data_partition_8, edge_data_partition_9, edge_data_partition_10]):  
    
    features = df[feature_columns]
    labels = df['RUL']
    
    # Split data into training and testing sets
    train_features, test_features, train_labels, test_labels = train_test_split(features, labels, test_size=0.3, random_state=0)
    
    # Append dataset dictionary to the list 
    datasets.append({
        'name': f'dataset_{i+1}',
        'train_features': train_features,
        'test_features': test_features,
        'train_labels': train_labels,
        'test_labels': test_labels
    })

for dataset in datasets:
    dataset['train_features'] = dataset['train_features'].fillna(0)
    dataset['test_features'] = dataset['test_features'].fillna(0)
    dataset['train_labels'] = dataset['train_labels'].fillna(0)
    dataset['test_labels'] = dataset['test_labels'].fillna(0)

# %% [markdown]
# ### LSTM Model

# %%
def create_lstm_model(input_shape):
    model = Sequential([
        layers.Reshape((input_shape, 1), input_shape=(input_shape,)),
        layers.LSTM(128, activation="relu", return_sequences=True),
        layers.LSTM(64, activation="relu", return_sequences=True),
        layers.LSTM(32, activation="relu"),
        layers.Dense(64, activation="relu"),
        layers.Dense(128, activation="relu"),
        layers.Dense(1)
    ])
    model.compile(loss="mse", optimizer=tf.keras.optimizers.Adam(learning_rate=0.001))
    return model

input_shape = len(train_features.columns)
lstm_model = create_lstm_model(input_shape)
# Out:
# 2024-06-02 19:08:57.082058: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-06-02 19:08:57.241962: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-06-02 19:08:57.245104: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-06-02 19:08:57.248898: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-06-02 19:08:57.254264: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-06-02 19:08:57.256800: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-06-02 19:08:58.093657: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-06-02 19:08:58.095342: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-06-02 19:08:58.096825: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-06-02 19:08:58.098465: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2416 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650, pci bus id: 0000:01:00.0, compute capability: 7.5

# %%
def evaluate_model(model, test_features, test_labels):
    predictions = model.predict(test_features)
    
    if np.isnan(predictions).any():
        raise ValueError("Model predictions contain NaNs.")
    
    mae = mean_absolute_error(test_labels, predictions)
    mape = mean_absolute_percentage_error(test_labels, predictions)
    rmse = mean_squared_error(test_labels, predictions, squared=False)
    
    return mae, mape, rmse

# %% [markdown]
# #### Function for KRUM

# %%
def krum(weights, num_byzantine):
    n = len(weights)
    num_layers = len(weights[0]) 
    distances = np.zeros((n, n))
    
    for i in range(n):
        for j in range(i + 1, n):
            distance = 0
            for layer in range(num_layers):
                distance += np.linalg.norm(weights[i][layer] - weights[j][layer])
            distances[i, j] = distance
            distances[j, i] = distance
    
    scores = np.zeros(n)
    for i in range(n):
        scores[i] = np.sum(np.sort(distances[i])[:n - num_byzantine - 2])
    
    return weights[np.argmin(scores)]

# %% [markdown]
# ### Federated Learning System with FedMA AGGREGATION

# %%
global_model = create_lstm_model(input_shape)

global_stats_mae = pd.DataFrame(columns=['Round'] + [str(i) for i in range(len(datasets))])
global_stats_mape = pd.DataFrame(columns=['Round'] + [str(i) for i in range(len(datasets))])
global_stats_rmse = pd.DataFrame(columns=['Round'] + [str(i) for i in range(len(datasets))])

for comm_round in range(comms_round):
    print('Round', comm_round)
    global_weights = global_model.get_weights()
    client_weights = []
    
    for dataset in datasets:
        local_model = create_lstm_model(input_shape)
        local_model.compile(loss='mse', optimizer=tf.keras.optimizers.Adam(), metrics='MAE')

        def scheduler(epoch):
            if epoch < 5:
                return 0.001
            else:
                return 0.0001

        callback = tf.keras.callbacks.LearningRateScheduler(scheduler, verbose=0)
        local_model.set_weights(global_weights)

        epochs = EPOCHS 
        history = local_model.fit(dataset['train_features'], dataset['train_labels'], epochs=epochs, callbacks=[callback])

        client_weights.append(local_model.get_weights())

        for dataset_1 in datasets:
            mae, mape, rmse = evaluate_model(local_model, dataset_1['test_features'], dataset_1['test_labels'])
            print(f'Evaluation results for {dataset["name"]} on {dataset_1["name"]} in round {comm_round}: MAE={mae}, MAPE={mape}, RMSE={rmse}')            

        mae, mape, rmse = evaluate_model(local_model, dataset['test_features'], dataset['test_labels'])
        print(f'Evaluation results for {dataset["name"]} on itself in round {comm_round}: MAE={mae}, MAPE={mape}, RMSE={rmse}')

        K.clear_session()

    num_byzantine = 2  # Υποθέτουμε ότι υπάρχουν 2 Byzantine clients
    aggregated_weights = krum(client_weights, num_byzantine)

    global_model.set_weights(aggregated_weights)

    global_row_mae = [comm_round]
    global_row_mape = [comm_round]
    global_row_rmse = [comm_round]

    for dataset in datasets:
        mae, mape, rmse = evaluate_model(global_model, dataset['test_features'], dataset['test_labels'])
        global_row_mae.append(mae)
        global_row_mape.append(mape)
        global_row_rmse.append(rmse)
        print(f'Global evaluation results for {dataset["name"]} in round {comm_round}: MAE={mae}, MAPE={mape}, RMSE={rmse}')

    global_stats_mae.loc[len(global_stats_mae)] = global_row_mae
    global_stats_mape.loc[len(global_stats_mape)] = global_row_mape
    global_stats_rmse.loc[len(global_stats_rmse)] = global_row_rmse

print("Training completed.")
# Out:
# Round 0
# Epoch 1/20
# 2024-06-02 19:09:02.145546: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x72d7bc002970 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-06-02 19:09:02.145585: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce GTX 1650, Compute Capability 7.5
# 2024-06-02 19:09:02.149706: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-06-02 19:09:02.194761: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8902
# 2024-06-02 19:09:02.247935: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 46/46 [==============================] - 6s 33ms/step - loss: 7355.9121 - MAE: 73.3377 - lr: 0.0010
# Epoch 2/20
# 46/46 [==============================] - 2s 33ms/step - loss: 802.2457 - MAE: 21.3155 - lr: 0.0010
# Epoch 3/20
# 46/46 [==============================] - 2s 33ms/step - loss: 316.3573 - MAE: 13.5817 - lr: 0.0010
# Epoch 4/20
# 46/46 [==============================] - 2s 33ms/step - loss: 291.9529 - MAE: 12.7883 - lr: 0.0010
# Epoch 5/20
# 46/46 [==============================] - 2s 33ms/step - loss: 295.6471 - MAE: 13.1487 - lr: 0.0010
# Epoch 6/20
# 46/46 [==============================] - 2s 33ms/step - loss: 281.1992 - MAE: 12.0701 - lr: 1.0000e-04
# Epoch 7/20
# 46/46 [==============================] - 2s 33ms/step - loss: 268.2285 - MAE: 11.8681 - lr: 1.0000e-04
# Epoch 8/20
# 46/46 [==============================] - 2s 33ms/step - loss: 265.3312 - MAE: 11.6935 - lr: 1.0000e-04
# Epoch 9/20
# 46/46 [==============================] - 2s 33ms/step - loss: 265.2795 - MAE: 11.7452 - lr: 1.0000e-04
# Epoch 10/20
# 46/46 [==============================] - 2s 33ms/step - loss: 265.2759 - MAE: 11.8459 - lr: 1.0000e-04
# Epoch 11/20
# 46/46 [==============================] - 2s 33ms/step - loss: 261.3323 - MAE: 11.5637 - lr: 1.0000e-04
# Epoch 12/20
# 46/46 [==============================] - 2s 33ms/step - loss: 262.3497 - MAE: 11.6654 - lr: 1.0000e-04
# Epoch 13/20
# 46/46 [==============================] - 1s 33ms/step - loss: 264.9442 - MAE: 11.7307 - lr: 1.0000e-04
# Epoch 14/20
# 46/46 [==============================] - 2s 33ms/step - loss: 266.5071 - MAE: 11.9763 - lr: 1.0000e-04
# Epoch 15/20
# 46/46 [==============================] - 2s 33ms/step - loss: 258.0576 - MAE: 11.5033 - lr: 1.0000e-04
# Epoch 16/20
# 46/46 [==============================] - 1s 32ms/step - loss: 259.0932 - MAE: 11.5211 - lr: 1.0000e-04
# Epoch 17/20
# 46/46 [==============================] - 2s 33ms/step - loss: 256.6403 - MAE: 11.4140 - lr: 1.0000e-04
# Epoch 18/20
# 46/46 [==============================] - 2s 33ms/step - loss: 256.4969 - MAE: 11.5576 - lr: 1.0000e-04
# Epoch 19/20
# 46/46 [==============================] - 2s 33ms/step - loss: 254.4664 - MAE: 11.2901 - lr: 1.0000e-04
# Epoch 20/20
# 46/46 [==============================] - 2s 33ms/step - loss: 254.7704 - MAE: 11.3876 - lr: 1.0000e-04
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_1 on dataset_1 in round 0: MAE=10.815141361537773, MAPE=156264434778668.03, RMSE=15.713882395426745
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_1 on dataset_2 in round 0: MAE=13.707208179406857, MAPE=85067737647570.78, RMSE=18.961298563510056
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_1 on dataset_3 in round 0: MAE=14.983711038537095, MAPE=171458577612350.38, RMSE=20.27709227319908
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_1 on dataset_4 in round 0: MAE=12.492689709671094, MAPE=113735792206737.45, RMSE=16.873385323447376
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_1 on dataset_5 in round 0: MAE=12.399786068280024, MAPE=77924684474186.28, RMSE=17.573176800827994
# 20/20 [==============================] - 0s 7ms/step
# Evaluation results for dataset_1 on dataset_6 in round 0: MAE=16.1157302093814, MAPE=122795078604505.84, RMSE=21.962479262836244
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_1 on dataset_7 in round 0: MAE=19.71745641512709, MAPE=181358775587616.94, RMSE=25.824587684560953
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_1 on dataset_8 in round 0: MAE=14.841850275754544, MAPE=258008385574564.9, RMSE=19.77317569410925
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_1 on dataset_9 in round 0: MAE=16.197815324262578, MAPE=101603123657905.28, RMSE=22.588953623415392
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_1 on dataset_10 in round 0: MAE=18.09846212287103, MAPE=127628320766731.88, RMSE=24.78503484745762
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_1 on itself in round 0: MAE=10.815141361537773, MAPE=156264434778668.03, RMSE=15.713882395426745
# Epoch 1/20
# 46/46 [==============================] - 4s 33ms/step - loss: 9578.5645 - MAE: 86.3067 - lr: 0.0010
# Epoch 2/20
# 46/46 [==============================] - 2s 33ms/step - loss: 3169.1550 - MAE: 44.9691 - lr: 0.0010
# Epoch 3/20
# 46/46 [==============================] - 2s 33ms/step - loss: 633.4252 - MAE: 20.1269 - lr: 0.0010
# Epoch 4/20
# 46/46 [==============================] - 2s 33ms/step - loss: 372.9718 - MAE: 14.7274 - lr: 0.0010
# Epoch 5/20
# 46/46 [==============================] - 2s 33ms/step - loss: 390.3927 - MAE: 15.3491 - lr: 0.0010
# Epoch 6/20
# 46/46 [==============================] - 2s 33ms/step - loss: 341.5569 - MAE: 13.8723 - lr: 1.0000e-04
# Epoch 7/20
# 46/46 [==============================] - 2s 33ms/step - loss: 334.8381 - MAE: 13.6642 - lr: 1.0000e-04
# Epoch 8/20
# 46/46 [==============================] - 2s 33ms/step - loss: 332.8973 - MAE: 13.5523 - lr: 1.0000e-04
# Epoch 9/20
# 46/46 [==============================] - 2s 33ms/step - loss: 329.0326 - MAE: 13.5674 - lr: 1.0000e-04
# Epoch 10/20
# 46/46 [==============================] - 2s 33ms/step - loss: 326.0958 - MAE: 13.3236 - lr: 1.0000e-04
# Epoch 11/20
# 46/46 [==============================] - 2s 33ms/step - loss: 323.6511 - MAE: 13.4229 - lr: 1.0000e-04
# Epoch 12/20
# 46/46 [==============================] - 2s 33ms/step - loss: 320.4163 - MAE: 13.2131 - lr: 1.0000e-04
# Epoch 13/20
# 46/46 [==============================] - 2s 34ms/step - loss: 318.5734 - MAE: 13.3142 - lr: 1.0000e-04
# Epoch 14/20
# 46/46 [==============================] - 2s 34ms/step - loss: 318.1787 - MAE: 13.1568 - lr: 1.0000e-04
# Epoch 15/20
# 46/46 [==============================] - 2s 33ms/step - loss: 312.9710 - MAE: 13.1318 - lr: 1.0000e-04
# Epoch 16/20
# 46/46 [==============================] - 2s 33ms/step - loss: 314.1323 - MAE: 13.1498 - lr: 1.0000e-04
# Epoch 17/20
# 46/46 [==============================] - 2s 33ms/step - loss: 308.3176 - MAE: 13.1516 - lr: 1.0000e-04
# Epoch 18/20
# 46/46 [==============================] - 1s 33ms/step - loss: 305.8651 - MAE: 12.8177 - lr: 1.0000e-04
# Epoch 19/20
# 46/46 [==============================] - 2s 34ms/step - loss: 301.6065 - MAE: 12.9309 - lr: 1.0000e-04
# Epoch 20/20
# 46/46 [==============================] - 2s 34ms/step - loss: 299.8431 - MAE: 12.7044 - lr: 1.0000e-04
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_2 on dataset_1 in round 0: MAE=11.347145018169298, MAPE=160821915905221.06, RMSE=16.234099026806135
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_2 on dataset_2 in round 0: MAE=12.92780273584634, MAPE=100771791626809.31, RMSE=17.8205008925945
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_2 on dataset_3 in round 0: MAE=14.850554143092166, MAPE=162873173898612.56, RMSE=20.711889275846637
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_2 on dataset_4 in round 0: MAE=12.200978897692506, MAPE=110892416309139.11, RMSE=16.83067242131737
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_2 on dataset_5 in round 0: MAE=11.746029028407206, MAPE=71295721626470.39, RMSE=17.137216200582216
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_2 on dataset_6 in round 0: MAE=16.246344822096322, MAPE=121112964030080.55, RMSE=22.34076018218849
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_2 on dataset_7 in round 0: MAE=18.741255539491988, MAPE=159119176467649.84, RMSE=25.231100133765203
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_2 on dataset_8 in round 0: MAE=13.393741356536914, MAPE=248406403345499.28, RMSE=18.324170281976027
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_2 on dataset_9 in round 0: MAE=15.28615957585213, MAPE=104115179949901.6, RMSE=21.575219538162425
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_2 on dataset_10 in round 0: MAE=17.9415698262953, MAPE=116191989252836.2, RMSE=24.67307888075482
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_2 on itself in round 0: MAE=12.92780273584634, MAPE=100771791626809.31, RMSE=17.8205008925945
# Epoch 1/20
# 46/46 [==============================] - 4s 33ms/step - loss: 6870.7632 - MAE: 70.8617 - lr: 0.0010
# Epoch 2/20
# 46/46 [==============================] - 2s 33ms/step - loss: 1176.2773 - MAE: 27.2307 - lr: 0.0010
# Epoch 3/20
# 46/46 [==============================] - 2s 33ms/step - loss: 488.2913 - MAE: 17.7919 - lr: 0.0010
# Epoch 4/20
# 46/46 [==============================] - 2s 33ms/step - loss: 441.3148 - MAE: 16.7816 - lr: 0.0010
# Epoch 5/20
# 46/46 [==============================] - 2s 34ms/step - loss: 422.9787 - MAE: 16.2615 - lr: 0.0010
# Epoch 6/20
# 46/46 [==============================] - 2s 33ms/step - loss: 417.8575 - MAE: 16.2039 - lr: 1.0000e-04
# Epoch 7/20
# 46/46 [==============================] - 2s 33ms/step - loss: 394.3026 - MAE: 15.6734 - lr: 1.0000e-04
# Epoch 8/20
# 46/46 [==============================] - 2s 33ms/step - loss: 391.3532 - MAE: 15.5088 - lr: 1.0000e-04
# Epoch 9/20
# 46/46 [==============================] - 2s 33ms/step - loss: 389.8871 - MAE: 15.4458 - lr: 1.0000e-04
# Epoch 10/20
# 46/46 [==============================] - 2s 33ms/step - loss: 387.6949 - MAE: 15.3879 - lr: 1.0000e-04
# Epoch 11/20
# 46/46 [==============================] - 2s 33ms/step - loss: 384.2138 - MAE: 15.3381 - lr: 1.0000e-04
# Epoch 12/20
# 46/46 [==============================] - 2s 33ms/step - loss: 381.4949 - MAE: 15.2778 - lr: 1.0000e-04
# Epoch 13/20
# 46/46 [==============================] - 2s 33ms/step - loss: 379.3438 - MAE: 15.2557 - lr: 1.0000e-04
# Epoch 14/20
# 46/46 [==============================] - 2s 33ms/step - loss: 378.6416 - MAE: 15.1443 - lr: 1.0000e-04
# Epoch 15/20
# 46/46 [==============================] - 2s 33ms/step - loss: 374.8948 - MAE: 15.2103 - lr: 1.0000e-04
# Epoch 16/20
# 46/46 [==============================] - 2s 33ms/step - loss: 373.0501 - MAE: 15.0853 - lr: 1.0000e-04
# Epoch 17/20
# 46/46 [==============================] - 2s 33ms/step - loss: 370.1548 - MAE: 15.0300 - lr: 1.0000e-04
# Epoch 18/20
# 46/46 [==============================] - 2s 34ms/step - loss: 371.1816 - MAE: 15.1514 - lr: 1.0000e-04
# Epoch 19/20
# 46/46 [==============================] - 2s 33ms/step - loss: 364.7836 - MAE: 14.8022 - lr: 1.0000e-04
# Epoch 20/20
# 46/46 [==============================] - 2s 33ms/step - loss: 362.7863 - MAE: 14.8884 - lr: 1.0000e-04
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_3 on dataset_1 in round 0: MAE=12.695368335975006, MAPE=288590226649161.06, RMSE=16.830068172451178
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_3 on dataset_2 in round 0: MAE=13.4919891627039, MAPE=120108637273238.8, RMSE=18.02631040604588
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_3 on dataset_3 in round 0: MAE=14.06428847174267, MAPE=192954330374925.12, RMSE=18.23039437197105
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_3 on dataset_4 in round 0: MAE=11.802389711863775, MAPE=188603754007206.56, RMSE=15.265423501041338
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_3 on dataset_5 in round 0: MAE=12.558250736150296, MAPE=110057036496869.8, RMSE=16.666727187060975
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_3 on dataset_6 in round 0: MAE=15.699754153584433, MAPE=148256695059385.22, RMSE=21.231825128734105
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_3 on dataset_7 in round 0: MAE=23.062804763652203, MAPE=275792190301258.75, RMSE=29.704361539532318
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_3 on dataset_8 in round 0: MAE=14.663489552807539, MAPE=355159671551798.5, RMSE=19.025977112519797
# 20/20 [==============================] - 0s 7ms/step
# Evaluation results for dataset_3 on dataset_9 in round 0: MAE=18.168610419518345, MAPE=186015540104481.88, RMSE=24.536309313353424
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_3 on dataset_10 in round 0: MAE=21.17214120145767, MAPE=181310103006148.84, RMSE=28.43517660149482
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_3 on itself in round 0: MAE=14.06428847174267, MAPE=192954330374925.12, RMSE=18.23039437197105
# Epoch 1/20
# 46/46 [==============================] - 4s 33ms/step - loss: 12607.4971 - MAE: 77.8795 - lr: 0.0010
# Epoch 2/20
# 46/46 [==============================] - 2s 33ms/step - loss: 3021.2715 - MAE: 44.0961 - lr: 0.0010
# Epoch 3/20
# 46/46 [==============================] - 2s 33ms/step - loss: 383.6207 - MAE: 15.2522 - lr: 0.0010
# Epoch 4/20
# 46/46 [==============================] - 2s 33ms/step - loss: 311.4053 - MAE: 13.4214 - lr: 0.0010
# Epoch 5/20
# 46/46 [==============================] - 2s 33ms/step - loss: 299.1476 - MAE: 13.2098 - lr: 0.0010
# Epoch 6/20
# 46/46 [==============================] - 2s 33ms/step - loss: 267.6074 - MAE: 12.3154 - lr: 1.0000e-04
# Epoch 7/20
# 46/46 [==============================] - 2s 33ms/step - loss: 264.2360 - MAE: 12.2433 - lr: 1.0000e-04
# Epoch 8/20
# 46/46 [==============================] - 2s 33ms/step - loss: 261.4164 - MAE: 12.1328 - lr: 1.0000e-04
# Epoch 9/20
# 46/46 [==============================] - 2s 33ms/step - loss: 259.6705 - MAE: 12.1556 - lr: 1.0000e-04
# Epoch 10/20
# 46/46 [==============================] - 2s 33ms/step - loss: 257.5009 - MAE: 12.0705 - lr: 1.0000e-04
# Epoch 11/20
# 46/46 [==============================] - 2s 34ms/step - loss: 254.5045 - MAE: 11.9611 - lr: 1.0000e-04
# Epoch 12/20
# 46/46 [==============================] - 2s 33ms/step - loss: 252.1174 - MAE: 11.9344 - lr: 1.0000e-04
# Epoch 13/20
# 46/46 [==============================] - 2s 33ms/step - loss: 250.5518 - MAE: 11.8944 - lr: 1.0000e-04
# Epoch 14/20
# 46/46 [==============================] - 2s 33ms/step - loss: 248.5298 - MAE: 11.8201 - lr: 1.0000e-04
# Epoch 15/20
# 46/46 [==============================] - 2s 34ms/step - loss: 246.5942 - MAE: 11.7005 - lr: 1.0000e-04
# Epoch 16/20
# 46/46 [==============================] - 2s 33ms/step - loss: 244.5728 - MAE: 11.7203 - lr: 1.0000e-04
# Epoch 17/20
# 46/46 [==============================] - 2s 33ms/step - loss: 239.6755 - MAE: 11.5377 - lr: 1.0000e-04
# Epoch 18/20
# 46/46 [==============================] - 2s 33ms/step - loss: 239.2165 - MAE: 11.6271 - lr: 1.0000e-04
# Epoch 19/20
# 46/46 [==============================] - 2s 33ms/step - loss: 235.5205 - MAE: 11.4012 - lr: 1.0000e-04
# Epoch 20/20
# 46/46 [==============================] - 2s 33ms/step - loss: 235.2524 - MAE: 11.4674 - lr: 1.0000e-04
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_4 on dataset_1 in round 0: MAE=12.598133786718371, MAPE=63406612598684.95, RMSE=17.014049658972844
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_4 on dataset_2 in round 0: MAE=12.879836042401093, MAPE=59771409348988.695, RMSE=17.90381677002376
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_4 on dataset_3 in round 0: MAE=13.44388147952676, MAPE=73099938339607.03, RMSE=18.00625571099109
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_4 on dataset_4 in round 0: MAE=11.006326220917586, MAPE=46043325240441.01, RMSE=14.823206659341004
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_4 on dataset_5 in round 0: MAE=11.912650982859832, MAPE=24504550817368.723, RMSE=16.311364469511318
# 20/20 [==============================] - 0s 7ms/step
# Evaluation results for dataset_4 on dataset_6 in round 0: MAE=15.199203378742077, MAPE=52886965332739.164, RMSE=21.304909551219428
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_4 on dataset_7 in round 0: MAE=22.60334712594314, MAPE=74558003412462.94, RMSE=29.529987228235495
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_4 on dataset_8 in round 0: MAE=13.97288514194658, MAPE=139933299095138.66, RMSE=19.13412372436398
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_4 on dataset_9 in round 0: MAE=17.40441679607878, MAPE=51023536701731.41, RMSE=24.337768764601506
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_4 on dataset_10 in round 0: MAE=21.074245469031794, MAPE=60391258054392.04, RMSE=28.780544879986696
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_4 on itself in round 0: MAE=11.006326220917586, MAPE=46043325240441.01, RMSE=14.823206659341004
# Epoch 1/20
# 46/46 [==============================] - 4s 33ms/step - loss: 7126.3257 - MAE: 70.5793 - lr: 0.0010
# Epoch 2/20
# 46/46 [==============================] - 2s 33ms/step - loss: 797.9555 - MAE: 22.1223 - lr: 0.0010
# Epoch 3/20
# 46/46 [==============================] - 2s 33ms/step - loss: 369.7301 - MAE: 14.5654 - lr: 0.0010
# Epoch 4/20
# 46/46 [==============================] - 2s 33ms/step - loss: 365.0476 - MAE: 14.5483 - lr: 0.0010
# Epoch 5/20
# 46/46 [==============================] - 2s 33ms/step - loss: 331.1645 - MAE: 13.5998 - lr: 0.0010
# Epoch 6/20
# 46/46 [==============================] - 2s 33ms/step - loss: 314.9845 - MAE: 12.8744 - lr: 1.0000e-04
# Epoch 7/20
# 46/46 [==============================] - 2s 33ms/step - loss: 297.8077 - MAE: 12.3620 - lr: 1.0000e-04
# Epoch 8/20
# 46/46 [==============================] - 2s 33ms/step - loss: 295.0251 - MAE: 12.2257 - lr: 1.0000e-04
# Epoch 9/20
# 46/46 [==============================] - 2s 33ms/step - loss: 293.2587 - MAE: 12.2642 - lr: 1.0000e-04
# Epoch 10/20
# 46/46 [==============================] - 2s 33ms/step - loss: 289.0746 - MAE: 12.1329 - lr: 1.0000e-04
# Epoch 11/20
# 46/46 [==============================] - 2s 33ms/step - loss: 287.3646 - MAE: 12.1682 - lr: 1.0000e-04
# Epoch 12/20
# 46/46 [==============================] - 2s 33ms/step - loss: 283.8284 - MAE: 11.8864 - lr: 1.0000e-04
# Epoch 13/20
# 46/46 [==============================] - 2s 33ms/step - loss: 284.9474 - MAE: 11.9949 - lr: 1.0000e-04
# Epoch 14/20
# 46/46 [==============================] - 2s 33ms/step - loss: 286.0928 - MAE: 12.3957 - lr: 1.0000e-04
# Epoch 15/20
# 46/46 [==============================] - 2s 33ms/step - loss: 276.7584 - MAE: 11.8169 - lr: 1.0000e-04
# Epoch 16/20
# 46/46 [==============================] - 2s 33ms/step - loss: 269.9474 - MAE: 11.5545 - lr: 1.0000e-04
# Epoch 17/20
# 46/46 [==============================] - 2s 33ms/step - loss: 267.9094 - MAE: 11.6379 - lr: 1.0000e-04
# Epoch 18/20
# 46/46 [==============================] - 2s 33ms/step - loss: 268.4328 - MAE: 11.6717 - lr: 1.0000e-04
# Epoch 19/20
# 46/46 [==============================] - 2s 33ms/step - loss: 262.9366 - MAE: 11.4562 - lr: 1.0000e-04
# Epoch 20/20
# 46/46 [==============================] - 2s 33ms/step - loss: 257.5207 - MAE: 11.2449 - lr: 1.0000e-04
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_5 on dataset_1 in round 0: MAE=13.93274685924629, MAPE=161573811640184.56, RMSE=16.996487601381286
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_5 on dataset_2 in round 0: MAE=15.03454413797604, MAPE=71635802218377.14, RMSE=19.216346266548396
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_5 on dataset_3 in round 0: MAE=15.79562612323268, MAPE=146778797853615.25, RMSE=19.640242852686754
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_5 on dataset_4 in round 0: MAE=13.572600647783048, MAPE=113095257506136.38, RMSE=16.892058468574994
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_5 on dataset_5 in round 0: MAE=13.98787112035736, MAPE=73152927238425.48, RMSE=17.20520194145857
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_5 on dataset_6 in round 0: MAE=17.17476683181014, MAPE=96845407027570.88, RMSE=21.855746688841045
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_5 on dataset_7 in round 0: MAE=23.419091411283983, MAPE=168590764114079.12, RMSE=29.07366669566521
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_5 on dataset_8 in round 0: MAE=16.346013904965943, MAPE=247423903556947.44, RMSE=20.314712157023326
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_5 on dataset_9 in round 0: MAE=18.694553646016775, MAPE=106240201751570.48, RMSE=24.169576231041255
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_5 on dataset_10 in round 0: MAE=21.720130255337683, MAPE=101247018857161.81, RMSE=27.6002047455282
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_5 on itself in round 0: MAE=13.98787112035736, MAPE=73152927238425.48, RMSE=17.20520194145857
# Epoch 1/20
# 46/46 [==============================] - 4s 33ms/step - loss: 6142.0171 - MAE: 65.3109 - lr: 0.0010
# Epoch 2/20
# 46/46 [==============================] - 2s 33ms/step - loss: 781.0220 - MAE: 22.2452 - lr: 0.0010
# Epoch 3/20
# 46/46 [==============================] - 2s 34ms/step - loss: 571.5162 - MAE: 18.6700 - lr: 0.0010
# Epoch 4/20
# 46/46 [==============================] - 2s 33ms/step - loss: 545.7914 - MAE: 18.1802 - lr: 0.0010
# Epoch 5/20
# 46/46 [==============================] - 2s 33ms/step - loss: 539.5421 - MAE: 18.0184 - lr: 0.0010
# Epoch 6/20
# 46/46 [==============================] - 2s 33ms/step - loss: 499.9867 - MAE: 16.7722 - lr: 1.0000e-04
# Epoch 7/20
# 46/46 [==============================] - 2s 33ms/step - loss: 494.4759 - MAE: 16.7595 - lr: 1.0000e-04
# Epoch 8/20
# 46/46 [==============================] - 2s 34ms/step - loss: 491.0749 - MAE: 16.6918 - lr: 1.0000e-04
# Epoch 9/20
# 46/46 [==============================] - 2s 33ms/step - loss: 487.6083 - MAE: 16.5903 - lr: 1.0000e-04
# Epoch 10/20
# 46/46 [==============================] - 2s 33ms/step - loss: 484.7956 - MAE: 16.5774 - lr: 1.0000e-04
# Epoch 11/20
# 46/46 [==============================] - 2s 34ms/step - loss: 483.5374 - MAE: 16.3956 - lr: 1.0000e-04
# Epoch 12/20
# 46/46 [==============================] - 2s 34ms/step - loss: 493.2818 - MAE: 16.6675 - lr: 1.0000e-04
# Epoch 13/20
# 46/46 [==============================] - 2s 33ms/step - loss: 478.0932 - MAE: 16.4230 - lr: 1.0000e-04
# Epoch 14/20
# 46/46 [==============================] - 2s 34ms/step - loss: 473.6442 - MAE: 16.2186 - lr: 1.0000e-04
# Epoch 15/20
# 46/46 [==============================] - 2s 34ms/step - loss: 470.5479 - MAE: 16.1162 - lr: 1.0000e-04
# Epoch 16/20
# 46/46 [==============================] - 2s 33ms/step - loss: 463.6919 - MAE: 15.8826 - lr: 1.0000e-04
# Epoch 17/20
# 46/46 [==============================] - 2s 33ms/step - loss: 461.6212 - MAE: 15.7413 - lr: 1.0000e-04
# Epoch 18/20
# 46/46 [==============================] - 2s 33ms/step - loss: 457.1429 - MAE: 15.6496 - lr: 1.0000e-04
# Epoch 19/20
# 46/46 [==============================] - 2s 33ms/step - loss: 452.2478 - MAE: 15.6357 - lr: 1.0000e-04
# Epoch 20/20
# 46/46 [==============================] - 2s 33ms/step - loss: 450.2407 - MAE: 15.5143 - lr: 1.0000e-04
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_6 on dataset_1 in round 0: MAE=12.65099637015378, MAPE=191274404915494.66, RMSE=16.46773146101084
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_6 on dataset_2 in round 0: MAE=13.5873515883247, MAPE=95511064680339.08, RMSE=17.636201691384834
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_6 on dataset_3 in round 0: MAE=14.642304727449556, MAPE=179473404634795.53, RMSE=18.72919484080234
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_6 on dataset_4 in round 0: MAE=12.161688721430322, MAPE=123938573750358.33, RMSE=15.281879833178213
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_6 on dataset_5 in round 0: MAE=13.255066685222078, MAPE=88801730782653.27, RMSE=16.97999392327315
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_6 on dataset_6 in round 0: MAE=16.0132843123114, MAPE=121951641391957.92, RMSE=20.78121388824671
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_6 on dataset_7 in round 0: MAE=20.315016410655083, MAPE=200872987251224.25, RMSE=25.828777092116894
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_6 on dataset_8 in round 0: MAE=14.60470283628473, MAPE=256870233118240.56, RMSE=18.53717089519498
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_6 on dataset_9 in round 0: MAE=17.02130157034694, MAPE=126213378199876.52, RMSE=22.354397668670448
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_6 on dataset_10 in round 0: MAE=19.314971302401634, MAPE=146973429305265.0, RMSE=25.05921985759648
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_6 on itself in round 0: MAE=16.0132843123114, MAPE=121951641391957.92, RMSE=20.78121388824671
# Epoch 1/20
# 46/46 [==============================] - 4s 33ms/step - loss: 7260.4805 - MAE: 72.3641 - lr: 0.0010
# Epoch 2/20
# 46/46 [==============================] - 2s 33ms/step - loss: 991.5978 - MAE: 25.3157 - lr: 0.0010
# Epoch 3/20
# 46/46 [==============================] - 2s 33ms/step - loss: 574.8646 - MAE: 18.1815 - lr: 0.0010
# Epoch 4/20
# 46/46 [==============================] - 2s 34ms/step - loss: 549.7598 - MAE: 17.9325 - lr: 0.0010
# Epoch 5/20
# 46/46 [==============================] - 2s 33ms/step - loss: 513.9454 - MAE: 16.9854 - lr: 0.0010
# Epoch 6/20
# 46/46 [==============================] - 2s 33ms/step - loss: 460.5611 - MAE: 15.5627 - lr: 1.0000e-04
# Epoch 7/20
# 46/46 [==============================] - 2s 34ms/step - loss: 454.0979 - MAE: 15.5612 - lr: 1.0000e-04
# Epoch 8/20
# 46/46 [==============================] - 2s 33ms/step - loss: 451.8872 - MAE: 15.6551 - lr: 1.0000e-04
# Epoch 9/20
# 46/46 [==============================] - 2s 33ms/step - loss: 447.6616 - MAE: 15.5224 - lr: 1.0000e-04
# Epoch 10/20
# 46/46 [==============================] - 2s 33ms/step - loss: 446.2403 - MAE: 15.6302 - lr: 1.0000e-04
# Epoch 11/20
# 46/46 [==============================] - 2s 34ms/step - loss: 442.1428 - MAE: 15.1438 - lr: 1.0000e-04
# Epoch 12/20
# 46/46 [==============================] - 2s 33ms/step - loss: 444.8411 - MAE: 15.3554 - lr: 1.0000e-04
# Epoch 13/20
# 46/46 [==============================] - 2s 33ms/step - loss: 436.0454 - MAE: 15.3080 - lr: 1.0000e-04
# Epoch 14/20
# 46/46 [==============================] - 2s 34ms/step - loss: 441.7504 - MAE: 15.4735 - lr: 1.0000e-04
# Epoch 15/20
# 46/46 [==============================] - 2s 34ms/step - loss: 428.9955 - MAE: 15.1350 - lr: 1.0000e-04
# Epoch 16/20
# 46/46 [==============================] - 2s 34ms/step - loss: 432.3137 - MAE: 15.1851 - lr: 1.0000e-04
# Epoch 17/20
# 46/46 [==============================] - 2s 33ms/step - loss: 430.2275 - MAE: 15.1624 - lr: 1.0000e-04
# Epoch 18/20
# 46/46 [==============================] - 2s 33ms/step - loss: 424.3810 - MAE: 14.8932 - lr: 1.0000e-04
# Epoch 19/20
# 46/46 [==============================] - 2s 34ms/step - loss: 425.6504 - MAE: 14.8812 - lr: 1.0000e-04
# Epoch 20/20
# 46/46 [==============================] - 2s 34ms/step - loss: 420.2472 - MAE: 14.8537 - lr: 1.0000e-04
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_7 on dataset_1 in round 0: MAE=13.848434978280583, MAPE=123369192225651.64, RMSE=19.82253529548972
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_7 on dataset_2 in round 0: MAE=15.26183485739258, MAPE=39565235044643.44, RMSE=22.023663554282855
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_7 on dataset_3 in round 0: MAE=16.955107325787306, MAPE=169753172033933.38, RMSE=24.104277468607478
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_7 on dataset_4 in round 0: MAE=13.96724155434499, MAPE=64080921596837.33, RMSE=19.429765213307096
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_7 on dataset_5 in round 0: MAE=15.08321056092498, MAPE=112574194363509.75, RMSE=21.883658848328878
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_7 on dataset_6 in round 0: MAE=17.51072597234045, MAPE=92184935152526.22, RMSE=24.437791334119517
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_7 on dataset_7 in round 0: MAE=14.347643673516243, MAPE=196655325897273.3, RMSE=20.574270653754713
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_7 on dataset_8 in round 0: MAE=14.985409863353354, MAPE=167398013880839.72, RMSE=21.079910784554432
# 20/20 [==============================] - 0s 7ms/step
# Evaluation results for dataset_7 on dataset_9 in round 0: MAE=15.996970593544123, MAPE=70842081751245.44, RMSE=22.482249578554864
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_7 on dataset_10 in round 0: MAE=15.74540383964777, MAPE=97516709872461.92, RMSE=22.162933006597513
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_7 on itself in round 0: MAE=14.347643673516243, MAPE=196655325897273.3, RMSE=20.574270653754713
# Epoch 1/20
# 46/46 [==============================] - 4s 34ms/step - loss: 6914.1948 - MAE: 70.7077 - lr: 0.0010
# Epoch 2/20
# 46/46 [==============================] - 2s 34ms/step - loss: 837.0160 - MAE: 23.3524 - lr: 0.0010
# Epoch 3/20
# 46/46 [==============================] - 2s 34ms/step - loss: 450.8060 - MAE: 16.7405 - lr: 0.0010
# Epoch 4/20
# 46/46 [==============================] - 2s 33ms/step - loss: 419.1718 - MAE: 15.6735 - lr: 0.0010
# Epoch 5/20
# 46/46 [==============================] - 2s 33ms/step - loss: 395.5426 - MAE: 15.3357 - lr: 0.0010
# Epoch 6/20
# 46/46 [==============================] - 2s 34ms/step - loss: 366.2660 - MAE: 14.5573 - lr: 1.0000e-04
# Epoch 7/20
# 46/46 [==============================] - 2s 34ms/step - loss: 358.7715 - MAE: 14.2392 - lr: 1.0000e-04
# Epoch 8/20
# 46/46 [==============================] - 2s 33ms/step - loss: 356.9959 - MAE: 14.2032 - lr: 1.0000e-04
# Epoch 9/20
# 46/46 [==============================] - 2s 33ms/step - loss: 352.5489 - MAE: 14.1211 - lr: 1.0000e-04
# Epoch 10/20
# 46/46 [==============================] - 2s 34ms/step - loss: 351.8403 - MAE: 14.0625 - lr: 1.0000e-04
# Epoch 11/20
# 46/46 [==============================] - 2s 33ms/step - loss: 346.9242 - MAE: 13.9617 - lr: 1.0000e-04
# Epoch 12/20
# 46/46 [==============================] - 2s 33ms/step - loss: 343.1500 - MAE: 13.9145 - lr: 1.0000e-04
# Epoch 13/20
# 46/46 [==============================] - 2s 33ms/step - loss: 341.8105 - MAE: 13.8761 - lr: 1.0000e-04
# Epoch 14/20
# 46/46 [==============================] - 2s 34ms/step - loss: 334.6345 - MAE: 13.6861 - lr: 1.0000e-04
# Epoch 15/20
# 46/46 [==============================] - 2s 34ms/step - loss: 329.5366 - MAE: 13.5007 - lr: 1.0000e-04
# Epoch 16/20
# 46/46 [==============================] - 2s 34ms/step - loss: 324.5951 - MAE: 13.4527 - lr: 1.0000e-04
# Epoch 17/20
# 46/46 [==============================] - 2s 34ms/step - loss: 322.4174 - MAE: 13.4315 - lr: 1.0000e-04
# Epoch 18/20
# 46/46 [==============================] - 2s 33ms/step - loss: 322.3044 - MAE: 13.4310 - lr: 1.0000e-04
# Epoch 19/20
# 46/46 [==============================] - 2s 34ms/step - loss: 323.1830 - MAE: 13.5879 - lr: 1.0000e-04
# Epoch 20/20
# 46/46 [==============================] - 2s 33ms/step - loss: 310.6708 - MAE: 13.1813 - lr: 1.0000e-04
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_8 on dataset_1 in round 0: MAE=12.073419386812866, MAPE=262859449658988.62, RMSE=16.99575692455434
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_8 on dataset_2 in round 0: MAE=12.619527721250963, MAPE=108131707256832.27, RMSE=17.066943232660705
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_8 on dataset_3 in round 0: MAE=14.229722344432393, MAPE=181181241310411.84, RMSE=20.01016799490733
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_8 on dataset_4 in round 0: MAE=11.955064072555023, MAPE=174737472907744.1, RMSE=16.891485209081115
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_8 on dataset_5 in round 0: MAE=11.575460626928795, MAPE=101700619068596.6, RMSE=16.489198905747735
# 20/20 [==============================] - 0s 7ms/step
# Evaluation results for dataset_8 on dataset_6 in round 0: MAE=15.563130301689679, MAPE=127206126238341.56, RMSE=21.935765658849693
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_8 on dataset_7 in round 0: MAE=20.21317264490636, MAPE=242966896650693.6, RMSE=27.16340052132635
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_8 on dataset_8 in round 0: MAE=12.421256468253683, MAPE=327281836767612.8, RMSE=17.00522833948994
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_8 on dataset_9 in round 0: MAE=16.18326668939606, MAPE=177922316051769.03, RMSE=22.42295332972368
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_8 on dataset_10 in round 0: MAE=19.313808150637534, MAPE=157240399687971.0, RMSE=26.2637406359376
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_8 on itself in round 0: MAE=12.421256468253683, MAPE=327281836767612.8, RMSE=17.00522833948994
# Epoch 1/20
# 46/46 [==============================] - 4s 33ms/step - loss: 6689.0825 - MAE: 69.4734 - lr: 0.0010
# Epoch 2/20
# 46/46 [==============================] - 2s 33ms/step - loss: 875.8002 - MAE: 23.3063 - lr: 0.0010
# Epoch 3/20
# 46/46 [==============================] - 2s 34ms/step - loss: 547.3904 - MAE: 17.9691 - lr: 0.0010
# Epoch 4/20
# 46/46 [==============================] - 2s 34ms/step - loss: 509.6322 - MAE: 17.2163 - lr: 0.0010
# Epoch 5/20
# 46/46 [==============================] - 2s 33ms/step - loss: 540.1639 - MAE: 17.9778 - lr: 0.0010
# Epoch 6/20
# 46/46 [==============================] - 2s 33ms/step - loss: 470.4862 - MAE: 16.3351 - lr: 1.0000e-04
# Epoch 7/20
# 46/46 [==============================] - 2s 34ms/step - loss: 465.6682 - MAE: 15.9828 - lr: 1.0000e-04
# Epoch 8/20
# 46/46 [==============================] - 2s 33ms/step - loss: 460.5246 - MAE: 15.9384 - lr: 1.0000e-04
# Epoch 9/20
# 46/46 [==============================] - 2s 34ms/step - loss: 463.3095 - MAE: 16.1518 - lr: 1.0000e-04
# Epoch 10/20
# 46/46 [==============================] - 2s 34ms/step - loss: 461.2778 - MAE: 15.7520 - lr: 1.0000e-04
# Epoch 11/20
# 46/46 [==============================] - 2s 33ms/step - loss: 456.9579 - MAE: 15.9261 - lr: 1.0000e-04
# Epoch 12/20
# 46/46 [==============================] - 2s 33ms/step - loss: 456.2368 - MAE: 15.8450 - lr: 1.0000e-04
# Epoch 13/20
# 46/46 [==============================] - 2s 33ms/step - loss: 452.7850 - MAE: 15.6052 - lr: 1.0000e-04
# Epoch 14/20
# 46/46 [==============================] - 2s 34ms/step - loss: 450.2006 - MAE: 15.7382 - lr: 1.0000e-04
# Epoch 15/20
# 46/46 [==============================] - 2s 33ms/step - loss: 453.9407 - MAE: 15.7604 - lr: 1.0000e-04
# Epoch 16/20
# 46/46 [==============================] - 2s 33ms/step - loss: 446.4509 - MAE: 15.5942 - lr: 1.0000e-04
# Epoch 17/20
# 46/46 [==============================] - 2s 33ms/step - loss: 445.7661 - MAE: 15.6241 - lr: 1.0000e-04
# Epoch 18/20
# 46/46 [==============================] - 2s 34ms/step - loss: 446.3520 - MAE: 15.6204 - lr: 1.0000e-04
# Epoch 19/20
# 46/46 [==============================] - 2s 34ms/step - loss: 443.4042 - MAE: 15.4815 - lr: 1.0000e-04
# Epoch 20/20
# 46/46 [==============================] - 2s 33ms/step - loss: 437.7667 - MAE: 15.4622 - lr: 1.0000e-04
# 20/20 [==============================] - 1s 6ms/step
# Evaluation results for dataset_9 on dataset_1 in round 0: MAE=11.548883220057496, MAPE=78701843498204.22, RMSE=16.612576479771437
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_9 on dataset_2 in round 0: MAE=13.934409338361034, MAPE=44075693347960.99, RMSE=19.327819229176278
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_9 on dataset_3 in round 0: MAE=15.985468320006893, MAPE=107823311778976.8, RMSE=21.95009869904389
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_9 on dataset_4 in round 0: MAE=13.051939231320999, MAPE=51313292611299.75, RMSE=17.6029885308794
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_9 on dataset_5 in round 0: MAE=13.098782766616402, MAPE=45024497765056.98, RMSE=18.71841479061158
# 20/20 [==============================] - 0s 7ms/step
# Evaluation results for dataset_9 on dataset_6 in round 0: MAE=16.827012680844074, MAPE=70374297625886.52, RMSE=22.653940818874926
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_9 on dataset_7 in round 0: MAE=17.521439023087215, MAPE=94237646773782.58, RMSE=23.337678247347917
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_9 on dataset_8 in round 0: MAE=14.711113148629185, MAPE=142794736058765.28, RMSE=19.87956651675494
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_9 on dataset_9 in round 0: MAE=15.536799568159323, MAPE=52614356334205.16, RMSE=21.47077504415456
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_9 on dataset_10 in round 0: MAE=17.047124125688306, MAPE=87695297751793.42, RMSE=23.203839119859545
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_9 on itself in round 0: MAE=15.536799568159323, MAPE=52614356334205.16, RMSE=21.47077504415456
# Epoch 1/20
# 46/46 [==============================] - 4s 33ms/step - loss: 7798.1792 - MAE: 74.6703 - lr: 0.0010
# Epoch 2/20
# 46/46 [==============================] - 2s 33ms/step - loss: 1364.4103 - MAE: 30.6085 - lr: 0.0010
# Epoch 3/20
# 46/46 [==============================] - 2s 33ms/step - loss: 658.5771 - MAE: 20.6033 - lr: 0.0010
# Epoch 4/20
# 46/46 [==============================] - 2s 34ms/step - loss: 537.7468 - MAE: 18.1857 - lr: 0.0010
# Epoch 5/20
# 46/46 [==============================] - 2s 34ms/step - loss: 545.2894 - MAE: 18.2708 - lr: 0.0010
# Epoch 6/20
# 46/46 [==============================] - 2s 33ms/step - loss: 529.8784 - MAE: 18.0771 - lr: 1.0000e-04
# Epoch 7/20
# 46/46 [==============================] - 2s 34ms/step - loss: 505.4207 - MAE: 17.2516 - lr: 1.0000e-04
# Epoch 8/20
# 46/46 [==============================] - 2s 33ms/step - loss: 503.3821 - MAE: 17.2991 - lr: 1.0000e-04
# Epoch 9/20
# 46/46 [==============================] - 2s 33ms/step - loss: 501.5645 - MAE: 17.1876 - lr: 1.0000e-04
# Epoch 10/20
# 46/46 [==============================] - 2s 33ms/step - loss: 503.2603 - MAE: 17.2232 - lr: 1.0000e-04
# Epoch 11/20
# 46/46 [==============================] - 2s 33ms/step - loss: 503.5638 - MAE: 16.9961 - lr: 1.0000e-04
# Epoch 12/20
# 46/46 [==============================] - 2s 33ms/step - loss: 496.7824 - MAE: 16.9156 - lr: 1.0000e-04
# Epoch 13/20
# 46/46 [==============================] - 2s 33ms/step - loss: 495.7539 - MAE: 17.0971 - lr: 1.0000e-04
# Epoch 14/20
# 46/46 [==============================] - 2s 34ms/step - loss: 495.1274 - MAE: 16.8593 - lr: 1.0000e-04
# Epoch 15/20
# 46/46 [==============================] - 2s 33ms/step - loss: 495.9601 - MAE: 16.9629 - lr: 1.0000e-04
# Epoch 16/20
# 46/46 [==============================] - 2s 33ms/step - loss: 493.1422 - MAE: 16.8824 - lr: 1.0000e-04
# Epoch 17/20
# 46/46 [==============================] - 2s 33ms/step - loss: 495.1438 - MAE: 16.8125 - lr: 1.0000e-04
# Epoch 18/20
# 46/46 [==============================] - 2s 33ms/step - loss: 492.8723 - MAE: 16.9153 - lr: 1.0000e-04
# Epoch 19/20
# 46/46 [==============================] - 2s 33ms/step - loss: 490.0802 - MAE: 16.9642 - lr: 1.0000e-04
# Epoch 20/20
# 46/46 [==============================] - 2s 33ms/step - loss: 487.8265 - MAE: 16.7504 - lr: 1.0000e-04
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_10 on dataset_1 in round 0: MAE=13.258129391078995, MAPE=67632066386737.445, RMSE=17.616020768967477
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_10 on dataset_2 in round 0: MAE=15.524303672483164, MAPE=34997408745197.65, RMSE=20.63465650121515
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_10 on dataset_3 in round 0: MAE=17.05400717489554, MAPE=126600048415918.03, RMSE=22.33778632697021
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_10 on dataset_4 in round 0: MAE=14.601199753835244, MAPE=38367583804447.734, RMSE=18.78516016444678
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_10 on dataset_5 in round 0: MAE=15.031615678443663, MAPE=72044725066968.98, RMSE=19.917751003545153
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_10 on dataset_6 in round 0: MAE=17.98196255679277, MAPE=91256844065188.52, RMSE=23.166856226025367
# 20/20 [==============================] - 0s 7ms/step
# Evaluation results for dataset_10 on dataset_7 in round 0: MAE=17.290058848545893, MAPE=102619186985314.25, RMSE=22.196471880969572
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_10 on dataset_8 in round 0: MAE=16.155159782130806, MAPE=132792166601293.19, RMSE=20.656933643392243
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_10 on dataset_9 in round 0: MAE=16.825149371509887, MAPE=32905877790151.2, RMSE=21.88744098803197
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_10 on dataset_10 in round 0: MAE=16.895512690467218, MAPE=57774845807186.85, RMSE=22.06432080764592
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_10 on itself in round 0: MAE=16.895512690467218, MAPE=57774845807186.85, RMSE=22.06432080764592
# 20/20 [==============================] - 0s 6ms/step
# Global evaluation results for dataset_1 in round 0: MAE=13.848434978280583, MAPE=123369192225651.64, RMSE=19.82253529548972
# 20/20 [==============================] - 0s 7ms/step
# Global evaluation results for dataset_2 in round 0: MAE=15.26183485739258, MAPE=39565235044643.44, RMSE=22.023663554282855
# 20/20 [==============================] - 0s 6ms/step
# Global evaluation results for dataset_3 in round 0: MAE=16.955107325787306, MAPE=169753172033933.38, RMSE=24.104277468607478
# 20/20 [==============================] - 0s 6ms/step
# Global evaluation results for dataset_4 in round 0: MAE=13.96724155434499, MAPE=64080921596837.33, RMSE=19.429765213307096
# 20/20 [==============================] - 0s 6ms/step
# Global evaluation results for dataset_5 in round 0: MAE=15.08321056092498, MAPE=112574194363509.75, RMSE=21.883658848328878
# 20/20 [==============================] - 0s 6ms/step
# Global evaluation results for dataset_6 in round 0: MAE=17.51072597234045, MAPE=92184935152526.22, RMSE=24.437791334119517
# 20/20 [==============================] - 0s 6ms/step
# Global evaluation results for dataset_7 in round 0: MAE=14.347643673516243, MAPE=196655325897273.3, RMSE=20.574270653754713
# 20/20 [==============================] - 0s 6ms/step
# Global evaluation results for dataset_8 in round 0: MAE=14.985409863353354, MAPE=167398013880839.72, RMSE=21.079910784554432
# 20/20 [==============================] - 0s 6ms/step
# Global evaluation results for dataset_9 in round 0: MAE=15.996970593544123, MAPE=70842081751245.44, RMSE=22.482249578554864
# 20/20 [==============================] - 0s 6ms/step
# Global evaluation results for dataset_10 in round 0: MAE=15.74540383964777, MAPE=97516709872461.92, RMSE=22.162933006597513
# Round 1
# Epoch 1/20
# 46/46 [==============================] - 4s 33ms/step - loss: 423.3281 - MAE: 15.6842 - lr: 0.0010
# Epoch 2/20
# 46/46 [==============================] - 2s 34ms/step - loss: 289.7676 - MAE: 12.3510 - lr: 0.0010
# Epoch 3/20
# 46/46 [==============================] - 2s 33ms/step - loss: 280.5119 - MAE: 12.1215 - lr: 0.0010
# Epoch 4/20
# 46/46 [==============================] - 2s 34ms/step - loss: 277.5309 - MAE: 12.4052 - lr: 0.0010
# Epoch 5/20
# 46/46 [==============================] - 2s 33ms/step - loss: 260.6935 - MAE: 11.7305 - lr: 0.0010
# Epoch 6/20
# 46/46 [==============================] - 2s 33ms/step - loss: 231.8764 - MAE: 10.4793 - lr: 1.0000e-04
# Epoch 7/20
# 46/46 [==============================] - 2s 33ms/step - loss: 229.2467 - MAE: 10.5710 - lr: 1.0000e-04
# Epoch 8/20
# 46/46 [==============================] - 2s 33ms/step - loss: 228.2481 - MAE: 10.4469 - lr: 1.0000e-04
# Epoch 9/20
# 46/46 [==============================] - 2s 34ms/step - loss: 226.0000 - MAE: 10.3076 - lr: 1.0000e-04
# Epoch 10/20
# 46/46 [==============================] - 2s 33ms/step - loss: 224.9476 - MAE: 10.3356 - lr: 1.0000e-04
# Epoch 11/20
# 46/46 [==============================] - 2s 34ms/step - loss: 226.2671 - MAE: 10.5104 - lr: 1.0000e-04
# Epoch 12/20
# 46/46 [==============================] - 2s 34ms/step - loss: 223.6729 - MAE: 10.3003 - lr: 1.0000e-04
# Epoch 13/20
# 46/46 [==============================] - 2s 34ms/step - loss: 222.6875 - MAE: 10.1182 - lr: 1.0000e-04
# Epoch 14/20
# 46/46 [==============================] - 2s 33ms/step - loss: 225.7793 - MAE: 10.5319 - lr: 1.0000e-04
# Epoch 15/20
# 46/46 [==============================] - 2s 33ms/step - loss: 220.5105 - MAE: 10.1431 - lr: 1.0000e-04
# Epoch 16/20
# 46/46 [==============================] - 2s 34ms/step - loss: 220.5407 - MAE: 10.2688 - lr: 1.0000e-04
# Epoch 17/20
# 46/46 [==============================] - 2s 33ms/step - loss: 219.1248 - MAE: 10.3278 - lr: 1.0000e-04
# Epoch 18/20
# 46/46 [==============================] - 2s 34ms/step - loss: 219.8631 - MAE: 10.2061 - lr: 1.0000e-04
# Epoch 19/20
# 46/46 [==============================] - 2s 34ms/step - loss: 216.3703 - MAE: 10.1261 - lr: 1.0000e-04
# Epoch 20/20
# 46/46 [==============================] - 2s 33ms/step - loss: 215.1583 - MAE: 10.0069 - lr: 1.0000e-04
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_1 on dataset_1 in round 1: MAE=10.41706120967865, MAPE=156493631389166.78, RMSE=14.596797397143474
# 20/20 [==============================] - 0s 6ms/step
# ...
# 20/20 [==============================] - 0s 9ms/step
# Evaluation results for dataset_7 on dataset_5 in round 19: MAE=16.15212128986642, MAPE=52989372375053.516, RMSE=23.488140224304484
# 20/20 [==============================] - 0s 8ms/step
# Evaluation results for dataset_7 on dataset_6 in round 19: MAE=17.048220624831266, MAPE=94511555017270.11, RMSE=25.58780629344187
# 20/20 [==============================] - 0s 7ms/step
# Evaluation results for dataset_7 on dataset_7 in round 19: MAE=11.838253549304648, MAPE=134970783558270.73, RMSE=17.4132216610816
# 20/20 [==============================] - 0s 9ms/step
# Evaluation results for dataset_7 on dataset_8 in round 19: MAE=14.27859301174207, MAPE=158640471485928.28, RMSE=21.45838371134471
# 20/20 [==============================] - 0s 8ms/step
# Evaluation results for dataset_7 on dataset_9 in round 19: MAE=17.427044768325732, MAPE=44482132382576.41, RMSE=24.643487432511314
# 20/20 [==============================] - 0s 8ms/step
# Evaluation results for dataset_7 on dataset_10 in round 19: MAE=14.27902459867539, MAPE=66427806879453.586, RMSE=20.29529470235541
# 20/20 [==============================] - 0s 9ms/step
# Evaluation results for dataset_7 on itself in round 19: MAE=11.838253549304648, MAPE=134970783558270.73, RMSE=17.4132216610816
# Epoch 1/20
# 46/46 [==============================] - 6s 43ms/step - loss: 236.2044 - MAE: 11.1081 - lr: 0.0010
# Epoch 2/20
# 46/46 [==============================] - 2s 41ms/step - loss: 194.7780 - MAE: 9.8212 - lr: 0.0010
# Epoch 3/20
# 46/46 [==============================] - 2s 41ms/step - loss: 190.5143 - MAE: 9.6745 - lr: 0.0010
# Epoch 4/20
# 46/46 [==============================] - 2s 41ms/step - loss: 186.4371 - MAE: 9.6661 - lr: 0.0010
# Epoch 5/20
# 46/46 [==============================] - 2s 39ms/step - loss: 184.1311 - MAE: 9.6143 - lr: 0.0010
# Epoch 6/20
# 46/46 [==============================] - 2s 43ms/step - loss: 178.9259 - MAE: 9.5776 - lr: 1.0000e-04
# Epoch 7/20
# 46/46 [==============================] - 2s 43ms/step - loss: 162.8079 - MAE: 8.8518 - lr: 1.0000e-04
# Epoch 8/20
# 46/46 [==============================] - 2s 40ms/step - loss: 160.4772 - MAE: 8.6808 - lr: 1.0000e-04
# Epoch 9/20
# 46/46 [==============================] - 2s 41ms/step - loss: 157.7253 - MAE: 8.5675 - lr: 1.0000e-04
# Epoch 10/20
# 46/46 [==============================] - 2s 41ms/step - loss: 156.2603 - MAE: 8.4776 - lr: 1.0000e-04
# Epoch 11/20
# 46/46 [==============================] - 2s 41ms/step - loss: 158.2169 - MAE: 8.6757 - lr: 1.0000e-04
# Epoch 12/20
# 46/46 [==============================] - 2s 42ms/step - loss: 152.9637 - MAE: 8.3538 - lr: 1.0000e-04
# Epoch 13/20
# 46/46 [==============================] - 2s 41ms/step - loss: 151.9274 - MAE: 8.2722 - lr: 1.0000e-04
# Epoch 14/20
# 46/46 [==============================] - 2s 39ms/step - loss: 150.8737 - MAE: 8.2978 - lr: 1.0000e-04
# Epoch 15/20
# 46/46 [==============================] - 2s 39ms/step - loss: 150.1889 - MAE: 8.2275 - lr: 1.0000e-04
# Epoch 16/20
# 46/46 [==============================] - 2s 39ms/step - loss: 149.6145 - MAE: 8.2556 - lr: 1.0000e-04
# Epoch 17/20
# 46/46 [==============================] - 2s 43ms/step - loss: 148.3363 - MAE: 8.2313 - lr: 1.0000e-04
# Epoch 18/20
# 46/46 [==============================] - 2s 43ms/step - loss: 147.8765 - MAE: 8.2406 - lr: 1.0000e-04
# Epoch 19/20
# 46/46 [==============================] - 2s 40ms/step - loss: 147.0411 - MAE: 8.1480 - lr: 1.0000e-04
# Epoch 20/20
# 46/46 [==============================] - 2s 39ms/step - loss: 145.3720 - MAE: 8.1675 - lr: 1.0000e-04
# 20/20 [==============================] - 1s 8ms/step
# Evaluation results for dataset_8 on dataset_1 in round 19: MAE=13.61564603414212, MAPE=128653897960658.36, RMSE=20.157972465902176
# 20/20 [==============================] - 0s 7ms/step
# Evaluation results for dataset_8 on dataset_2 in round 19: MAE=12.067930808167466, MAPE=71891434978137.16, RMSE=17.653149001068016
# 20/20 [==============================] - 0s 7ms/step
# Evaluation results for dataset_8 on dataset_3 in round 19: MAE=11.53076023277443, MAPE=116888846348069.89, RMSE=17.05624671389029
# 20/20 [==============================] - 0s 9ms/step
# Evaluation results for dataset_8 on dataset_4 in round 19: MAE=10.985404392436555, MAPE=58842226306112.805, RMSE=17.57102996981204
# 20/20 [==============================] - 0s 7ms/step
# Evaluation results for dataset_8 on dataset_5 in round 19: MAE=8.69884133801129, MAPE=61774242279973.4, RMSE=12.545669965931625
# 20/20 [==============================] - 0s 7ms/step
# Evaluation results for dataset_8 on dataset_6 in round 19: MAE=13.931455054171444, MAPE=96007783892823.55, RMSE=21.705476135008627
# 20/20 [==============================] - 0s 8ms/step
# Evaluation results for dataset_8 on dataset_7 in round 19: MAE=22.981826808032775, MAPE=110333957809094.39, RMSE=33.532794239221005
# 20/20 [==============================] - 0s 7ms/step
# Evaluation results for dataset_8 on dataset_8 in round 19: MAE=8.506640531712472, MAPE=183048172178483.44, RMSE=13.291410534289831
# 20/20 [==============================] - 0s 8ms/step
# Evaluation results for dataset_8 on dataset_9 in round 19: MAE=16.687813922161048, MAPE=63880764151831.42, RMSE=24.283208794289056
# 20/20 [==============================] - 0s 7ms/step
# Evaluation results for dataset_8 on dataset_10 in round 19: MAE=20.890739982743415, MAPE=80336530255845.88, RMSE=31.2770362796545
# 20/20 [==============================] - 0s 8ms/step
# Evaluation results for dataset_8 on itself in round 19: MAE=8.506640531712472, MAPE=183048172178483.44, RMSE=13.291410534289831
# Epoch 1/20
# 46/46 [==============================] - 6s 40ms/step - loss: 428.6419 - MAE: 14.7822 - lr: 0.0010
# Epoch 2/20
# 46/46 [==============================] - 2s 39ms/step - loss: 385.4555 - MAE: 14.2811 - lr: 0.0010
# Epoch 3/20
# 46/46 [==============================] - 2s 41ms/step - loss: 359.9480 - MAE: 13.7097 - lr: 0.0010
# Epoch 4/20
# 46/46 [==============================] - 2s 42ms/step - loss: 360.4976 - MAE: 13.6000 - lr: 0.0010
# Epoch 5/20
# 46/46 [==============================] - 2s 41ms/step - loss: 337.2704 - MAE: 12.9169 - lr: 0.0010
# Epoch 6/20
# 46/46 [==============================] - 2s 41ms/step - loss: 325.3829 - MAE: 12.6913 - lr: 1.0000e-04
# Epoch 7/20
# 46/46 [==============================] - 2s 41ms/step - loss: 306.4789 - MAE: 12.0774 - lr: 1.0000e-04
# Epoch 8/20
# 46/46 [==============================] - 2s 40ms/step - loss: 304.8990 - MAE: 11.9975 - lr: 1.0000e-04
# Epoch 9/20
# 46/46 [==============================] - 2s 40ms/step - loss: 302.3267 - MAE: 12.0529 - lr: 1.0000e-04
# Epoch 10/20
# 46/46 [==============================] - 2s 42ms/step - loss: 299.9330 - MAE: 11.9458 - lr: 1.0000e-04
# Epoch 11/20
# 46/46 [==============================] - 2s 40ms/step - loss: 299.1017 - MAE: 11.9316 - lr: 1.0000e-04
# Epoch 12/20
# 46/46 [==============================] - 2s 40ms/step - loss: 297.1070 - MAE: 11.8317 - lr: 1.0000e-04
# Epoch 13/20
# 46/46 [==============================] - 2s 40ms/step - loss: 293.9886 - MAE: 11.6410 - lr: 1.0000e-04
# Epoch 14/20
# 46/46 [==============================] - 2s 40ms/step - loss: 292.8986 - MAE: 11.6775 - lr: 1.0000e-04
# Epoch 15/20
# 46/46 [==============================] - 2s 41ms/step - loss: 292.3987 - MAE: 11.7988 - lr: 1.0000e-04
# Epoch 16/20
# 46/46 [==============================] - 2s 41ms/step - loss: 289.2348 - MAE: 11.5489 - lr: 1.0000e-04
# Epoch 17/20
# 46/46 [==============================] - 2s 39ms/step - loss: 286.6210 - MAE: 11.4531 - lr: 1.0000e-04
# Epoch 18/20
# 46/46 [==============================] - 2s 40ms/step - loss: 286.3602 - MAE: 11.4864 - lr: 1.0000e-04
# Epoch 19/20
# 46/46 [==============================] - 2s 41ms/step - loss: 284.8931 - MAE: 11.4927 - lr: 1.0000e-04
# Epoch 20/20
# 46/46 [==============================] - 2s 43ms/step - loss: 281.6193 - MAE: 11.3960 - lr: 1.0000e-04
# 20/20 [==============================] - 1s 9ms/step
# Evaluation results for dataset_9 on dataset_1 in round 19: MAE=9.98993631325939, MAPE=125781043600124.45, RMSE=14.866752227542
# 20/20 [==============================] - 0s 7ms/step
# Evaluation results for dataset_9 on dataset_2 in round 19: MAE=12.418032036074143, MAPE=72914965928409.38, RMSE=18.05671883377859
# 20/20 [==============================] - 0s 8ms/step
# Evaluation results for dataset_9 on dataset_3 in round 19: MAE=13.814427900006198, MAPE=197762313821109.84, RMSE=20.287869772211067
# 20/20 [==============================] - 0s 8ms/step
# Evaluation results for dataset_9 on dataset_4 in round 19: MAE=11.15970863452443, MAPE=51777992981363.67, RMSE=16.21932512908782
# 20/20 [==============================] - 0s 8ms/step
# Evaluation results for dataset_9 on dataset_5 in round 19: MAE=11.29888538513122, MAPE=132385603539956.62, RMSE=16.550883384634364
# 20/20 [==============================] - 0s 9ms/step
# Evaluation results for dataset_9 on dataset_6 in round 19: MAE=14.325925639449876, MAPE=122546022540521.53, RMSE=21.069319694449458
# 20/20 [==============================] - 0s 7ms/step
# Evaluation results for dataset_9 on dataset_7 in round 19: MAE=16.897492094841066, MAPE=133738951898060.95, RMSE=23.43394420591996
# 20/20 [==============================] - 0s 7ms/step
# Evaluation results for dataset_9 on dataset_8 in round 19: MAE=11.791361391833217, MAPE=131588278248099.17, RMSE=17.259172390310454
# 20/20 [==============================] - 0s 8ms/step
# Evaluation results for dataset_9 on dataset_9 in round 19: MAE=12.573855334607003, MAPE=63970623679632.13, RMSE=18.947223994668104
# 20/20 [==============================] - 0s 7ms/step
# Evaluation results for dataset_9 on dataset_10 in round 19: MAE=15.380083801861732, MAPE=76428143787398.03, RMSE=21.55366622554982
# 20/20 [==============================] - 0s 9ms/step
# Evaluation results for dataset_9 on itself in round 19: MAE=12.573855334607003, MAPE=63970623679632.13, RMSE=18.947223994668104
# Epoch 1/20
# 46/46 [==============================] - 6s 40ms/step - loss: 448.5655 - MAE: 15.6477 - lr: 0.0010
# Epoch 2/20
# 46/46 [==============================] - 2s 41ms/step - loss: 308.9978 - MAE: 12.8093 - lr: 0.0010
# Epoch 3/20
# 46/46 [==============================] - 2s 40ms/step - loss: 292.7029 - MAE: 12.3594 - lr: 0.0010
# Epoch 4/20
# 46/46 [==============================] - 2s 41ms/step - loss: 279.4026 - MAE: 11.8766 - lr: 0.0010
# Epoch 5/20
# 46/46 [==============================] - 2s 39ms/step - loss: 280.4033 - MAE: 12.1946 - lr: 0.0010
# Epoch 6/20
# 46/46 [==============================] - 2s 40ms/step - loss: 241.3965 - MAE: 10.9868 - lr: 1.0000e-04
# Epoch 7/20
# 46/46 [==============================] - 2s 41ms/step - loss: 219.9684 - MAE: 10.2653 - lr: 1.0000e-04
# Epoch 8/20
# 46/46 [==============================] - 2s 43ms/step - loss: 215.1169 - MAE: 10.2582 - lr: 1.0000e-04
# Epoch 9/20
# 46/46 [==============================] - 2s 40ms/step - loss: 213.5008 - MAE: 10.1319 - lr: 1.0000e-04
# Epoch 10/20
# 46/46 [==============================] - 2s 39ms/step - loss: 210.5646 - MAE: 10.0130 - lr: 1.0000e-04
# Epoch 11/20
# 46/46 [==============================] - 2s 39ms/step - loss: 208.1124 - MAE: 10.0524 - lr: 1.0000e-04
# Epoch 12/20
# 46/46 [==============================] - 2s 41ms/step - loss: 208.9888 - MAE: 10.0075 - lr: 1.0000e-04
# Epoch 13/20
# 46/46 [==============================] - 2s 42ms/step - loss: 206.3734 - MAE: 9.9381 - lr: 1.0000e-04
# Epoch 14/20
# 46/46 [==============================] - 2s 41ms/step - loss: 203.7730 - MAE: 9.8305 - lr: 1.0000e-04
# Epoch 15/20
# 46/46 [==============================] - 2s 39ms/step - loss: 202.0661 - MAE: 9.7939 - lr: 1.0000e-04
# Epoch 16/20
# 46/46 [==============================] - 2s 39ms/step - loss: 200.1863 - MAE: 9.7073 - lr: 1.0000e-04
# Epoch 17/20
# 46/46 [==============================] - 2s 40ms/step - loss: 198.0805 - MAE: 9.7273 - lr: 1.0000e-04
# Epoch 18/20
# 46/46 [==============================] - 2s 41ms/step - loss: 200.3204 - MAE: 9.8317 - lr: 1.0000e-04
# Epoch 19/20
# 46/46 [==============================] - 2s 41ms/step - loss: 197.2598 - MAE: 9.7303 - lr: 1.0000e-04
# Epoch 20/20
# 46/46 [==============================] - 2s 39ms/step - loss: 193.1829 - MAE: 9.5036 - lr: 1.0000e-04
# 20/20 [==============================] - 0s 7ms/step
# Evaluation results for dataset_10 on dataset_1 in round 19: MAE=13.573869315073832, MAPE=48708698725010.625, RMSE=21.387663770695077
# 20/20 [==============================] - 0s 7ms/step
# Evaluation results for dataset_10 on dataset_2 in round 19: MAE=15.383949482190589, MAPE=45404192128521.35, RMSE=23.274973994128178
# 20/20 [==============================] - 0s 7ms/step
# Evaluation results for dataset_10 on dataset_3 in round 19: MAE=13.421611787044174, MAPE=82796895548232.64, RMSE=21.448781448217243
# 20/20 [==============================] - 0s 7ms/step
# Evaluation results for dataset_10 on dataset_4 in round 19: MAE=14.352639293824721, MAPE=40790454476072.41, RMSE=22.93197753601622
# 20/20 [==============================] - 0s 8ms/step
# Evaluation results for dataset_10 on dataset_5 in round 19: MAE=11.514401483420217, MAPE=28283814139345.06, RMSE=17.39723380749132
# 20/20 [==============================] - 0s 7ms/step
# Evaluation results for dataset_10 on dataset_6 in round 19: MAE=15.943932287912569, MAPE=58140561176400.93, RMSE=25.958488954025906
# 20/20 [==============================] - 0s 8ms/step
# Evaluation results for dataset_10 on dataset_7 in round 19: MAE=14.464954538183566, MAPE=65684920152586.96, RMSE=21.482214803172027
# 20/20 [==============================] - 0s 7ms/step
# Evaluation results for dataset_10 on dataset_8 in round 19: MAE=13.247212767023262, MAPE=84297852183626.67, RMSE=20.68511053026432
# 20/20 [==============================] - 0s 8ms/step
# Evaluation results for dataset_10 on dataset_9 in round 19: MAE=16.303414203046017, MAPE=35962291969082.16, RMSE=25.596444492912223
# 20/20 [==============================] - 0s 7ms/step
# Evaluation results for dataset_10 on dataset_10 in round 19: MAE=11.015915458625363, MAPE=51158216187957.03, RMSE=16.460751106130893
# 20/20 [==============================] - 0s 7ms/step
# Evaluation results for dataset_10 on itself in round 19: MAE=11.015915458625363, MAPE=51158216187957.03, RMSE=16.460751106130893
# 20/20 [==============================] - 0s 9ms/step
# Global evaluation results for dataset_1 in round 19: MAE=13.966831012139991, MAPE=80065797875609.66, RMSE=21.36988973406474
# 20/20 [==============================] - 0s 8ms/step
# Global evaluation results for dataset_2 in round 19: MAE=13.75165573060994, MAPE=19260427406122.824, RMSE=20.3105991307349
# 20/20 [==============================] - 0s 7ms/step
# Global evaluation results for dataset_3 in round 19: MAE=10.176505967565422, MAPE=107092127422302.11, RMSE=15.451554058952201
# 20/20 [==============================] - 0s 9ms/step
# Global evaluation results for dataset_4 in round 19: MAE=12.939151397333006, MAPE=27263537806354.477, RMSE=19.946938636099627
# 20/20 [==============================] - 0s 8ms/step
# Global evaluation results for dataset_5 in round 19: MAE=11.625116990822004, MAPE=25308978590483.62, RMSE=16.602345296023433
# 20/20 [==============================] - 0s 8ms/step
# Global evaluation results for dataset_6 in round 19: MAE=14.515877295195189, MAPE=65612551861752.81, RMSE=22.75747503376327
# 20/20 [==============================] - 0s 9ms/step
# Global evaluation results for dataset_7 in round 19: MAE=23.889648008423592, MAPE=135255611357141.3, RMSE=33.2872068101063
# 20/20 [==============================] - 0s 7ms/step
# Global evaluation results for dataset_8 in round 19: MAE=10.514062089950857, MAPE=101113970942733.03, RMSE=15.558337540146654
# 20/20 [==============================] - 0s 9ms/step
# Global evaluation results for dataset_9 in round 19: MAE=18.450642111035656, MAPE=28948417829734.43, RMSE=27.51769975608547
# 20/20 [==============================] - 0s 7ms/step
# Global evaluation results for dataset_10 in round 19: MAE=19.517422105840616, MAPE=76084196950544.78, RMSE=29.123666470439755
# Training completed.

# %% [markdown]
# #### Save the model

# %%
# save model to storage
global_model.save(f'federated/model_KRUM_{EPOCHS}_{comms_round}_{int(datetime.now().timestamp())}')

# %%
fig, (ax1, ax2, ax3) = pyplot.subplots(1, 3, figsize=(30, 7))
ax1.plot(global_stats_mae[global_stats_mae.columns[1:11]], label='train')
# ax1.legend(global_stats_mae.columns[1:], bbox_to_anchor=(0.853, 1.16), ncol=10)
ax1.set_ylabel('MAE', fontsize=15)
ax1.set_xlabel('Round', fontsize=15)
ax1.xaxis.set_major_formatter(FormatStrFormatter('%.0f'))

ax2.plot(global_stats_mape[global_stats_mape.columns[1:11]], label='train')
ax2.legend(global_stats_mape.columns[1:11], bbox_to_anchor=(1.05, 1.06), ncol=10)
ax2.set_ylabel('MAPE', fontsize=15)
ax2.set_xlabel('Round', fontsize=15)
ax2.xaxis.set_major_formatter(FormatStrFormatter('%.0f'))

ax3.plot(global_stats_rmse[global_stats_rmse.columns[1:11]], label='train')
# ax3.legend(global_stats_rmse.columns[1:], bbox_to_anchor=(0.853, 1.16), ncol=10)
ax3.set_ylabel('RMSE', fontsize=15)
ax3.set_xlabel('Round', fontsize=15)
ax3.xaxis.set_major_formatter(FormatStrFormatter('%.0f'))
pyplot.savefig(f'federated-KRUM_{EPOCHS}_{comms_round}.png', bbox_inches='tight', dpi=400)

# %%
print('size of model: ', sys.getsizeof(global_model.get_weights()))
# Out:
# size of model:  184

# %% [markdown]
# ### Calculating the average metrics across all rounds and storing them in new columns

# %%
global_stats_mae['A'] = (global_stats_mae['0'] + global_stats_mae['1'] + global_stats_mae['2'] + global_stats_mae['3'] +
                         global_stats_mae['4'] + global_stats_mae['5'] + global_stats_mae['6'] + global_stats_mae['7'] +
                         global_stats_mae['8'] + global_stats_mae['9']) / 10
global_stats_mape['A'] = (global_stats_mape['0'] + global_stats_mape['1'] + global_stats_mape['2'] + global_stats_mape[
    '3'] + global_stats_mape['4'] + global_stats_mape['5'] + global_stats_mape['6'] + global_stats_mape['7'] +
                          global_stats_mape['8'] + global_stats_mape['9']) / 10
global_stats_rmse['A'] = (global_stats_rmse['0'] + global_stats_rmse['1'] + global_stats_rmse['2'] + global_stats_rmse[
    '3'] + global_stats_rmse['4'] + global_stats_rmse['5'] + global_stats_rmse['6'] + global_stats_rmse['7'] +
                          global_stats_rmse['8'] + global_stats_rmse['9']) / 10

# %%
fig, (ax1, ax2, ax3) = pyplot.subplots(1, 3, figsize=(30, 7))

# Plot MAE
ax1.plot(global_stats_mae['A'], label='train', marker='o')
ax1.set_ylabel('MAE', fontsize=15)
ax1.set_xlabel('Round', fontsize=15)
ax1.xaxis.set_major_formatter(FormatStrFormatter('%.0f'))

# Plot MAPE
ax2.plot(global_stats_mape['A'], label='train', marker='o')
ax2.set_ylabel('MAPE', fontsize=15)
ax2.set_xlabel('Round', fontsize=15)
ax2.xaxis.set_major_formatter(FormatStrFormatter('%.0f'))

# Plot RMSE
ax3.plot(global_stats_rmse['A'], label='train', marker='o')
ax3.set_ylabel('RMSE', fontsize=15)
ax3.set_xlabel('Round', fontsize=15)
ax3.xaxis.set_major_formatter(FormatStrFormatter('%.0f'))


ax1.text(19, global_stats_mae['A'][19], f'{global_stats_mae["A"][19]:.2f}', bbox=dict(facecolor='white', alpha=0.5, edgecolor='black'))
ax2.text(19, global_stats_mape['A'][19], f'{global_stats_mape["A"][19]:.2f}', bbox=dict(facecolor='white', alpha=0.5, edgecolor='black'))
ax3.text(19, global_stats_rmse['A'][19], f'{global_stats_rmse["A"][19]:.2f}', bbox=dict(facecolor='white', alpha=0.5, edgecolor='black'))

pyplot.savefig(f'global-KRUM_{EPOCHS}_{comms_round}.png', bbox_inches='tight', dpi=400)
