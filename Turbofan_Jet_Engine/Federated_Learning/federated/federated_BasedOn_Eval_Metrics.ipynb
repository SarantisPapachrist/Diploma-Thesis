# %% [markdown]
# #### Import Libraries

# %%
import pandas as pd
import numpy as np
import os
from matplotlib import pyplot
from matplotlib.ticker import FormatStrFormatter
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

import tensorflow as tf
from tensorflow.keras import layers, Sequential
from tensorflow.keras import backend as K

import matplotlib.pyplot as plt 
from matplotlib.ticker import FormatStrFormatter

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

from sklearn.preprocessing import StandardScaler
from datetime import datetime
import sys

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
tf.get_logger().setLevel('ERROR')

USE_CUDA = False
EPOCHS = 10
comms_round = 20
# Out:
# 2024-07-05 20:47:01.891643: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-05 20:47:01.891720: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-05 20:47:01.892273: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-05 20:47:01.971858: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-05 20:47:03.522239: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ### Dataset

# %%
# %store -r Fed_X_Train_st
# %store -r Fed_X_Test_st

# %store -r Fed_y_Train
# %store -r Fed_y_Test

merged_dataset = pd.concat([Fed_X_Train_st, Fed_y_Train], axis=1)
Fed_X_Test_st = Fed_X_Test_st.drop(columns=['unit_number'])

# %%
feature_columns = ['time_cycles', 'LPC_Outlet_Temperature', 'HPC_Outlet_Temperature', 'LPT Outlet Temperature', 'Bypass-Duct Pressure', 
                'HPC Outlet Pressure', 'Physical Fan Speed', 'Physical Core Speed', 'HPC Outlet Static Pressure',
                'Ratio of Fuel Flow to Ps30', 'Corrected Fan Speed', 'Bypass Ratio', 'Bleed Enthalpy',
                'High-Pressure Turbines Cool Air Flow', 'Low-Pressure Turbines Cool Air Flow']

features = merged_dataset[feature_columns]

labels = merged_dataset['RUL']

# %% [markdown]
# ### Data Partition

# %%
grouped = merged_dataset.groupby('unit_number')

unit_numbers = merged_dataset['unit_number'].unique()

np.random.seed(42)
np.random.shuffle(unit_numbers)

num_clients = 10
unit_subsets = np.array_split(unit_numbers, num_clients)

client_data = {f"client_{i+1}": pd.DataFrame() for i in range(num_clients)}

for i, unit_subset in enumerate(unit_subsets):
    client_data[f"client_{i+1}"] = grouped.filter(lambda x: x.name in unit_subset)

for i in range(num_clients):
    print(f"Client {i+1} dataset size: {len(client_data[f'client_{i+1}'])}")

client_1_data = client_data["client_1"]
client_2_data = client_data["client_2"]
client_3_data = client_data["client_3"]
client_4_data = client_data["client_4"]
client_5_data = client_data["client_5"]
client_6_data = client_data["client_6"]
client_7_data = client_data["client_7"]
client_8_data = client_data["client_8"]
client_9_data = client_data["client_9"]
client_10_data = client_data["client_10"]
# Out:
# Client 1 dataset size: 2174
# Client 2 dataset size: 1896
# Client 3 dataset size: 2054
# Client 4 dataset size: 2237
# Client 5 dataset size: 2031
# Client 6 dataset size: 1878
# Client 7 dataset size: 2046
# Client 8 dataset size: 2024
# Client 9 dataset size: 2082
# Client 10 dataset size: 2209

# %%
client_1_data = client_data["client_1"].drop(columns=['unit_number'], errors='ignore')
client_2_data = client_data["client_2"].drop(columns=['unit_number'], errors='ignore')
client_3_data = client_data["client_3"].drop(columns=['unit_number'], errors='ignore')
client_4_data = client_data["client_4"].drop(columns=['unit_number'], errors='ignore')
client_5_data = client_data["client_5"].drop(columns=['unit_number'], errors='ignore')
client_6_data = client_data["client_6"].drop(columns=['unit_number'], errors='ignore')
client_7_data = client_data["client_7"].drop(columns=['unit_number'], errors='ignore')
client_8_data = client_data["client_8"].drop(columns=['unit_number'], errors='ignore')
client_9_data = client_data["client_9"].drop(columns=['unit_number'], errors='ignore')
client_10_data = client_data["client_10"].drop(columns=['unit_number'], errors='ignore')

# %% [markdown]
# #### Train, Test split for each one of the 10 datasets

# %%
datasets = []

for i, df in enumerate([client_1_data, client_2_data, client_3_data, client_4_data, client_5_data, 
                        client_6_data, client_7_data, client_8_data, client_9_data, client_10_data]):
    
    features = df[feature_columns]
    labels = df['RUL']
    
    train_features, test_features, train_labels, test_labels = train_test_split(features, labels, test_size=0.3, random_state=0)
    
    datasets.append({
        'name': f'dataset_{i+1}',
        'train_features': train_features,
        'test_features': test_features,
        'train_labels': train_labels,
        'test_labels': test_labels
    })

# %% [markdown]
# ### LSTM Model

# %%
def create_lstm_model(input_shape):
    model = Sequential([
        layers.Reshape((input_shape, 1), input_shape=(input_shape,)),
        layers.LSTM(32, activation="relu", return_sequences=True),
        layers.Dropout(0.1), 
        layers.LSTM(64, activation="relu", return_sequences=True),
        layers.Dropout(0.2), 
        layers.LSTM(128, activation="relu"),
        layers.Dropout(0.3), 
        layers.Dense(128, activation="relu"),
        layers.Dropout(0.4), 
        layers.Dense(1)
    ])
    model.compile(loss="mse", optimizer=tf.keras.optimizers.Adam(learning_rate=0.001))
    return model


input_shape = len(train_features.columns)
lstm_model = create_lstm_model(input_shape)
# Out:
# 2024-07-05 20:47:05.060097: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-05 20:47:05.221074: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-05 20:47:05.226108: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-05 20:47:05.230880: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-05 20:47:05.233293: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-05 20:47:05.235547: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-05 20:47:06.125787: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-05 20:47:06.127309: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-05 20:47:06.128657: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-05 20:47:06.129947: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2414 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650, pci bus id: 0000:01:00.0, compute capability: 7.5

# %%
def evaluate_model(model, X_test, y_test):
    predictions = model.predict(X_test)
    
    if np.isnan(predictions).any():
        raise ValueError("Model predictions contain NaNs.")
    
    mae = mean_absolute_error(y_test, predictions)
    rmse = np.sqrt(mean_squared_error(y_test, predictions))
    r2 = r2_score(y_test, predictions)
    
    return mae, rmse, r2

# %% [markdown]
# #### Function for Clients Update

# %%
def compute_weight_factor(mae, r2, rmse):
    return 3 / (1.0 / (mae + 1e-10) + 1.0 / (r2 + 1e-10) + 1.0 / (rmse + 1e-10))

def federated_model_aggregation(weights_list, mae_values, r2_values, rmse_values):
    num_clients = len(weights_list)
    aggregated_weights = [np.zeros_like(weights_list[0][i]) for i in range(len(weights_list[0]))]

    weight_factors = [compute_weight_factor(mae, r2, rmse) for mae, mape, rmse in zip(mae_values, r2_values, rmse_values)]

    for i in range(len(weights_list[0])):
        total_weight = 0.0
        for j in range(num_clients):
            aggregated_weights[i] += weights_list[j][i] * weight_factors[j]
            total_weight += weight_factors[j]

        aggregated_weights[i] /= total_weight

    return aggregated_weights

# %%
def compute_mae(model, test_features, test_labels):
    predictions = model.predict(test_features)
    mae = mean_absolute_error(test_labels, predictions)
    return mae

def compute_r2(model, test_features, test_labels):
    predictions = model.predict(test_features)
    test_labels = np.ravel(test_labels)
    predictions = np.ravel(predictions)
    r2 = r2_score(test_labels, predictions)
    return r2

def compute_rmse(model, test_features, test_labels):
    predictions = model.predict(test_features)
    test_labels = np.ravel(test_labels)
    predictions = np.ravel(predictions)
    rmse = np.sqrt(mean_squared_error(test_labels, predictions))
    return rmse

# %% [markdown]
# ### Federated Learning System with FedMA AGGREGATION

# %%
global_model = create_lstm_model(input_shape)

global_stats_mae_3 = pd.DataFrame(columns=['Round'] + [str(i) for i in range(len(datasets))] + ['test'])
global_stats_rmse_3 = pd.DataFrame(columns=['Round'] + [str(i) for i in range(len(datasets))] + ['test'])
global_stats_r2_3 = pd.DataFrame(columns=['Round'] + [str(i) for i in range(len(datasets))] + ['test'])

for comm_round in range(comms_round):
    print('Round', comm_round)
    
    local_models = []  

    for dataset in datasets:
        local_model = create_lstm_model(input_shape)
        local_model.compile(loss='mse', optimizer=tf.keras.optimizers.Adam(), metrics='MAE')

        def scheduler(epoch):
            if epoch < 5:
                return 0.001
            else:
                return 0.0001

        callback = tf.keras.callbacks.LearningRateScheduler(scheduler, verbose=0)

        local_model.set_weights(global_model.get_weights())

        history = local_model.fit(dataset['train_features'], dataset['train_labels'], epochs=EPOCHS, callbacks=[callback])

        for dataset_1 in datasets:
            mae, rmse, r2 = evaluate_model(local_model, dataset_1['test_features'], dataset_1['test_labels'])
            print(f'Evaluation results for {dataset["name"]} on {dataset_1["name"]} in round {comm_round}: MAE={mae}, RMSE={rmse}, R²={r2}')            

        mae, rmse, r2 = evaluate_model(local_model, dataset['test_features'], dataset['test_labels'])
        print(f'Evaluation results for {dataset["name"]} on itself in round {comm_round}: MAE={mae}, RMSE={rmse}, R²={r2}')
        
        dataset['weights'] = local_model.get_weights()
        local_models.append(local_model)

        K.clear_session()

    mae_values = [compute_mae(local_model, dataset['test_features'], dataset['test_labels']) for local_model, dataset in zip(local_models, datasets)]
    rmse_values = [compute_rmse(local_model, dataset['test_features'], dataset['test_labels']) for local_model, dataset in zip(local_models, datasets)]
    r2_values = [compute_r2(local_model, dataset['test_features'], dataset['test_labels']) for local_model, dataset in zip(local_models, datasets)]

    aggregated_weights = federated_model_aggregation([dataset['weights'] for dataset in datasets], mae_values, rmse_values, r2_values)

    for layer in aggregated_weights:
        if np.isnan(layer).any():
            print("Warning: NaNs detected in aggregated weights.")

    global_model.set_weights(aggregated_weights)

    global_row_mae = [comm_round]
    global_row_rmse = [comm_round]
    global_row_r2 = [comm_round]

    for dataset in datasets:
        mae, rmse, r2 = evaluate_model(global_model, dataset['test_features'], dataset['test_labels'])
        global_row_mae.append(mae)
        global_row_rmse.append(rmse)
        global_row_r2.append(r2)
        print(f'Global evaluation results for {dataset["name"]} in round {comm_round}: MAE={mae}, RMSE={rmse}, R²={r2}')

    # Evaluate on the separate test dataset
    test_mae, test_rmse, test_r2 = evaluate_model(global_model, Fed_X_Test_st, Fed_y_Test)
    global_row_mae.append(test_mae)
    global_row_rmse.append(test_rmse)
    global_row_r2.append(test_r2)
    print(f'Global evaluation results on test dataset in round {comm_round}: MAE={test_mae}, RMSE={test_rmse}, R²={test_r2}')

    global_stats_mae_3.loc[len(global_stats_mae_3)] = global_row_mae
    global_stats_rmse_3.loc[len(global_stats_rmse_3)] = global_row_rmse
    global_stats_r2_3.loc[len(global_stats_r2_3)] = global_row_r2

print("Training completed.")
# Out:
# Round 0
# Epoch 1/10
# 2024-07-05 20:47:11.020687: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x75a83c023720 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-07-05 20:47:11.020728: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce GTX 1650, Compute Capability 7.5
# 2024-07-05 20:47:11.027339: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-07-05 20:47:11.087746: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8902
# 2024-07-05 20:47:11.171782: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 48/48 [==============================] - 7s 38ms/step - loss: 7200.2510 - MAE: 72.8178 - lr: 0.0010
# Epoch 2/10
# 48/48 [==============================] - 2s 41ms/step - loss: 1226.3668 - MAE: 28.1634 - lr: 0.0010
# Epoch 3/10
# 48/48 [==============================] - 2s 47ms/step - loss: 725.3723 - MAE: 20.8760 - lr: 0.0010
# Epoch 4/10
# 48/48 [==============================] - 2s 41ms/step - loss: 794.0670 - MAE: 21.6236 - lr: 0.0010
# Epoch 5/10
# 48/48 [==============================] - 2s 36ms/step - loss: 722.3259 - MAE: 20.6051 - lr: 0.0010
# Epoch 6/10
# 48/48 [==============================] - 2s 37ms/step - loss: 582.9814 - MAE: 18.5052 - lr: 1.0000e-04
# Epoch 7/10
# 48/48 [==============================] - 2s 35ms/step - loss: 591.7408 - MAE: 18.6511 - lr: 1.0000e-04
# Epoch 8/10
# 48/48 [==============================] - 2s 37ms/step - loss: 595.8968 - MAE: 18.9171 - lr: 1.0000e-04
# Epoch 9/10
# 48/48 [==============================] - 2s 37ms/step - loss: 610.2535 - MAE: 18.7869 - lr: 1.0000e-04
# Epoch 10/10
# 48/48 [==============================] - 2s 38ms/step - loss: 579.1099 - MAE: 18.3096 - lr: 1.0000e-04
# 21/21 [==============================] - 0s 6ms/step
# Evaluation results for dataset_1 on dataset_1 in round 0: MAE=13.938054438572017, RMSE=19.007495441335898, R²=0.802379325003481
# 18/18 [==============================] - 0s 6ms/step
# Evaluation results for dataset_1 on dataset_2 in round 0: MAE=13.376582720996206, RMSE=18.1809855853491, R²=0.8248025153241315
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_1 on dataset_3 in round 0: MAE=17.030938760194825, RMSE=22.569444559644086, R²=0.731676657517804
# 21/21 [==============================] - 0s 7ms/step
# Evaluation results for dataset_1 on dataset_4 in round 0: MAE=16.22844828452383, RMSE=21.088436078256787, R²=0.7487363546442675
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_1 on dataset_5 in round 0: MAE=16.451362649729994, RMSE=22.008740182844548, R²=0.7509896265318409
# 18/18 [==============================] - 0s 6ms/step
# Evaluation results for dataset_1 on dataset_6 in round 0: MAE=16.871652627667636, RMSE=23.22852040036453, R²=0.7179513558426307
# 20/20 [==============================] - 0s 6ms/step
# Evaluation results for dataset_1 on dataset_7 in round 0: MAE=18.21633433528754, RMSE=25.182108746973093, R²=0.6816853401556613
# 19/19 [==============================] - 0s 6ms/step
# Evaluation results for dataset_1 on dataset_8 in round
# 21/21 [==============================] - 0s 7ms/step
# Evaluation results for dataset_10 on dataset_10 in round 19: MAE=12.209748045171908, RMSE=17.04380431675152, R²=0.839204763807105
# 21/21 [==============================] - 0s 7ms/step
# Evaluation results for dataset_10 on itself in round 19: MAE=12.209748045171908, RMSE=17.04380431675152, R²=0.839204763807105
# 21/21 [==============================] - 0s 7ms/step
# 18/18 [==============================] - 0s 6ms/step
# 20/20 [==============================] - 0s 6ms/step
# 21/21 [==============================] - 0s 6ms/step
# 20/20 [==============================] - 0s 6ms/step
# 18/18 [==============================] - 0s 6ms/step
# 20/20 [==============================] - 0s 7ms/step
# 19/19 [==============================] - 0s 6ms/step
# 20/20 [==============================] - 0s 6ms/step
# 21/21 [==============================] - 0s 6ms/step
# 21/21 [==============================] - 0s 6ms/step
# 18/18 [==============================] - 0s 6ms/step
# 20/20 [==============================] - 0s 6ms/step
# 21/21 [==============================] - 0s 6ms/step
# 20/20 [==============================] - 0s 6ms/step
# 18/18 [==============================] - 0s 6ms/step
# 20/20 [==============================] - 0s 8ms/step
# 19/19 [==============================] - 0s 9ms/step
# 20/20 [==============================] - 0s 7ms/step
# 21/21 [==============================] - 0s 6ms/step
# 21/21 [==============================] - 0s 6ms/step
# 18/18 [==============================] - 0s 6ms/step
# 20/20 [==============================] - 0s 6ms/step
# 21/21 [==============================] - 0s 6ms/step
# 20/20 [==============================] - 0s 6ms/step
# 18/18 [==============================] - 0s 6ms/step
# 20/20 [==============================] - 0s 6ms/step
# 19/19 [==============================] - 0s 6ms/step
# 20/20 [==============================] - 0s 6ms/step
# 21/21 [==============================] - 0s 6ms/step
# 21/21 [==============================] - 0s 6ms/step
# Global evaluation results for dataset_1 in round 19: MAE=13.807653430410037, RMSE=18.788023040667696, R²=0.8069166805295137
# 18/18 [==============================] - 0s 6ms/step
# Global evaluation results for dataset_2 in round 19: MAE=10.356915406476844, RMSE=13.342534487573003, R²=0.9056439634874882
# 20/20 [==============================] - 0s 7ms/step
# Global evaluation results for dataset_3 in round 19: MAE=15.48661003236446, RMSE=20.7421134221735, R²=0.773367221853585
# 21/21 [==============================] - 0s 6ms/step
# Global evaluation results for dataset_4 in round 19: MAE=17.216462861569156, RMSE=23.204382599897773, R²=0.6957847756924093
# 20/20 [==============================] - 0s 6ms/step
# Global evaluation results for dataset_5 in round 19: MAE=12.847822825635065, RMSE=17.42015333290276, R²=0.8439976935436698
# 18/18 [==============================] - 0s 6ms/step
# Global evaluation results for dataset_6 in round 19: MAE=12.685460532387943, RMSE=17.51054896272692, R²=0.8397195898194513
# 20/20 [==============================] - 0s 7ms/step
# Global evaluation results for dataset_7 in round 19: MAE=14.001719491877852, RMSE=19.648823288901255, R²=0.80620367200036
# 19/19 [==============================] - 0s 8ms/step
# Global evaluation results for dataset_8 in round 19: MAE=11.676933316415862, RMSE=15.056187073153975, R²=0.8819490502416274
# 20/20 [==============================] - 0s 7ms/step
# Global evaluation results for dataset_9 in round 19: MAE=13.499706687164307, RMSE=18.326093135151467, R²=0.8276136888952935
# 21/21 [==============================] - 0s 7ms/step
# Global evaluation results for dataset_10 in round 19: MAE=14.382339437263225, RMSE=19.225167872278142, R²=0.795411894531612
# 4/4 [==============================] - 0s 6ms/step
# Global evaluation results on test dataset in round 19: MAE=16.61956998825073, RMSE=21.63350477313593, R²=0.7289844416918944
# Training completed.

# %% [markdown]
# #### Save the model

# %%
# save model to storage
#global_model.save(f'federated/model_BasedOn_EvalMetrics_{EPOCHS}_{comms_round}_{int(datetime.now().timestamp())}')

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(30, 7))
plt.rcParams.update({'font.size': 20})

# Plot MAE
ax1.plot(global_stats_mae_3[global_stats_mae_3.columns[1:11]], label='train')
ax1.set_ylabel('MAE', fontsize=25)
ax1.set_xlabel('Round', fontsize=25)
ax1.tick_params(axis='both', which='major', labelsize=20)
ax1.xaxis.set_major_formatter(FormatStrFormatter('%.0f'))

# Plot R² 
ax2.plot(global_stats_r2_3[global_stats_r2_3.columns[1:11]], label='train')
ax2.set_ylabel('R²', fontsize=25)
ax2.set_xlabel('Round', fontsize=25)
ax2.tick_params(axis='both', which='major', labelsize=20)
ax2.xaxis.set_major_formatter(FormatStrFormatter('%.0f'))

# Plot RMSE
ax3.plot(global_stats_rmse_3[global_stats_rmse_3.columns[1:11]], label='train')
ax3.set_ylabel('RMSE', fontsize=25)
ax3.set_xlabel('Round', fontsize=25)
ax3.tick_params(axis='both', which='major', labelsize=20)
ax3.xaxis.set_major_formatter(FormatStrFormatter('%.0f'))

plt.tight_layout()
plt.show()

# %%
print('size of model: ', sys.getsizeof(global_model.get_weights()))
# Out:
# size of model:  184

# %% [markdown]
# ### Calculating the average metrics across all rounds and storing them in new columns

# %%
global_stats_mae_3['A'] = (global_stats_mae_3['0'] + global_stats_mae_3['1'] + global_stats_mae_3['2'] + global_stats_mae_3['3'] +
                         global_stats_mae_3['4'] + global_stats_mae_3['5'] + global_stats_mae_3['6'] + global_stats_mae_3['7'] +
                         global_stats_mae_3['8'] + global_stats_mae_3['9'] + global_stats_mae_3['test']) / 11

global_stats_r2_3['A'] = (global_stats_r2_3['0'] + global_stats_r2_3['1'] + global_stats_r2_3['2'] + global_stats_r2_3['3'] +
                          global_stats_r2_3['4'] + global_stats_r2_3['5'] + global_stats_r2_3['6'] + global_stats_r2_3['7'] +
                          global_stats_r2_3['8'] + global_stats_r2_3['9'] + global_stats_r2_3['test']) / 11

global_stats_rmse_3['A'] = (global_stats_rmse_3['0'] + global_stats_rmse_3['1'] + global_stats_rmse_3['2'] + global_stats_rmse_3['3'] +
                          global_stats_rmse_3['4'] + global_stats_rmse_3['5'] + global_stats_rmse_3['6'] + global_stats_rmse_3['7'] +
                          global_stats_rmse_3['8'] + global_stats_rmse_3['9'] + global_stats_rmse_3['test']) / 11

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(30, 7))
plt.rcParams.update({'font.size': 20})

# Plot MAE
ax1.plot(global_stats_mae_3['A'], label='train', marker='o')
ax1.set_ylabel('MAE', fontsize=25)
ax1.set_xlabel('Round', fontsize=25)
ax1.tick_params(axis='both', which='major', labelsize=20)
ax1.xaxis.set_major_formatter(FormatStrFormatter('%.0f'))

# Plot R² 
ax2.plot(global_stats_r2_3['A'], label='train', marker='o')
ax2.set_ylabel('R²', fontsize=25)
ax2.set_xlabel('Round', fontsize=25)
ax2.tick_params(axis='both', which='major', labelsize=20)
ax2.xaxis.set_major_formatter(FormatStrFormatter('%.0f'))

# Plot RMSE
ax3.plot(global_stats_rmse_3['A'], label='train', marker='o')
ax3.set_ylabel('RMSE', fontsize=25)
ax3.set_xlabel('Round', fontsize=25)
ax3.tick_params(axis='both', which='major', labelsize=20)
ax3.xaxis.set_major_formatter(FormatStrFormatter('%.0f'))

# Add text annotations for the last round values
round_idx = len(global_stats_mae_3) - 1
ax1.text(round_idx, global_stats_mae_3['A'][round_idx], f'{global_stats_mae_3["A"][round_idx]:.2f}', bbox=dict(facecolor='white', alpha=0.5, edgecolor='black'))
ax2.text(round_idx, global_stats_r2_3['A'][round_idx], f'{global_stats_r2_3["A"][round_idx]:.2f}', bbox=dict(facecolor='white', alpha=0.5, edgecolor='black'))
ax3.text(round_idx, global_stats_rmse_3['A'][round_idx], f'{global_stats_rmse_3["A"][round_idx]:.2f}', bbox=dict(facecolor='white', alpha=0.5, edgecolor='black'))

plt.tight_layout()
plt.show()

#pyplot.savefig(f'global-BasedOn_EvalMetrics_{EPOCHS}_{comms_round}.png', bbox_inches='tight', dpi=400)

# %%
fig, (ax1, ax2, ax3) = pyplot.subplots(1, 3, figsize=(30, 7))
plt.rcParams.update({'font.size': 20})

ax1.plot(global_stats_mae_3['test'], label='test', marker='o', color='red')
ax1.set_ylabel('MAE', fontsize=25)
ax1.set_xlabel('Round', fontsize=25)
ax1.tick_params(axis='both', which='major', labelsize=18)
ax1.xaxis.set_major_formatter(FormatStrFormatter('%.0f'))

ax2.plot(global_stats_r2_3['test'], label='test', marker='o', color='red')
ax2.set_ylabel('R2', fontsize=25)
ax2.set_xlabel('Round', fontsize=25)
ax2.tick_params(axis='both', which='major', labelsize=18)
ax2.xaxis.set_major_formatter(FormatStrFormatter('%.0f'))

ax3.plot(global_stats_rmse_3['test'], label='test', marker='o', color='red')
ax3.set_ylabel('RMSE', fontsize=25)
ax3.set_xlabel('Round', fontsize=25)
ax3.tick_params(axis='both', which='major', labelsize=18)
ax3.xaxis.set_major_formatter(FormatStrFormatter('%.0f'))

round_idx = len(global_stats_mae_3) - 1  
ax1.text(round_idx, global_stats_mae_3['test'][round_idx], f'{global_stats_mae_3["test"][round_idx]:.2f}', bbox=dict(facecolor='white', alpha=0.5, edgecolor='black'))
ax2.text(round_idx, global_stats_r2_3['test'][round_idx], f'{global_stats_r2_3["test"][round_idx]:.2f}', bbox=dict(facecolor='white', alpha=0.5, edgecolor='black'))
ax3.text(round_idx, global_stats_rmse_3['test'][round_idx], f'{global_stats_rmse_3["test"][round_idx]:.2f}', bbox=dict(facecolor='white', alpha=0.5, edgecolor='black'))

ax1.set_title('MAE for Test Dataset', fontsize=20)
ax2.set_title('R^2 for Test Dataset', fontsize=20)
ax3.set_title('RMSE for Test Dataset', fontsize=20)

plt.tight_layout()

plt.show()

# %%
global_stats_mae_3.to_csv('global_stats_mae_Eval.csv', index=False)
global_stats_r2_3.to_csv('global_stats_r2_Eval.csv', index=False)
global_stats_rmse_3.to_csv('global_stats_rmse_Eval.csv', index=False)
