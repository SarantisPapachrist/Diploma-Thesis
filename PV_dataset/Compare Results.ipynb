# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ##### Accuracies

# %%
#Random Forest
# %store -r accuracy 
#Random Forest with Ranges_4 dataset 
# %store -r accuracy_Ranges_4
#AdaBoost
# %store -r accuracy_test 
#CN2 Rule Induction
# %store -r cn2_accuracy_test 
#Logistic Regression
# %store -r multi_accuracy_test 
#KNN
# %store -r knn_accuracy_test 
#Naive Bayes
# %store -r accuracy_test_nb 
#Support Vector Machine
# %store -r svm_accuracy_test

# %%
classifiers = ['Random Forest', 'Random Forest (Ranges_4)', 'AdaBoost', 'CN2 Rule Induction', 'Logistic Regression', 'KNN', 'Naive Bayes', 'Support Vector Machine']
accuracies = [accuracy, accuracy_Ranges_4, accuracy_test, cn2_accuracy_test, multi_accuracy_test, knn_accuracy_test, accuracy_test_nb, svm_accuracy_test]

import pandas as pd
data = pd.DataFrame({'Classifier': classifiers, 'Accuracy': accuracies})

sns.set_theme(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.barplot(x='Classifier', y='Accuracy', hue='Classifier', data=data, dodge=False)
plt.xlabel('Classifier')
plt.ylabel('Accuracy')
plt.title('Classifier Accuracies')

for index, row in data.iterrows():
    plt.text(index, row['Accuracy'] + 0.01, f'{row["Accuracy"]:.2f}', color='black', ha="center")

plt.xticks(rotation=45, ha='right')
plt.ylim(0, 1) 
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Precisions

# %%
# %store -r precision
# %store -r precision_Ranges_4
# %store -r precision_test
# %store -r cn2_precision_test
# %store -r multi_precision_test
# %store -r knn_precision_test
# %store -r precision_test_nb
# %store -r svm_precision_test

# %%
classifiers = ['Random Forest', 'Random Forest (Ranges_4)', 'AdaBoost', 'CN2 Rule Induction', 'Logistic Regression', 'KNN', 'Naive Bayes', 'Support Vector Machine']
precisions = [precision, precision_Ranges_4, precision_test, cn2_precision_test, multi_precision_test, knn_precision_test, precision_test_nb, svm_precision_test]

data = pd.DataFrame({'Classifier': classifiers, 'Precision': precisions})

sns.set_theme(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.barplot(x='Classifier', y='Precision', hue='Classifier', data=data, dodge=False)

for index, row in data.iterrows():
    plt.text(index, row['Precision'] + 0.03, f'{row["Precision"]:.2f}', color='black', ha="center")

plt.xlabel('Classifier')
plt.ylabel('Precision')
plt.title('Classifier Precisions')
plt.xticks(rotation=45, ha='right')
plt.ylim(0, 1)  
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Recall

# %%
# %store -r recall
# %store -r recall_Ranges_4
# %store -r recall_test
# %store -r cn2_recall_test
# %store -r multi_recall_test
# %store -r knn_recall_test
# %store -r recall_test_nb
# %store -r svm_recall_test

# %%
classifiers = ['Random Forest', 'Random Forest (Ranges_4)', 'AdaBoost', 'CN2 Rule Induction', 'Logistic Regression', 'KNN', 'Naive Bayes', 'Support Vector Machine']
recalls = [recall, recall_Ranges_4, recall_test, cn2_recall_test, multi_recall_test, knn_recall_test, recall_test_nb, svm_recall_test]

data = pd.DataFrame({'Classifier': classifiers, 'Recall': recalls})

sns.set_theme(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.barplot(x='Classifier', y='Recall', hue='Classifier', data=data, dodge=False)

for index, row in data.iterrows():
    plt.text(index, row['Recall'] + 0.03, f'{row["Recall"]:.2f}', color='black', ha="center")

plt.xlabel('Classifier')
plt.ylabel('Recall')
plt.title('Classifier Recalls')
plt.xticks(rotation=45, ha='right')
plt.ylim(0, 1)  
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### F1

# %%
# %store -r f1
# %store -r f1_Ranges_4
# %store -r f1_test
# %store -r cn2_f1_test
# %store -r multi_f1_test
# %store -r knn_f1_test
# %store -r f1_test_nb
# %store -r svm_f1_test

# %%
classifiers = ['Random Forest', 'Random Forest (Ranges_4)', 'AdaBoost', 'CN2 Rule Induction', 'Logistic Regression', 'KNN', 'Naive Bayes', 'Support Vector Machine']
f1_scores = [f1, f1_Ranges_4, f1_test, cn2_f1_test, multi_f1_test, knn_f1_test, f1_test_nb, svm_f1_test]

data = pd.DataFrame({'Classifier': classifiers, 'F1 Score': f1_scores})

sns.set_theme(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.barplot(x='Classifier', y='F1 Score', hue='Classifier', data=data, dodge=False)

for index, row in data.iterrows():
    plt.text(index, row['F1 Score'] + 0.03, f'{row["F1 Score"]:.2f}', color='black', ha="center")

plt.xlabel('Classifier')
plt.ylabel('F1 Score')
plt.title('Classifier F1 Scores')
plt.xticks(rotation=45, ha='right')
plt.ylim(0, 1) 
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Log Losses

# %%
# %store -r log_loss_value_test
# %store -r log_loss_value_Ranges_4
# %store -r log_loss_value_test_ada
# %store -r multi_log_loss_value_test
# %store -r log_loss_value_test_nb
# %store -r svm_log_loss_value_test

# %%
classifiers = ['Random Forest', 'Random Forest (Ranges_4)', 'AdaBoost', 'Logistic Regression', 'Naive Bayes', 'Support Vector Machine']
log_loss_values = [log_loss_value_test, log_loss_value_Ranges_4, log_loss_value_test_ada, multi_log_loss_value_test, log_loss_value_test_nb, svm_log_loss_value_test]

data = pd.DataFrame({'Classifier': classifiers, 'Log Loss': log_loss_values})

sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.barplot(x='Classifier', y='Log Loss', hue='Classifier', data=data, dodge=False)

for index, row in data.iterrows():
    plt.text(index, row['Log Loss'] + 0.03, f'{row["Log Loss"]:.2f}', color='black', ha="center")

plt.xlabel('Classifier')
plt.ylabel('Log Loss')
plt.title('Classifier Log Loss')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Confusion Matrixes

# %%
# %store -r conf_matrix
# %store -r conf_matrix_Ranges_4
# %store -r conf_matrix_test
# %store -r cn2_conf_matrix_test
# %store -r multi_conf_matrix_test
# %store -r knn_conf_matrix_test
# %store -r conf_matrix_test_nb
# %store -r svm_conf_matrix_test

# %%
classifiers = ['Random Forest', 'Random Forest (Ranges_4)', 'AdaBoost', 'CN2 Rule Induction', 'Logistic Regression', 'KNN', 'Naive Bayes', 'Support Vector Machine']
conf_matrices = [conf_matrix, conf_matrix_Ranges_4, conf_matrix_test, cn2_conf_matrix_test, multi_conf_matrix_test, knn_conf_matrix_test, conf_matrix_test_nb, svm_conf_matrix_test]

plt.figure(figsize=(15, 10))

for i, (clf, conf_matrix) in enumerate(zip(classifiers, conf_matrices), 1):
    plt.subplot(3, 3, i)
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False)
    plt.title(clf)
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')

plt.tight_layout()
plt.show()
