# %% [markdown]
# #### Load the Dataset

# %%
import pandas as pd
import numpy as np

path_train = "/home/sarantis/Documents/Διπλωματική Εργασία/Diploma-Thesis/PV_dataset/datasets/train data.csv"  
train_data = pd.read_csv(path_train, delimiter=';')

path_test = "/home/sarantis/Documents/Διπλωματική Εργασία/Diploma-Thesis/PV_dataset/datasets/test data.csv"  
test_data = pd.read_csv(path_test, delimiter=';')

display(train_data)
display(test_data)
# Out:
#            I1        I2     I1MAX     I1MIN     I1VAR     I2MAX     I2MIN  \
# 0    3.464132  3.464132  3.776515  3.433125  0.000054  3.776515  3.433125
# 1    2.244766  2.244766  2.611714  2.210978  0.000350  2.611714  2.210978
# 2    3.878360  3.878360  4.101282  3.854098  0.000010  4.101282  3.854098
# 3    2.816389  2.816389  3.285793  2.758149  0.000192  3.285793  2.758149
# 4    1.238798  1.238798  5.455667  0.141519  0.001153  5.455667  0.141519
# ..        ...       ...       ...       ...       ...       ...       ...
# 595  2.816000  3.704300  3.616700  2.806100  0.000238  3.713500  3.618800
# 596  1.565200  1.948200  1.875500  1.563700  0.000007  1.949200  1.877600
# 597  5.009200  5.229700  5.128300  4.992000  0.000009  5.237100  5.130300
# 598  0.158040  1.333400  1.283700  0.151170  0.000144  1.334700  1.285800
# 599  4.234300  5.044700  4.926600  4.222600  0.000206  5.060500  4.928800
#
#             I2VAR        I3        I4  ...     Vdcmax1     Vdcmin1  \
# ...

# %% [markdown]
# #### Create new Datasets without some attributes

# %%
# Dataframe without Range 4
No_Range_4_train = train_data.drop('range 4', axis=1) 
No_Range_4_test = test_data.drop('range 4', axis=1) 

# Dataframe without Range 1, Range 2, Range 3, Range 4
No_Range_train = train_data.drop(['range 1', 'range 2', 'range 3', 'range 4'], axis=1)
No_Range_test = test_data.drop(['range 1', 'range 2', 'range 3', 'range 4'], axis=1)

# Dataframe μόνο με τα 4 No_Range
Ranges_4_train = train_data.drop(['I1', 'I2', 'I1MAX', 'I1MIN', 'I1VAR', 'I2MAX', 'I2MIN', 'I2VAR', 'I3', 'I4', 'I3max', 'I3min', 'I3var', 'I4MAX', 'I4MIN', 'I6', 'I5', 'Itotal1', 'Itotalmax1', 'Itotalmin1', 'Vdcmean1', 'Vdcmax1', 'Vdcmin1', 'Pdcmean1', 'IR', 'T'], axis=1)
Ranges_4_test = test_data.drop(['I1', 'I2', 'I1MAX', 'I1MIN', 'I1VAR', 'I2MAX', 'I2MIN', 'I2VAR', 'I3', 'I4', 'I3max', 'I3min', 'I3var', 'I4MAX', 'I4MIN', 'I6', 'I5', 'Itotal1', 'Itotalmax1', 'Itotalmin1', 'Vdcmean1', 'Vdcmax1', 'Vdcmin1', 'Pdcmean1', 'IR', 'T'], axis=1)

# %%
# Dataframes without class
X_No_Range_4_train = No_Range_4_train.drop('class', axis=1) 
X_No_Range_4_test = No_Range_4_test.drop('class', axis=1)

X_No_Range_train = No_Range_train.drop('class', axis=1) 
X_No_Range_test = No_Range_test.drop('class', axis=1)

X_Ranges_4_train = Ranges_4_train.drop('class', axis=1) 
X_Ranges_4_test = Ranges_4_test.drop('class', axis=1)

# Dataframe for Target Variable
y_No_Range_4_train = No_Range_4_train['class']  
y_No_Range_4_test = No_Range_4_test['class']

y_No_Range_train = No_Range_train['class']  
y_No_Range_test = No_Range_test['class']

y_Ranges_4_train = Ranges_4_train['class']  
# %store y_Ranges_4_train
y_Ranges_4_test = Ranges_4_test['class']
# %store y_Ranges_4_test
# Out:
# Stored 'y_Ranges_4_train' (Series)
# Stored 'y_Ranges_4_test' (Series)

# %% [markdown]
# #### Min-Max Scaling

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

X_No_Range_4_train_scaled = pd.DataFrame(scaler.fit_transform(X_No_Range_4_train), columns=X_No_Range_4_train.columns)
X_No_Range_4_test_scaled = pd.DataFrame(scaler.transform(X_No_Range_4_test), columns=X_No_Range_4_test.columns)

X_No_Range_train_scaled = pd.DataFrame(scaler.fit_transform(X_No_Range_train), columns=X_No_Range_train.columns)
X_No_Range_test_scaled = pd.DataFrame(scaler.transform(X_No_Range_test), columns=X_No_Range_test.columns)

X_Ranges_4_train_scaled = pd.DataFrame(scaler.fit_transform(X_Ranges_4_train), columns=X_Ranges_4_train.columns)
# %store X_Ranges_4_train_scaled
X_Ranges_4_test_scaled = pd.DataFrame(scaler.transform(X_Ranges_4_test), columns=X_Ranges_4_test.columns)
# %store X_Ranges_4_test_scaled
# Out:
# Stored 'X_Ranges_4_train_scaled' (DataFrame)
# Stored 'X_Ranges_4_test_scaled' (DataFrame)

# %% [markdown]
# #### Random Forest Algorithm

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier

datasets = {
    'No_Range_4': (X_No_Range_4_train_scaled, y_No_Range_4_train),
    'No_Range': (X_No_Range_train_scaled, y_No_Range_train),
    'Ranges_4': (X_Ranges_4_train_scaled, y_Ranges_4_train)
}

param_grid = {
    'max_depth': [2, 3, 5, 10, 20],
    'min_samples_leaf': [5, 10, 20, 50, 100, 200],
    'n_estimators': [10, 25, 30, 50, 100, 200]
}

# Dictionairy to save the trained models
models = {}

random_forest = RandomForestClassifier(random_state=42)

for dataset_name, (X_train, y_train) in datasets.items():
    grid_search = GridSearchCV(estimator=random_forest, param_grid=param_grid, cv=5, scoring='accuracy')
    grid_search.fit(X_train, y_train)

    best_params = grid_search.best_params_
    best_score = grid_search.best_score_

    print(f'Best Parameters for {dataset_name}: {best_params}')
    print(f'Best Mean Cross-Validated Score for {dataset_name}: {best_score}')

    random_forest_model = RandomForestClassifier(random_state=42, max_depth=best_params['max_depth'],
                                       min_samples_leaf=best_params['min_samples_leaf'],
                                       n_estimators=best_params['n_estimators'])
    
    random_forest_model.fit(X_train, y_train)

    models[dataset_name] = random_forest_model
# Out:
# Best Parameters for No_Range_4: {'max_depth': 10, 'min_samples_leaf': 5, 'n_estimators': 10}
# Best Mean Cross-Validated Score for No_Range_4: 0.9516666666666668
# Best Parameters for No_Range: {'max_depth': 20, 'min_samples_leaf': 5, 'n_estimators': 100}
# Best Mean Cross-Validated Score for No_Range: 0.7283333333333333
# Best Parameters for Ranges_4: {'max_depth': 2, 'min_samples_leaf': 5, 'n_estimators': 10}
# Best Mean Cross-Validated Score for Ranges_4: 1.0

# %% [markdown]
# #### Evaluation on Test Data
#
# ##### Evaluation of the Model Trained with 'No_Range_4': (X_No_Range_4_train_scaled, y_No_Range_4_train)

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, log_loss, confusion_matrix, roc_auc_score

y_No_Range_4_pred = models['No_Range_4'].predict(X_No_Range_4_test_scaled)
y_No_Range_4_pred_proba = models['No_Range_4'].predict_proba(X_No_Range_4_test_scaled)

# Precision
precision_No_Range_4 = precision_score(y_No_Range_4_test, y_No_Range_4_pred, average='weighted')

# Recall
recall_No_Range_4 = recall_score(y_No_Range_4_test, y_No_Range_4_pred, average='weighted')

# F1-Score
f1_No_Range_4 = f1_score(y_No_Range_4_test, y_No_Range_4_pred, average='weighted')

# Classification Accuracy
accuracy_No_Range_4 = accuracy_score(y_No_Range_4_test, y_No_Range_4_pred)

# Log Loss
#log_loss_value_No_Range_4 = log_loss(y_No_Range_4_test, y_No_Range_4_pred)
log_loss_value_No_Range_4 = log_loss(y_No_Range_4_test, y_No_Range_4_pred_proba, labels=models['No_Range_4'].classes_)

# Confusion Matrix
conf_matrix_No_Range_4 = confusion_matrix(y_No_Range_4_test, y_No_Range_4_pred)

# AROC Curve
roc_auc_No_Range_4 = roc_auc_score(y_No_Range_4_test, y_No_Range_4_pred_proba, multi_class='ovr', labels=random_forest_model.classes_)

# Metrics
print(f'Test Confusion Matrix without No_Range_4:\n{conf_matrix_No_Range_4}')
print()
print(f'Test Area Under the ROC Curve (AROC) without No_Range_4: {roc_auc_No_Range_4}')
print(f'Test Accuracy without No_Range_4: {accuracy_No_Range_4}')
print(f'Test F1-Score without No_Range_4: {f1_No_Range_4}')
print(f'Test Precision without No_Range_4: {precision_No_Range_4}')
print(f'Test Recall without No_Range_4: {recall_No_Range_4}')
print(f'Training Log Loss without No_Range_4: {log_loss_value_No_Range_4}')
# Out:
# Test Confusion Matrix without No_Range_4:
# [[25  0  0  0]
#  [ 8 17  0  0]
#  [ 0  0 22  3]
#  [ 0  0  8 17]]
#
# Test Area Under the ROC Curve (AROC) without No_Range_4: 0.9773333333333333
# Test Accuracy without No_Range_4: 0.81
# Test F1-Score without No_Range_4: 0.8067870826491516
# Test Precision without No_Range_4: 0.8352272727272727
# Test Recall without No_Range_4: 0.81
# Training Log Loss without No_Range_4: 0.48104841176194313

# %% [markdown]
# ##### Evaluation of the Model Trained with 'No_Range': (X_No_Range_train_scaled, y_No_Range_train)

# %%
y_No_Range_pred = models['No_Range'].predict(X_No_Range_test_scaled)
y_No_Range_pred_proba = models['No_Range'].predict_proba(X_No_Range_test_scaled)

# Precision
precision_No_Range = precision_score(y_No_Range_test, y_No_Range_pred, average='weighted')

# Recall
recall_No_Range = recall_score(y_No_Range_test, y_No_Range_pred, average='weighted')

# F1-Score
f1_No_Range = f1_score(y_No_Range_test, y_No_Range_pred, average='weighted')

# Classification Accuracy
accuracy_No_Range = accuracy_score(y_No_Range_test, y_No_Range_pred)

# Log Loss
log_loss_value_No_Range = log_loss(y_No_Range_test, y_No_Range_pred_proba, labels=models['No_Range'].classes_)

# Confusion Matrix
conf_matrix_No_Range = confusion_matrix(y_No_Range_test, y_No_Range_pred)

# AROC Curve
roc_auc_No_Range = roc_auc_score(y_No_Range_test, y_No_Range_pred_proba, multi_class='ovr', labels=models['No_Range'].classes_)

# Metrics
print(f'Test Confusion Matrix for No_Range:\n{conf_matrix_No_Range}')
print()
print(f'Test Area Under the ROC Curve (AROC) for No_Range: {roc_auc_No_Range}')
print(f'Test Accuracy for No_Range: {accuracy_No_Range}')
print(f'Test F1-Score for No_Range: {f1_No_Range}')
print(f'Test Precision for No_Range: {precision_No_Range}')
print(f'Test Recall for No_Range: {recall_No_Range}')
print(f'Training Log Loss for No_Range: {log_loss_value_No_Range}')
# Out:
# Test Confusion Matrix for No_Range:
# [[ 8  4  0 13]
#  [ 0 15  0 10]
#  [ 0 14  2  9]
#  [ 2  4  1 18]]
#
# Test Area Under the ROC Curve (AROC) for No_Range: 0.7477333333333334
# Test Accuracy for No_Range: 0.43
# Test F1-Score for No_Range: 0.39096774193548384
# Test Precision for No_Range: 0.558018018018018
# Test Recall for No_Range: 0.43
# Training Log Loss for No_Range: 1.2522119913245862

# %% [markdown]
# ##### Evaluation of the Model Trained with 'Ranges_4': (X_Ranges_4_scaled, y_Ranges_4)

# %%
y_Ranges_4_pred = models['Ranges_4'].predict(X_Ranges_4_test_scaled)
y_Ranges_4_pred_proba = models['Ranges_4'].predict_proba(X_Ranges_4_test_scaled)

# Precision
precision_Ranges_4 = precision_score(y_Ranges_4_test, y_Ranges_4_pred, average='weighted')
# %store precision_Ranges_4

# Recall
recall_Ranges_4 = recall_score(y_Ranges_4_test, y_Ranges_4_pred, average='weighted')
# %store recall_Ranges_4

# F1-Score
f1_Ranges_4 = f1_score(y_Ranges_4_test, y_Ranges_4_pred, average='weighted')
# %store f1_Ranges_4

# Classification Accuracy
accuracy_Ranges_4 = accuracy_score(y_Ranges_4_test, y_Ranges_4_pred)
# %store accuracy_Ranges_4

# Log Loss
log_loss_value_Ranges_4 = log_loss(y_Ranges_4_test, y_Ranges_4_pred_proba, labels=models['Ranges_4'].classes_)
# %store log_loss_value_Ranges_4

# Confusion Matrix
conf_matrix_Ranges_4 = confusion_matrix(y_Ranges_4_test, y_Ranges_4_pred)
# %store conf_matrix_Ranges_4

# AROC Curve
roc_auc_Ranges_4 = roc_auc_score(y_Ranges_4_test, y_Ranges_4_pred_proba, multi_class='ovr', labels=models['Ranges_4'].classes_)
# %store roc_auc_Ranges_4

# Metrics
print(f'Test Confusion Matrix for Ranges_4:\n{conf_matrix_Ranges_4}')
print()
print(f'Test Area Under the ROC Curve (AROC) for Ranges_4: {roc_auc_Ranges_4}')
print(f'Test Accuracy for Ranges_4: {accuracy_Ranges_4}')
print(f'Test F1-Score for Ranges_4: {f1_Ranges_4}')
print(f'Test Precision for Ranges_4: {precision_Ranges_4}')
print(f'Test Recall for Ranges_4: {recall_Ranges_4}')
print(f'Training Log Loss for Ranges_4: {log_loss_value_Ranges_4}')
# Out:
# Stored 'precision_Ranges_4' (float64)
# Stored 'recall_Ranges_4' (float64)
# Stored 'f1_Ranges_4' (float64)
# Stored 'accuracy_Ranges_4' (float)
# Stored 'log_loss_value_Ranges_4' (float)
# Stored 'conf_matrix_Ranges_4' (ndarray)
# Stored 'roc_auc_Ranges_4' (float64)
# Test Confusion Matrix for Ranges_4:
# [[25  0  0  0]
#  [ 5 20  0  0]
#  [ 0  2 23  0]
#  [ 0  0  0 25]]
#
# Test Area Under the ROC Curve (AROC) for Ranges_4: 0.9758666666666667
# Test Accuracy for Ranges_4: 0.93
# Test F1-Score for Ranges_4: 0.9296220180528693
# Test Precision for Ranges_4: 0.9356060606060607
# Test Recall for Ranges_4: 0.93
# Training Log Loss for Ranges_4: 0.38131698562579913

# %% [markdown]
# ### Plot and Compare Results

# %% [markdown]
# ##### Accuracy

# %%
import matplotlib.pyplot as plt
# %store -r accuracy

accuracy_values = [accuracy_No_Range_4, accuracy_No_Range, accuracy_Ranges_4]
models_names = ['Range4', 'Ranges', 'Ranges_4']
bar_width = 0.3

accuracy_values.append(accuracy)
models_names.append('Original Dataset')

plt.figure(figsize=(7, 5))
bars = plt.bar(models_names, accuracy_values, color=['blue', 'green', 'grey', 'purple'], width=bar_width)
plt.title('Accuracy Comparison for Different Models')
plt.xlabel('Different Datasets')
plt.ylabel('Accuracy')
plt.ylim(0, 1) 

for bar, value in zip(bars, accuracy_values):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.01, f'{value:.2f}', 
             ha='center', va='bottom', color='black')

plt.show()

# %% [markdown]
# ##### Precision

# %%
# %store -r precision
precision_values = [precision_No_Range_4, precision_No_Range, precision_Ranges_4]
models_names = ['Range4', 'Ranges', 'Ranges_4']
bar_width = 0.3

precision_values.append(precision)
models_names.append('Original Dataset')

plt.figure(figsize=(7, 5))
bars = plt.bar(models_names, precision_values, color=['blue', 'green', 'grey', 'purple'], width=bar_width)
plt.title('Precision Comparison for Different Models')
plt.xlabel('Different Datasets')
plt.ylabel('Precision')
plt.ylim(0, 1) 

# Display actual values on top of the bars
for bar, value in zip(bars, precision_values):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.01, f'{value:.3f}', 
             ha='center', va='bottom', color='black')

plt.show()

# %% [markdown]
# ##### Recall

# %%
# %store -r recall

recall_values = [recall_No_Range_4, recall_No_Range, recall_Ranges_4]
models_names = ['Range4', 'Ranges', 'Ranges_4']
bar_width = 0.3

recall_values.append(recall)
models_names.append('Original Dataset')

plt.figure(figsize=(7, 5))
bars = plt.bar(models_names, recall_values, color=['blue', 'green', 'grey', 'purple'], width=bar_width)
plt.title('Recall Comparison for Different Models')
plt.xlabel('Different Datasets')
plt.ylabel('Recall')
plt.ylim(0, 1) 

for bar, value in zip(bars, recall_values):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.01, f'{value:.3f}', 
             ha='center', va='bottom', color='black')

plt.show()

# %% [markdown]
# ##### F1-Score

# %%
# %store -r f1

f1_values = [f1_No_Range_4, f1_No_Range, f1_Ranges_4]
models_names = ['Range4', 'Ranges', 'Ranges_4']
bar_width = 0.3

original_dataset_f1 = 0.8675  # F1-SCORE of the Original dataset
f1_values.append(f1)
models_names.append('Original Dataset')

plt.figure(figsize=(7, 5))
bars = plt.bar(models_names, f1_values, color=['blue', 'green', 'grey', 'purple'], width=bar_width)
plt.title('F1 Score Comparison for Different Models')
plt.xlabel('Different Datasets')
plt.ylabel('F1 Score')
plt.ylim(0, 1) 

for bar, value in zip(bars, f1_values):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.01, f'{value:.3f}', 
             ha='center', va='bottom', color='black')

plt.show()

# %% [markdown]
# ##### Log Loss

# %%
# %store -r log_loss_value_test

log_loss_values = [log_loss_value_No_Range_4, log_loss_value_No_Range, log_loss_value_Ranges_4]
models_names = ['Range4', 'Ranges', 'Ranges_4']
bar_width = 0.3

log_loss_values.append(log_loss_value_test)
models_names.append('Original Dataset')

plt.figure(figsize=(7, 5))
bars = plt.bar(models_names, log_loss_values, color=['blue', 'green', 'grey', 'purple'], width=bar_width)
plt.title('Positive Log Loss Comparison for Different Models')
plt.xlabel('Different Datasets')
plt.ylabel('Log Loss')

for bar, value in zip(bars, f1_values):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.01, f'{value:.3f}', 
             ha='center', va='bottom', color='black')

plt.show()

# %% [markdown]
# ##### Area under the Receiver Operating Characteristic (AROC) Curve

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import LabelBinarizer

plt.figure(figsize=(7, 5))

model_names = ['No_Range_4', 'No_Range', 'Ranges_4', 'random_forest']
datasets = [X_No_Range_4_test_scaled, X_No_Range_test_scaled, X_Ranges_4_test_scaled]
labels = [y_No_Range_4_test, y_No_Range_test, y_Ranges_4_test]
model_colors = ['red', 'green', 'cyan']

for model_name, dataset, label, color in zip(model_names, datasets, labels, model_colors):
    y_pred_proba = models[model_name].predict_proba(dataset)
    
    label_binarizer = LabelBinarizer()
    y_binary = label_binarizer.fit_transform(label)
    
    fpr, tpr, _ = roc_curve(y_binary.ravel(), y_pred_proba.ravel())
    roc_auc = auc(fpr, tpr)

    plt.plot(fpr, tpr, label=f'{model_name} (Avg AUC = {roc_auc:.2f})', linestyle='-', linewidth=2, color=color)

plt.plot([0, 1], [0, 1], color='black', lw=2, linestyle='--', label='Random Classifier (AUC = 0.5)')

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Average ROC Curves for Different Models')
plt.legend(loc='lower right')

plt.grid(True)
plt.tight_layout()
plt.show()
