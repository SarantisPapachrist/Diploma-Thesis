# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import cross_validate, KFold

from sklearn.metrics import roc_curve, auc
from sklearn.metrics import make_scorer, precision_score, recall_score, f1_score, accuracy_score, confusion_matrix, roc_auc_score, log_loss

# %% [markdown]
# #### Load the Dataset

# %%
path_train = "/home/sarantis/Documents/Διπλωματική Εργασία/Diploma-Thesis/PV_dataset/datasets/train data.csv"  
train_data = pd.read_csv(path_train, delimiter=';')

path_test = "/home/sarantis/Documents/Διπλωματική Εργασία/Diploma-Thesis/PV_dataset/datasets/test data.csv"  
test_data = pd.read_csv(path_test, delimiter=';')

display(train_data.head())
display(test_data.head())
# Out:
#          I1        I2     I1MAX     I1MIN     I1VAR     I2MAX     I2MIN  \
# 0  3.464132  3.464132  3.776515  3.433125  0.000054  3.776515  3.433125
# 1  2.244766  2.244766  2.611714  2.210978  0.000350  2.611714  2.210978
# 2  3.878360  3.878360  4.101282  3.854098  0.000010  4.101282  3.854098
# 3  2.816389  2.816389  3.285793  2.758149  0.000192  3.285793  2.758149
# 4  1.238798  1.238798  5.455667  0.141519  0.001153  5.455667  0.141519
#
#       I2VAR        I3        I4  ...     Vdcmax1     Vdcmin1    Pdcmean1   IR  \
# 0  0.000054  3.755050  3.755050  ...  514.369415  509.002655  169.603373  660
# 1  0.000350  2.572122  2.572122  ...  521.970593  503.241431  116.954097  450
# 2  0.000010  4.094577  4.094577  ...  511.837039  509.378912  184.213307  720
# 3  0.000192  3.247759  3.247759  ...  518.028478  507.378348  147.283635  570
# 4  0.001153  5.465640  5.465640  ...  500.827418  500.127036  238.608844  960
#
#     T   range 1   range 2       range 3       range 4  class
# 0  22  0.343390  0.343390  1.332270e-14  5.773160e-15      1
# 1  15  0.400736  0.400736  1.554310e-14  0.000000e+00      1
# 2  24  0.247183  0.247183  2.131630e-14  7.105430e-15      1
# 3  19  0.527644  0.527644  1.199040e-14  1.332270e-14      1
# 4  32  5.314147  5.314147  2.442490e-14  2.042810e-14      1
#
# [5 rows x 31 columns]
#         I1      I2   I1MAX    I1MIN     I1VAR   I2MAX    I2MIN     I2VAR  \
# 0  2.79120  3.0740  3.0704  2.54180  0.060570  3.1119  3.00330  0.001416
# 1  3.45340  3.6386  3.6218  3.31490  0.018449  3.6889  3.56890  0.002442
# 2  1.95250  2.0837  2.3345  1.84450  0.012447  2.3366  2.03480  0.001690
# 3  2.40180  2.5785  2.5868  2.25420  0.021388  2.6087  2.51950  0.000998
# 4  0.85467  1.0284  2.3547  0.51656  0.211560  2.3567  0.86222  0.129860
#
#        I3      I4  ...  Vdcmax1  Vdcmin1  Pdcmean1   IR   T  range 1  range 2  \
# 0  3.0158  3.0158  ...   506.76   483.08   132.930  526  26  0.52860  0.10860
# 1  3.5794  3.5794  ...   500.68   489.94   157.050  627  31  0.30690  0.12000
# 2  2.0466  2.0466  ...   492.02   475.91    88.824  357  33  0.49000  0.30180
# 3  2.5323  2.5323  ...   500.54   476.94   110.530  442  29  0.33260  0.08920
# 4  1.0164  1.0164  ...   509.73   476.00    46.718  148  11  1.83814  1.49448
#
#    range 3  range 4  class
# 0 -0.28280      0.0      2
# 1 -0.18520      0.0      2
# 2 -0.13120      0.0      2
# 3 -0.17670      0.0      2
# 4 -0.17373      0.0      2
#
# [5 rows x 31 columns]

# %%
# Ένωση των δύο dataframe(train & test) 
combined_data = pd.concat([train_data, test_data], axis=0, ignore_index=True)

combined_data.head()
# Out:
#          I1        I2     I1MAX     I1MIN     I1VAR     I2MAX     I2MIN  \
# 0  3.464132  3.464132  3.776515  3.433125  0.000054  3.776515  3.433125
# 1  2.244766  2.244766  2.611714  2.210978  0.000350  2.611714  2.210978
# 2  3.878360  3.878360  4.101282  3.854098  0.000010  4.101282  3.854098
# 3  2.816389  2.816389  3.285793  2.758149  0.000192  3.285793  2.758149
# 4  1.238798  1.238798  5.455667  0.141519  0.001153  5.455667  0.141519
#
#       I2VAR        I3        I4  ...     Vdcmax1     Vdcmin1    Pdcmean1   IR  \
# 0  0.000054  3.755050  3.755050  ...  514.369415  509.002655  169.603373  660
# 1  0.000350  2.572122  2.572122  ...  521.970593  503.241431  116.954097  450
# 2  0.000010  4.094577  4.094577  ...  511.837039  509.378912  184.213307  720
# 3  0.000192  3.247759  3.247759  ...  518.028478  507.378348  147.283635  570
# 4  0.001153  5.465640  5.465640  ...  500.827418  500.127036  238.608844  960
#
#     T   range 1   range 2       range 3       range 4  class
# 0  22  0.343390  0.343390  1.332270e-14  5.773160e-15      1
# 1  15  0.400736  0.400736  1.554310e-14  0.000000e+00      1
# 2  24  0.247183  0.247183  2.131630e-14  7.105430e-15      1
# 3  19  0.527644  0.527644  1.199040e-14  1.332270e-14      1
# 4  32  5.314147  5.314147  2.442490e-14  2.042810e-14      1
#
# [5 rows x 31 columns]

# %% [markdown]
# #### Preprocessing

# %%
# Check for missing values
missing_values_train = train_data.isnull().sum()
if missing_values_train.sum() == 0:
    print("No missing values found.")
else:
    print("Missing values:")
    print(missing_values_train)

missing_values_test = test_data.isnull().sum()
if missing_values_test.sum() == 0:
    print("No missing values found.")
else:
    print("Missing values:")
    print(missing_values_test)

missing_values_test = combined_data.isnull().sum()
if missing_values_test.sum() == 0:
    print("No missing values found.")
else:
    print("Missing values:")
    print(missing_values_test)    

# Dataframe without class
X_train = train_data.drop('class', axis=1) 
X_test = test_data.drop('class', axis=1)
# Dataframe for Target Variable
y_train = train_data['class']  
y_test = test_data['class']

# Dataframe without class
X_dataset = combined_data.drop('class', axis=1)
# Dataframe for Target Variable
y_dataset = combined_data['class']

# Check data types
#print(X_train.dtypes)
#print(X_test.dtypes)
# Out:
# No missing values found.
# No missing values found.
# No missing values found.

# %% [markdown]
# #### Min-Max Scaling

# %%
scaler = MinMaxScaler()

X_train_scaled = pd.DataFrame(scaler.fit_transform(X_train), columns=X_train.columns)
X_test_scaled = pd.DataFrame(scaler.transform(X_test), columns=X_test.columns)
X_scaled = pd.DataFrame(scaler.fit_transform(X_dataset), columns=X_dataset.columns)

# %% [markdown]
# #### Lasso-Regression

# %%
logreg_model = LogisticRegression(penalty='l1', solver='liblinear', max_iter=1000, C=10)

logreg_model.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression(C=10, max_iter=1000, penalty='l1', solver='liblinear')

# %% [markdown]
# #### Evaluation on Training Data

# %%
y_train_pred = logreg_model.predict(X_train_scaled)
y_train_pred_proba = logreg_model.predict_proba(X_train_scaled)

# Precision
precision_train = precision_score(y_train, y_train_pred, average='weighted', zero_division=1)

# Recall
recall_train = recall_score(y_train, y_train_pred, average='weighted')

# F1-Score
f1_train = f1_score(y_train, y_train_pred, average='weighted')

# Accuracy
accuracy_train = accuracy_score(y_train, y_train_pred)

# Log Loss
log_loss_value_train = log_loss(y_train, y_train_pred_proba)

# Confusion Matrix
conf_matrix_train = confusion_matrix(y_train, y_train_pred)

# AROC Curve
roc_auc_train = roc_auc_score(y_train, y_train_pred_proba, multi_class='ovr', labels=np.unique(y_train))

# Evaluation Metrics
print(f'Logistic Regression Training Confusion Matrix:\n{conf_matrix_train}')
print()
print(f'Logistic Regression Training Accuracy: {accuracy_train}')
print(f'Logistic Regression Training F1-Score: {f1_train}')
print(f'Logistic Regression Training Precision: {precision_train}')
print(f'Logistic Regression Training Recall: {recall_train}')
print(f'Logistic Regression Training Log Loss: {log_loss_value_train}')
print(f'Logistic Regression Training Area Under the ROC Curve (AROC): {roc_auc_train}')
# Out:
# Logistic Regression Training Confusion Matrix:
# [[100   0   0   0]
#  [  0 153   0   0]
#  [  0   0 149   0]
#  [  0   0   0 198]]
#
# Logistic Regression Training Accuracy: 1.0
# Logistic Regression Training F1-Score: 1.0
# Logistic Regression Training Precision: 1.0
# Logistic Regression Training Recall: 1.0
# Logistic Regression Training Log Loss: 0.24188484226982884
# Logistic Regression Training Area Under the ROC Curve (AROC): 1.0

# %% [markdown]
# #### Evaluation on Test Data

# %%
y_test_pred = logreg_model.predict(X_test_scaled)
y_test_pred_proba = logreg_model.predict_proba(X_test_scaled)

# Precision
precision_test = precision_score(y_test, y_test_pred, average='weighted', zero_division=1)

# Recall
recall_test = recall_score(y_test, y_test_pred, average='weighted')

# F1-Score
f1_test = f1_score(y_test, y_test_pred, average='weighted')

# Accuracy
accuracy_test = accuracy_score(y_test, y_test_pred)

# Log Loss
log_loss_value_test = log_loss(y_test, y_test_pred_proba)

# Confusion Matrix
conf_matrix_test = confusion_matrix(y_test, y_test_pred)

# AROC Curve
roc_auc_test = roc_auc_score(y_test, y_test_pred_proba, multi_class='ovr', labels=np.unique(y_test))

# Evaluation Metrics
print(f'Logistic Regression Testing Confusion Matrix:\n{conf_matrix_test}')
print()
print(f'Logistic Regression Testing Accuracy: {accuracy_test}')
print(f'Logistic Regression Testing F1-Score: {f1_test}')
print(f'Logistic Regression Testing Precision: {precision_test}')
print(f'Logistic Regression Testing Recall: {recall_test}')
print(f'Logistic Regression Testing Log Loss: {log_loss_value_test}')
print(f'Logistic Regression Testing Area Under the ROC Curve (AROC): {roc_auc_test}')
# Out:
# Logistic Regression Testing Confusion Matrix:
# [[25  0  0  0]
#  [15  3  7  0]
#  [ 0  0 25  0]
#  [ 0  0  0 25]]
#
# Logistic Regression Testing Accuracy: 0.78
# Logistic Regression Testing F1-Score: 0.715177366493156
# Logistic Regression Testing Precision: 0.8515625
# Logistic Regression Testing Recall: 0.78
# Logistic Regression Testing Log Loss: 1.0635034965586359
# Logistic Regression Testing Area Under the ROC Curve (AROC): 0.8758666666666667

# %% [markdown]
# ### Plot Results

# %% [markdown]
# #### Confusion Matrix

# %%
conf_matrix = confusion_matrix(y_test, y_test_pred)

# Plot confusion matrix 
plt.figure(figsize=(7, 5))
sns.heatmap(conf_matrix, annot=True, fmt='g', cmap='Purples', xticklabels=['Class 0', 'Class 1', 'Class 2', 'Class 3'], yticklabels=['Class 0', 'Class 1', 'Class 2', 'Class 3'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# %% [markdown]
# #### Receiver Operating Characteristic (ROC) Curve

# %%
selected_classes = [0, 1, 2, 3]
plt.figure(figsize=(6, 4))

for class_label in selected_classes:
    y_test_binary = (y_test == class_label).astype(int)
    fpr, tpr, thresholds = roc_curve(y_test_binary, y_test_pred_proba[:, class_label])
    roc_auc = auc(fpr, tpr)
    
    # Customize κάθε κλάση
    plt.plot(fpr, tpr, label=f'Class {class_label} (AUC = {roc_auc:.2f})', 
             color=plt.cm.get_cmap('tab10')(class_label), linestyle='-', linewidth=2)

# Plot the diagonal line 
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves for Selected Classes (OvR)')
plt.legend(loc='lower right')

plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Precision, Recall, F1 Score, Accuracy

# %%
fig, ax = plt.subplots(figsize=(7, 4))
metrics = ['Precision', 'Recall', 'F1 Score', 'Accuracy']
scores = [precision_test, recall_test, f1_test, accuracy_test]
bar_width = 0.5

# Plot horizontal bars
bars = ax.barh(metrics, scores, height=bar_width, color = ['pink', 'green', 'purple', 'cyan'])

# Display actual values 
for bar in bars:
    plt.text(bar.get_width(), bar.get_y() + bar.get_height() / 2, f'{bar.get_width():.3f}', 
             va='center', ha='left', color='black')

ax.set_xlabel('Scores')
ax.set_title('Model Evaluation Metrics')

plt.show()

# %% [markdown]
# #### 5fold Cross Validation

# %%
kf = KFold(n_splits=5, shuffle=True, random_state=42)
logreg = LogisticRegression(solver='liblinear')

scoring = {
    'accuracy': make_scorer(accuracy_score),
    'precision': make_scorer(precision_score, average='micro'),
    'recall': make_scorer(recall_score, average='micro'),
    'f1': make_scorer(f1_score, average='micro'),
    'log_loss': make_scorer(log_loss, needs_proba=True),
    'roc_auc': make_scorer(roc_auc_score, needs_proba=True, multi_class='ovo') 
}

cv_results = cross_validate(logreg, X_dataset, y_dataset, cv=kf, scoring=scoring, error_score=np.nan)

for fold in range(1, kf.get_n_splits() + 1):
    print(f"Fold {fold} Metrics:")
    print(f"Accuracy: {cv_results['test_accuracy'][fold-1]:.4f}")
    print(f"Precision: {cv_results['test_precision'][fold-1]:.4f}")
    print(f"Recall: {cv_results['test_recall'][fold-1]:.4f}")
    print(f"F1 Score: {cv_results['test_f1'][fold-1]:.4f}")
    print(f"Log Loss: {abs(np.mean(cv_results['test_log_loss'][fold-1])):.4f}")
    print(f"ROC AUC: {cv_results['test_roc_auc'][fold-1]:.4f}")
    print("-" * 100)

mean_metrics = {metric: np.mean(cv_results[f'test_{metric}']) for metric in scoring}

print("Mean Metrics Across Folds:")
for metric, value in mean_metrics.items():
    if metric == 'test_log_loss':
        value = abs(value)
    print(f"{metric}: {value}")
# Out:
# Fold 1 Metrics:
# Accuracy: 0.9929
# Precision: 0.9929
# Recall: 0.9929
# F1 Score: 0.9929
# Log Loss: 0.2912
# ROC AUC: 1.0000
# ----------------------------------------------------------------------------------------------------
# Fold 2 Metrics:
# Accuracy: 0.9714
# Precision: 0.9714
# Recall: 0.9714
# F1 Score: 0.9714
# Log Loss: 0.3280
# ROC AUC: 1.0000
# ----------------------------------------------------------------------------------------------------
# Fold 3 Metrics:
# Accuracy: 0.9857
# Precision: 0.9857
# Recall: 0.9857
# F1 Score: 0.9857
# Log Loss: 0.3608
# ROC AUC: 0.9989
# ----------------------------------------------------------------------------------------------------
# Fold 4 Metrics:
# Accuracy: 0.9714
# Precision: 0.9714
# Recall: 0.9714
# F1 Score: 0.9714
# Log Loss: 0.3477
# ROC AUC: 0.9985
# ----------------------------------------------------------------------------------------------------
# Fold 5 Metrics:
# Accuracy: 0.9714
# Precision: 0.9714
# Recall: 0.9714
# F1 Score: 0.9714
# Log Loss: 0.3518
# ROC AUC: 0.9995
# ----------------------------------------------------------------------------------------------------
# Mean Metrics Across Folds:
# accuracy: 0.9785714285714286
# precision: 0.9785714285714286
# recall: 0.9785714285714286
# f1: 0.9785714285714286
# log_loss: 0.3359066725180347
# roc_auc: 0.9993988900461044
# /home/sarantis/.local/lib/python3.10/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(18, 9))
fig.suptitle('Evaluation Metrics Across Folds', fontsize=16)

# Function for values inside the bars
def add_values(ax, values):
    for i, value in enumerate(values):
        ax.text(i + 1, value - 0.05, f'{value:.4f}', ha='center', va='bottom', color='black')

bar_height = 0.5
metrics_to_plot = ['test_accuracy', 'test_precision', 'test_recall', 'test_f1', 'test_log_loss', 'test_roc_auc']
colors = ['red', 'green', 'blue', 'orange', 'purple', 'pink']  

for idx, (metric, color) in enumerate(zip(metrics_to_plot, colors)):
    row = idx // 3
    col = idx % 3

    if metric == 'neg_log_loss':
        metric_values = np.abs(cv_results[f'{metric}'])
    else:
        metric_values = cv_results[f'{metric}']

    bars = axes[row, col].bar(range(1, kf.get_n_splits() + 1), metric_values, color=color, alpha=0.7)
    axes[row, col].set_title(metric.capitalize())
    add_values(axes[row, col], metric_values)

    axes[row, col].legend([f'Mean {metric.capitalize()}'], loc='center right', bbox_to_anchor=(0.99, 0.4))

if len(metrics_to_plot) < 6:
    fig.delaxes(axes[-1, -1])

plt.subplots_adjust(hspace=0.2)
plt.show()
